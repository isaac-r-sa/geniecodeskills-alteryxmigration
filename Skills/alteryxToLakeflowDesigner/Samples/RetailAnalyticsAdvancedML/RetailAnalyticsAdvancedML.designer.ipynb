# %%
"""
id: source_products
template: source
templateVersion: 1.0.0
name: source_products
position:
  x: 0
  y: 145
description:
  text: Read data from a CSV file with headers and automatically detect schema.
  hash: 22f042dd
previewCodeHash: 90dbaaa327195f6b
previewMode: "1000"
config:
  file_source:
    path: /Volumes/aldi_aus/demo/raw_test/product_catalog.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/aldi_aus/demo/raw_test/product_catalog.csv",
        "format": "csv",
        "header": True,
        "inferSchema": True
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_products.data"] = out["data"]

# %%
"""
id: source_stores
template: source
templateVersion: 1.0.0
name: source_stores
position:
  x: 0
  y: 290
description:
  text: Load data from a CSV file with header and schema inference.
  hash: 58f44f54
previewCodeHash: b2857a1f0fde10d4
previewMode: "1000"
config:
  file_source:
    path: /Volumes/aldi_aus/demo/raw_test/stores.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/aldi_aus/demo/raw_test/stores.csv",
        "format": "csv",
        "header": True,
        "inferSchema": True
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_stores.data"] = out["data"]

# %%
"""
id: source_transactions
template: source
templateVersion: 1.0.0
name: source_transactions
position:
  x: 0
  y: 0
description:
  text: Read a CSV file with headers and schema inference from the given path.
  hash: f46dc4b7
previewCodeHash: cfed9af8a5f08ba7
previewMode: "1000"
config:
  file_source:
    path: /Volumes/aldi_aus/demo/raw_test/transactions.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/aldi_aus/demo/raw_test/transactions.csv",
        "format": "csv",
        "header": True,
        "inferSchema": True
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_transactions.data"] = out["data"]

# %%
"""
id: geo_coords
template: transform
templateVersion: 1.0.0
name: geo_coords
position:
  x: 260
  y: 435
description:
  text: Add latitude and longitude based on store region.
  hash: 2a261ccf
previewMode: "1000"
config:
  expressions:
    - store_id
    - store_region
    - CASE WHEN store_region = 'AUS-NSW' THEN -33.86 WHEN store_region = 'AUS-VIC' THEN -37.81 WHEN store_region = 'AUS-QLD' THEN -27.47 WHEN store_region = 'AUS-WA' THEN -31.95 WHEN store_region = 'AUS-SA' THEN -34.93 WHEN store_region = 'AUS-TAS' THEN -42.88 WHEN store_region = 'AUS-ACT' THEN -35.28 WHEN store_region = 'AUS-NT' THEN -12.46 ELSE -33.86 END AS `store_lat`
    - CASE WHEN store_region = 'AUS-NSW' THEN 151.21 WHEN store_region = 'AUS-VIC' THEN 144.96 WHEN store_region = 'AUS-QLD' THEN 153.03 WHEN store_region = 'AUS-WA' THEN 115.86 WHEN store_region = 'AUS-SA' THEN 138.60 WHEN store_region = 'AUS-TAS' THEN 147.33 WHEN store_region = 'AUS-ACT' THEN 149.13 WHEN store_region = 'AUS-NT' THEN 130.84 ELSE 151.21 END AS `store_lon`
input:
  - node: source_stores
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "store_id",
        "store_region",
        "CASE WHEN store_region = 'AUS-NSW' THEN -33.86 WHEN store_region = 'AUS-VIC' THEN -37.81 WHEN store_region = 'AUS-QLD' THEN -27.47 WHEN store_region = 'AUS-WA' THEN -31.95 WHEN store_region = 'AUS-SA' THEN -34.93 WHEN store_region = 'AUS-TAS' THEN -42.88 WHEN store_region = 'AUS-ACT' THEN -35.28 WHEN store_region = 'AUS-NT' THEN -12.46 ELSE -33.86 END AS `store_lat`",
        "CASE WHEN store_region = 'AUS-NSW' THEN 151.21 WHEN store_region = 'AUS-VIC' THEN 144.96 WHEN store_region = 'AUS-QLD' THEN 153.03 WHEN store_region = 'AUS-WA' THEN 115.86 WHEN store_region = 'AUS-SA' THEN 138.60 WHEN store_region = 'AUS-TAS' THEN 147.33 WHEN store_region = 'AUS-ACT' THEN 149.13 WHEN store_region = 'AUS-NT' THEN 130.84 ELSE 151.21 END AS `store_lon`"
    ]
}
inputs = {
    "data": ctx["source_stores.data"]
}
out = run(config, inputs, spark)
ctx["geo_coords.transformed_data"] = out["transformed_data"]

# %%
"""
id: cleanse_fields
template: transform
templateVersion: 1.0.0
name: cleanse_fields
position:
  x: 260
  y: 0
description:
  text: Add a unique row ID and clean up name and payment method formats while keeping selected columns.
  hash: 6618939d
previewCodeHash: 07b028b9d8a49c07
previewMode: "1000"
config:
  expressions:
    - monotonically_increasing_id() AS `row_id`
    - transaction_id
    - customer_id
    - TRIM(INITCAP(customer_name)) AS `customer_name`
    - product_id
    - product_code
    - store_id
    - store_region
    - transaction_date
    - quantity
    - unit_price
    - discount_pct
    - TRIM(INITCAP(payment_method)) AS `payment_method`
    - email
input:
  - node: source_transactions
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "monotonically_increasing_id() AS `row_id`",
        "transaction_id",
        "customer_id",
        "TRIM(INITCAP(customer_name)) AS `customer_name`",
        "product_id",
        "product_code",
        "store_id",
        "store_region",
        "transaction_date",
        "quantity",
        "unit_price",
        "discount_pct",
        "TRIM(INITCAP(payment_method)) AS `payment_method`",
        "email"
    ]
}
inputs = {
    "data": ctx["source_transactions.data"]
}
out = run(config, inputs, spark)
ctx["cleanse_fields.transformed_data"] = out["transformed_data"]

# %%
"""
id: geo_rank_stores
template: sql
templateVersion: 1.0.0
name: geo_rank_stores
position:
  x: 520
  y: 435
description:
  text: Assign a rank to each store within its region based on store ID.
  hash: b3a4e26f
previewCodeHash: 207068b411b0d159
previewMode: "1000"
config:
  query: |
    SELECT *,
      ROW_NUMBER() OVER (PARTITION BY store_region ORDER BY store_id) AS store_rank_in_region
    FROM (
      SELECT DISTINCT store_id, store_region, store_lat, store_lon
      FROM geo_coords
    )
input:
  - node: geo_coords
    input_port: data
    output_port: transformed_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *,\n  ROW_NUMBER() OVER (PARTITION BY store_region ORDER BY store_id) AS store_rank_in_region\nFROM (\n  SELECT DISTINCT store_id, store_region, store_lat, store_lon\n  FROM geo_coords\n)\n"
}
inputs = {
    "data": [
        ctx["geo_coords.transformed_data"]
    ],
    "data__sources": [
        {
            "node": "geo_coords",
            "output_port": "transformed_data",
            "name": "geo_coords",
            "df_name": "geo_coords"
        }
    ]
}
out = run(config, inputs, spark)
ctx["geo_rank_stores.result"] = out["result"]

# %%
"""
id: filter_valid_rows
template: filter
templateVersion: 1.0.0
name: filter_valid_rows
position:
  x: 520
  y: 0
description:
  text: Keep rows with positive quantity and non-empty unit price.
  hash: ec44c5e0
previewMode: "1000"
config:
  condition: CAST(quantity AS INT) > 0 AND unit_price IS NOT NULL
input:
  - node: cleanse_fields
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")

    if not condition:
        return {"filtered_data": df}

    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "CAST(quantity AS INT) > 0 AND unit_price IS NOT NULL"
}
inputs = {
    "data": ctx["cleanse_fields.transformed_data"]
}
out = run(config, inputs, spark)
ctx["filter_valid_rows.filtered_data"] = out["filtered_data"]

# %%
"""
id: output_geospatial_table
template: output
templateVersion: 1.0.0
name: output_geospatial_table
position:
  x: 780
  y: 435
description:
  text: Save data as a table named retail_geospatial in the aldi_aus.demo area, overwriting existing data.
  hash: e00965c4
previewMode: "1000"
config:
  catalog: aldi_aus
  schema: demo
  table_name: retail_geospatial
input:
  - node: geo_rank_stores
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "aldi_aus",
    "schema": "demo",
    "table_name": "retail_geospatial"
}
inputs = {
    "data": ctx["geo_rank_stores.result"]
}
out = run(config, inputs, spark)

# %%
"""
id: write_geospatial_csv
template: python
templateVersion: 1.0.0
name: write_geospatial_csv
position:
  x: 780
  y: 580
description:
  text: Save the data as a CSV file without the index.
  hash: 03a85b98
previewMode: "1000"
config:
  code: |
    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_geospatial.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df
input:
  - node: geo_rank_stores
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_geospatial.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["geo_rank_stores.result"]
    ],
    "data__sources": [
        {
            "node": "geo_rank_stores",
            "output_port": "result",
            "name": "geo_rank_stores",
            "df_name": "geo_rank_stores"
        }
    ]
}
out = run(config, inputs, spark)
ctx["write_geospatial_csv.result"] = out["result"]

# %%
"""
id: parse_and_derive
template: transform
templateVersion: 1.0.0
name: parse_and_derive
position:
  x: 780
  y: 0
description:
  text: Create new columns derived from transaction date and product code, calculate net amounts with discounts, and flag weekends.
  hash: 2ec4c09d
previewCodeHash: 286d4b7f9ec65e79
previewMode: "1000"
config:
  expressions:
    - "*"
    - TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss') AS `txn_dt`
    - YEAR(TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss')) AS `txn_year`
    - MONTH(TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss')) AS `txn_month`
    - TO_DATE(transaction_date, 'yyyy-MM-dd HH:mm:ss') AS `txn_date_only`
    - REGEXP_EXTRACT(product_code, '^([A-Z]{2,4})-([0-9]{3,5})-([A-Z0-9]{2,4})$', 1) AS `pc_category`
    - REGEXP_EXTRACT(product_code, '^([A-Z]{2,4})-([0-9]{3,5})-([A-Z0-9]{2,4})$', 2) AS `pc_sku`
    - REGEXP_EXTRACT(product_code, '^([A-Z]{2,4})-([0-9]{3,5})-([A-Z0-9]{2,4})$', 3) AS `pc_variant`
    - CAST(quantity AS DOUBLE) * CAST(unit_price AS DOUBLE) * (1 - CAST(discount_pct AS DOUBLE)) AS `net_amount`
    - CAST(quantity AS DOUBLE) * CAST(unit_price AS DOUBLE) * (1 - CAST(discount_pct AS DOUBLE)) * 0.62 AS `net_amount_eur`
    - CASE WHEN DAYOFWEEK(TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss')) IN (1, 7) THEN 'WK' ELSE 'WD' END AS `day_type`
    - CASE WHEN DAYOFWEEK(TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss')) IN (1, 7) THEN 1 ELSE 0 END AS `is_weekend`
input:
  - node: filter_valid_rows
    input_port: data
    output_port: filtered_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss') AS `txn_dt`",
        "YEAR(TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss')) AS `txn_year`",
        "MONTH(TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss')) AS `txn_month`",
        "TO_DATE(transaction_date, 'yyyy-MM-dd HH:mm:ss') AS `txn_date_only`",
        "REGEXP_EXTRACT(product_code, '^([A-Z]{2,4})-([0-9]{3,5})-([A-Z0-9]{2,4})$', 1) AS `pc_category`",
        "REGEXP_EXTRACT(product_code, '^([A-Z]{2,4})-([0-9]{3,5})-([A-Z0-9]{2,4})$', 2) AS `pc_sku`",
        "REGEXP_EXTRACT(product_code, '^([A-Z]{2,4})-([0-9]{3,5})-([A-Z0-9]{2,4})$', 3) AS `pc_variant`",
        "CAST(quantity AS DOUBLE) * CAST(unit_price AS DOUBLE) * (1 - CAST(discount_pct AS DOUBLE)) AS `net_amount`",
        "CAST(quantity AS DOUBLE) * CAST(unit_price AS DOUBLE) * (1 - CAST(discount_pct AS DOUBLE)) * 0.62 AS `net_amount_eur`",
        "CASE WHEN DAYOFWEEK(TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss')) IN (1, 7) THEN 'WK' ELSE 'WD' END AS `day_type`",
        "CASE WHEN DAYOFWEEK(TO_TIMESTAMP(transaction_date, 'yyyy-MM-dd HH:mm:ss')) IN (1, 7) THEN 1 ELSE 0 END AS `is_weekend`"
    ]
}
inputs = {
    "data": ctx["filter_valid_rows.filtered_data"]
}
out = run(config, inputs, spark)
ctx["parse_and_derive.transformed_data"] = out["transformed_data"]

# %%
"""
id: split_trim_names
template: transform
templateVersion: 1.0.0
name: split_trim_names
position:
  x: 1040
  y: 0
description:
  text: Split customer name into two parts by comma and trim spaces from each part.
  hash: d13202bc
previewMode: "1000"
config:
  expressions:
    - "*"
    - TRIM(SPLIT(customer_name, ',')[0]) AS `name_part1`
    - TRIM(SPLIT(customer_name, ',')[1]) AS `name_part2`
input:
  - node: parse_and_derive
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "TRIM(SPLIT(customer_name, ',')[0]) AS `name_part1`",
        "TRIM(SPLIT(customer_name, ',')[1]) AS `name_part2`"
    ]
}
inputs = {
    "data": ctx["parse_and_derive.transformed_data"]
}
out = run(config, inputs, spark)
ctx["split_trim_names.transformed_data"] = out["transformed_data"]

# %%
"""
id: join_products
template: join
templateVersion: 1.0.0
name: join_products
position:
  x: 1300
  y: 70
description:
  text: Combine two tables using a left join on product_id.
  hash: 1ca2f9e4
previewCodeHash: 0ca94a4a5df4838f
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.product_id = right.product_id
  expressions: []
input:
  - node: split_trim_names
    input_port: left
    output_port: transformed_data
  - node: source_products
    input_port: right
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.product_id = right.product_id",
    "expressions": []
}
inputs = {
    "left": ctx["split_trim_names.transformed_data"],
    "right": ctx["source_products.data"]
}
out = run(config, inputs, spark)
ctx["join_products.joined_data"] = out["joined_data"]

# %%
"""
id: standardize_product_names
template: transform
templateVersion: 1.0.0
name: standardize_product_names
position:
  x: 1560
  y: 70
description:
  text: Keep all columns and standardize product names to a consistent format.
  hash: b3e4e70c
previewMode: "1000"
config:
  expressions:
    - "*"
    - CASE WHEN product_name = 'Cola 1L' THEN 'Cola - 1 Liter' WHEN product_name = 'Choc Bar' THEN 'Chocolate Bar 100g' WHEN product_name = 'Bread Wht' THEN 'White Bread Loaf' WHEN product_name = 'Milk2pc' THEN 'Milk 2% 2L' ELSE product_name END AS `product_name_std`
input:
  - node: join_products
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "CASE WHEN product_name = 'Cola 1L' THEN 'Cola - 1 Liter' WHEN product_name = 'Choc Bar' THEN 'Chocolate Bar 100g' WHEN product_name = 'Bread Wht' THEN 'White Bread Loaf' WHEN product_name = 'Milk2pc' THEN 'Milk 2% 2L' ELSE product_name END AS `product_name_std`"
    ]
}
inputs = {
    "data": ctx["join_products.joined_data"]
}
out = run(config, inputs, spark)
ctx["standardize_product_names.transformed_data"] = out["transformed_data"]

# %%
"""
id: impute_median_price
template: sql
templateVersion: 1.0.0
name: impute_median_price
position:
  x: 1820
  y: 70
description:
  text: Fill missing unit prices with the median price and mark those rows.
  hash: 2b2e6308
previewMode: "1000"
config:
  query: |
    SELECT
      *,
      COALESCE(unit_price, PERCENTILE_APPROX(unit_price, 0.5) OVER ()) AS unit_price_imputed,
      CASE WHEN unit_price IS NULL THEN 1 ELSE 0 END AS price_was_imputed
    FROM standardize_product_names
input:
  - node: standardize_product_names
    input_port: data
    output_port: transformed_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT\n  *,\n  COALESCE(unit_price, PERCENTILE_APPROX(unit_price, 0.5) OVER ()) AS unit_price_imputed,\n  CASE WHEN unit_price IS NULL THEN 1 ELSE 0 END AS price_was_imputed\nFROM standardize_product_names\n"
}
inputs = {
    "data": [
        ctx["standardize_product_names.transformed_data"]
    ],
    "data__sources": [
        {
            "node": "standardize_product_names",
            "output_port": "transformed_data",
            "name": "standardize_product_names",
            "df_name": "standardize_product_names"
        }
    ]
}
out = run(config, inputs, spark)
ctx["impute_median_price.result"] = out["result"]

# %%
"""
id: join_stores
template: join
templateVersion: 1.0.0
name: join_stores
position:
  x: 2080
  y: 145
description:
  text: Join datasets on store_id keeping all left entries and selected columns from both.
  hash: 9026f102
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.store_id = right.store_id
  expressions:
    - left.*
    - "`right`.store_name"
    - "`right`.store_size_sqm"
    - "`right`.opened_year"
input:
  - node: impute_median_price
    input_port: left
    output_port: result
  - node: source_stores
    input_port: right
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.store_id = right.store_id",
    "expressions": [
        "left.*",
        "`right`.store_name",
        "`right`.store_size_sqm",
        "`right`.opened_year"
    ]
}
inputs = {
    "left": ctx["impute_median_price.result"],
    "right": ctx["source_stores.data"]
}
out = run(config, inputs, spark)
ctx["join_stores.joined_data"] = out["joined_data"]

# %%
"""
id: dedup_transactions
template: sql
templateVersion: 1.0.0
name: dedup_transactions
position:
  x: 2340
  y: 145
description:
  text: Keep only the first transaction record for each transaction ID.
  hash: 059232d5
previewMode: "1000"
config:
  query: |
    SELECT *
    FROM (
      SELECT *,
        ROW_NUMBER() OVER (PARTITION BY transaction_id ORDER BY txn_dt) AS rn
      FROM join_stores
    )
    WHERE rn = 1
input:
  - node: join_stores
    input_port: data
    output_port: joined_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *\nFROM (\n  SELECT *,\n    ROW_NUMBER() OVER (PARTITION BY transaction_id ORDER BY txn_dt) AS rn\n  FROM join_stores\n)\nWHERE rn = 1\n"
}
inputs = {
    "data": [
        ctx["join_stores.joined_data"]
    ],
    "data__sources": [
        {
            "node": "join_stores",
            "output_port": "joined_data",
            "name": "join_stores",
            "df_name": "join_stores"
        }
    ]
}
out = run(config, inputs, spark)
ctx["dedup_transactions.result"] = out["result"]

# %%
"""
id: soundex_columns
template: transform
templateVersion: 1.0.0
name: soundex_columns
position:
  x: 2600
  y: 145
description:
  text: Add columns for soundex of customer name and email domain extraction.
  hash: a8832565
previewMode: "1000"
config:
  expressions:
    - "*"
    - SOUNDEX(customer_name) AS `name_soundex`
    - REGEXP_EXTRACT(email, '@(.+)$', 1) AS `email_domain`
input:
  - node: dedup_transactions
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "SOUNDEX(customer_name) AS `name_soundex`",
        "REGEXP_EXTRACT(email, '@(.+)$', 1) AS `email_domain`"
    ]
}
inputs = {
    "data": ctx["dedup_transactions.result"]
}
out = run(config, inputs, spark)
ctx["soundex_columns.transformed_data"] = out["transformed_data"]

# %%
"""
id: assign_customer_groups
template: sql
templateVersion: 1.0.0
name: assign_customer_groups
position:
  x: 2860
  y: 145
description:
  text: Assign a group ID to each customer based on their name sound and email domain.
  hash: 7384b6c9
previewCodeHash: 27c10fda4cf2d26e
previewMode: "1000"
config:
  query: |
    SELECT *,
      DENSE_RANK() OVER (ORDER BY name_soundex, email_domain) AS customer_group_id
    FROM soundex_columns
input:
  - node: soundex_columns
    input_port: data
    output_port: transformed_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *,\n  DENSE_RANK() OVER (ORDER BY name_soundex, email_domain) AS customer_group_id\nFROM soundex_columns\n"
}
inputs = {
    "data": [
        ctx["soundex_columns.transformed_data"]
    ],
    "data__sources": [
        {
            "node": "soundex_columns",
            "output_port": "transformed_data",
            "name": "soundex_columns",
            "df_name": "soundex_columns"
        }
    ]
}
out = run(config, inputs, spark)
ctx["assign_customer_groups.result"] = out["result"]

# %%
"""
id: customer_features
template: sql
templateVersion: 1.0.0
name: customer_features
position:
  x: 3120
  y: 145
description:
  text: Calculate days since previous transaction for each customer group, running total sales per store, and rank customers into deciles by amount.
  hash: ee15926c
previewCodeHash: a69a520e1c55d558
previewMode: "1000"
config:
  query: |
    SELECT *,
      DATEDIFF(
        txn_dt,
        LAG(txn_dt) OVER (PARTITION BY customer_group_id ORDER BY txn_dt)
      ) AS days_since_prior,
      SUM(net_amount) OVER (
        PARTITION BY store_id ORDER BY txn_dt
        ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
      ) AS running_store_sales,
      NTILE(10) OVER (ORDER BY net_amount DESC) AS customer_decile
    FROM assign_customer_groups
input:
  - node: assign_customer_groups
    input_port: data
    output_port: result
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *,\n  DATEDIFF(\n    txn_dt,\n    LAG(txn_dt) OVER (PARTITION BY customer_group_id ORDER BY txn_dt)\n  ) AS days_since_prior,\n  SUM(net_amount) OVER (\n    PARTITION BY store_id ORDER BY txn_dt\n    ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW\n  ) AS running_store_sales,\n  NTILE(10) OVER (ORDER BY net_amount DESC) AS customer_decile\nFROM assign_customer_groups\n"
}
inputs = {
    "data": [
        ctx["assign_customer_groups.result"]
    ],
    "data__sources": [
        {
            "node": "assign_customer_groups",
            "output_port": "result",
            "name": "assign_customer_groups",
            "df_name": "assign_customer_groups"
        }
    ]
}
out = run(config, inputs, spark)
ctx["customer_features.result"] = out["result"]

# %%
"""
id: aggregate_store_cat_month
template: sql
templateVersion: 1.0.0
name: aggregate_store_cat_month
position:
  x: 3120
  y: 290
description:
  text: Aggregate transactions by store, category, and month with counts, customers, revenue, and basket stats.
  hash: 01cc4b6a
previewMode: "1000"
config:
  query: |
    SELECT
      store_id,
      store_region,
      pc_category,
      txn_year,
      txn_month,
      COUNT(*) AS txn_count,
      COUNT(DISTINCT customer_id) AS unique_customers,
      SUM(net_amount) AS total_revenue,
      AVG(net_amount) AS avg_basket,
      STDDEV(net_amount) AS stddev_basket,
      PERCENTILE_APPROX(net_amount, 0.5) AS median_basket,
      SUM(CAST(quantity AS BIGINT)) AS total_units
    FROM customer_features
    GROUP BY store_id, store_region, pc_category, txn_year, txn_month
input:
  - node: customer_features
    input_port: data
    output_port: result
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT\n  store_id,\n  store_region,\n  pc_category,\n  txn_year,\n  txn_month,\n  COUNT(*) AS txn_count,\n  COUNT(DISTINCT customer_id) AS unique_customers,\n  SUM(net_amount) AS total_revenue,\n  AVG(net_amount) AS avg_basket,\n  STDDEV(net_amount) AS stddev_basket,\n  PERCENTILE_APPROX(net_amount, 0.5) AS median_basket,\n  SUM(CAST(quantity AS BIGINT)) AS total_units\nFROM customer_features\nGROUP BY store_id, store_region, pc_category, txn_year, txn_month\n"
}
inputs = {
    "data": [
        ctx["customer_features.result"]
    ],
    "data__sources": [
        {
            "node": "customer_features",
            "output_port": "result",
            "name": "customer_features",
            "df_name": "customer_features"
        }
    ]
}
out = run(config, inputs, spark)
ctx["aggregate_store_cat_month.result"] = out["result"]

# %%
"""
id: daily_revenue_agg
template: aggregate
templateVersion: 1.0.0
name: daily_revenue_agg
position:
  x: 3120
  y: 780
description:
  text: Group data by transaction date and calculate total revenue and transaction count for each day.
  hash: 4420063f
previewMode: "1000"
config:
  group_bys:
    - expr: txn_date_only
      type: expr
  aggregations:
    - columnExpr:
        expr: net_amount
        type: expr
      fn: SUM
      alias: daily_revenue
    - columnExpr:
        expr: transaction_id
        type: expr
      fn: COUNT
      alias: daily_txns
input:
  - node: customer_features
    input_port: data
    output_port: result
"""

# generated from the system
import math
from typing import Dict, Any
import pyspark.sql.functions as F

# Default percentile (median). Used as a fallback when a PERCENTILE aggregation
# is missing or has a non-numeric / non-finite percentage. Mirrors
# DEFAULT_PERCENTILE_VALUE in AggregateNodeViewModel.ts so SQL and Python
# pipelines agree on the default.
DEFAULT_PERCENTILE = 0.5

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        # Skip pass-through columns that duplicate a group-by column;
        # groupBy() already includes them in the output.
        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum,
            "AVG": F.avg,
            "COUNT": F.count,
            "MIN": F.min,
            "MAX": F.max,
            "MEAN": F.mean,
            "MEDIAN": F.median,
            "STDDEV": F.stddev,
            "VARIANCE": F.variance,
        }

        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        elif fn == "PERCENTILE":
            # Spark PERCENTILE requires (col, percentage [, frequency]) with percentage
            # in [0, 1]; emitting PERCENTILE(col) triggers WRONG_NUM_ARGS at analysis
            # time. For finite numeric inputs we clamp to [0, 1] (mirroring the V1/V2
            # input clamps) so out-of-range values like -0.1 or 1.5 — typos or stale
            # frontend state — become a valid boundary instead of silently overriding
            # the user's intent with the median. Non-numeric, non-finite, boolean, or
            # missing values fall back to DEFAULT_PERCENTILE.
            raw_pct = agg_def.get("percentage")
            if (
                isinstance(raw_pct, (int, float))
                and not isinstance(raw_pct, bool)
                and math.isfinite(raw_pct)
            ):
                pct = max(0.0, min(1.0, float(raw_pct)))
            else:
                pct = DEFAULT_PERCENTILE
            col = F.expr(f"PERCENTILE({raw_expr}, {pct})")
        else:
            col = F.expr(f"{fn}({raw_expr})")

        if alias:
            col = col.alias(alias)

        agg_exprs.append(col)

    group_cols = [
        gb.get("expr", "") for gb in group_bys if gb.get("expr", "")
    ]

    if not agg_exprs:
        if group_cols:
            result = df.select(*group_cols).distinct()
            return {"aggregated_data": result}
        return {"aggregated_data": df}

    if group_cols:
        result = df.groupBy(*group_cols).agg(*agg_exprs)
    else:
        result = df.agg(*agg_exprs)

    return {"aggregated_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "txn_date_only",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "net_amount",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "daily_revenue",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "transaction_id",
                "type": "expr"
            },
            "fn": "COUNT",
            "alias": "daily_txns",
            "withAsKeyword": None
        }
    ]
}
inputs = {
    "data": ctx["customer_features.result"]
}
out = run(config, inputs, spark)
ctx["daily_revenue_agg.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: ml_linear_regression
template: python
templateVersion: 1.0.0
name: ml_linear_regression
position:
  x: 3120
  y: 580
description:
  text: Randomly sample 10% of data, balance weekend transactions, then build and evaluate a linear regression model to predict net amount from sales features.
  hash: 30d1b706
previewMode: "1000"
config:
  code: |
    from pyspark.sql import functions as F
    from pyspark.ml.feature import VectorAssembler, StringIndexer
    from pyspark.ml.regression import LinearRegression
    from pyspark.ml import Pipeline

    df = inputs["data"][0]

    # Random 10% sample (Alteryx: Random %Sample tool, seed=42)
    df_sample = df.sample(fraction=0.1, seed=42)

    # Oversample weekend transactions to 50% balance (Alteryx: Oversample tool)
    wk_count = df_sample.filter(F.col("day_type") == "WK").count()
    wd_count = df_sample.filter(F.col("day_type") == "WD").count()
    if wk_count > 0 and wd_count > wk_count:
        oversample_ratio = (wd_count / wk_count) - 1
        wk_extra = df_sample.filter(F.col("day_type") == "WK").sample(
            withReplacement=True, fraction=oversample_ratio, seed=42
        )
        df_sample = df_sample.union(wk_extra)

    # Prepare features for Linear Regression
    # Target: net_amount, Predictors: quantity, unit_price_imputed, discount_pct, is_weekend
    df_ml = df_sample.select(
        F.col("net_amount").cast("double"),
        F.col("quantity").cast("double"),
        F.col("unit_price_imputed").cast("double").alias("price"),
        F.col("discount_pct").cast("double"),
        F.col("is_weekend").cast("double"),
        F.col("customer_decile").cast("double"),
        F.col("store_id"), F.col("pc_category"), F.col("transaction_id")
    ).dropna()

    # String indexing for categorical features
    indexer_cat = StringIndexer(inputCol="pc_category", outputCol="pc_cat_idx", handleInvalid="keep")

    # Assemble feature vector
    assembler = VectorAssembler(
        inputCols=["quantity", "price", "discount_pct", "is_weekend", "pc_cat_idx"],
        outputCol="features"
    )

    # Linear Regression model
    lr = LinearRegression(
        featuresCol="features",
        labelCol="net_amount",
        predictionCol="predicted_net_amount"
    )

    # 70/30 train/test split (Alteryx: Create Samples 70/15/15)
    train_df, test_df = df_ml.randomSplit([0.7, 0.3], seed=42)

    # Build and fit pipeline
    pipeline = Pipeline(stages=[indexer_cat, assembler, lr])
    model = pipeline.fit(train_df)

    # Score test set
    scored = model.transform(test_df)

    # Compute residuals (Alteryx: Formula tool)
    scored = scored.withColumn("residual", F.col("net_amount") - F.col("predicted_net_amount"))
    scored = scored.withColumn(
        "abs_pct_error",
        F.when(F.col("net_amount") != 0,
               F.abs(F.col("residual")) / F.abs(F.col("net_amount"))
        ).otherwise(0)
    )

    result = scored.select(
        "transaction_id", "store_id", "pc_category", "quantity", "price",
        "discount_pct", "is_weekend", "net_amount",
        "predicted_net_amount", "residual", "abs_pct_error"
    )
input:
  - node: customer_features
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    from pyspark.sql import functions as F
    from pyspark.ml.feature import VectorAssembler, StringIndexer
    from pyspark.ml.regression import LinearRegression
    from pyspark.ml import Pipeline

    df = inputs["data"][0]

    # Random 10% sample (Alteryx: Random %Sample tool, seed=42)
    df_sample = df.sample(fraction=0.1, seed=42)

    # Oversample weekend transactions to 50% balance (Alteryx: Oversample tool)
    wk_count = df_sample.filter(F.col("day_type") == "WK").count()
    wd_count = df_sample.filter(F.col("day_type") == "WD").count()
    if wk_count > 0 and wd_count > wk_count:
        oversample_ratio = (wd_count / wk_count) - 1
        wk_extra = df_sample.filter(F.col("day_type") == "WK").sample(
            withReplacement=True, fraction=oversample_ratio, seed=42
        )
        df_sample = df_sample.union(wk_extra)

    # Prepare features for Linear Regression
    # Target: net_amount, Predictors: quantity, unit_price_imputed, discount_pct, is_weekend
    df_ml = df_sample.select(
        F.col("net_amount").cast("double"),
        F.col("quantity").cast("double"),
        F.col("unit_price_imputed").cast("double").alias("price"),
        F.col("discount_pct").cast("double"),
        F.col("is_weekend").cast("double"),
        F.col("customer_decile").cast("double"),
        F.col("store_id"), F.col("pc_category"), F.col("transaction_id")
    ).dropna()

    # String indexing for categorical features
    indexer_cat = StringIndexer(inputCol="pc_category", outputCol="pc_cat_idx", handleInvalid="keep")

    # Assemble feature vector
    assembler = VectorAssembler(
        inputCols=["quantity", "price", "discount_pct", "is_weekend", "pc_cat_idx"],
        outputCol="features"
    )

    # Linear Regression model
    lr = LinearRegression(
        featuresCol="features",
        labelCol="net_amount",
        predictionCol="predicted_net_amount"
    )

    # 70/30 train/test split (Alteryx: Create Samples 70/15/15)
    train_df, test_df = df_ml.randomSplit([0.7, 0.3], seed=42)

    # Build and fit pipeline
    pipeline = Pipeline(stages=[indexer_cat, assembler, lr])
    model = pipeline.fit(train_df)

    # Score test set
    scored = model.transform(test_df)

    # Compute residuals (Alteryx: Formula tool)
    scored = scored.withColumn("residual", F.col("net_amount") - F.col("predicted_net_amount"))
    scored = scored.withColumn(
        "abs_pct_error",
        F.when(F.col("net_amount") != 0,
               F.abs(F.col("residual")) / F.abs(F.col("net_amount"))
        ).otherwise(0)
    )

    result = scored.select(
        "transaction_id", "store_id", "pc_category", "quantity", "price",
        "discount_pct", "is_weekend", "net_amount",
        "predicted_net_amount", "residual", "abs_pct_error"
    )

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["customer_features.result"]
    ],
    "data__sources": [
        {
            "node": "customer_features",
            "output_port": "result",
            "name": "customer_features",
            "df_name": "customer_features"
        }
    ]
}
out = run(config, inputs, spark)
ctx["ml_linear_regression.result"] = out["result"]

# %%
"""
id: rfm_aggregate
template: aggregate
templateVersion: 1.0.0
name: rfm_aggregate
position:
  x: 3120
  y: 0
description:
  text: Group data by customer group, name, and email, then compute summary metrics like last and first transaction dates, transaction count, total and average amount, average days between transactions, max customer decile, and minimum store region.
  hash: 073832ed
previewMode: "1000"
config:
  group_bys:
    - expr: customer_group_id
      type: expr
    - expr: customer_name
      type: expr
    - expr: email
      type: expr
  aggregations:
    - columnExpr:
        expr: txn_date_only
        type: expr
      fn: MAX
      alias: last_txn_date
    - columnExpr:
        expr: transaction_id
        type: expr
      fn: COUNT
      alias: frequency
    - columnExpr:
        expr: net_amount
        type: expr
      fn: SUM
      alias: monetary
    - columnExpr:
        expr: net_amount
        type: expr
      fn: AVG
      alias: avg_order_value
    - columnExpr:
        expr: txn_date_only
        type: expr
      fn: MIN
      alias: first_txn_date
    - columnExpr:
        expr: days_since_prior
        type: expr
      fn: AVG
      alias: avg_days_between_txns
    - columnExpr:
        expr: customer_decile
        type: expr
      fn: MAX
      alias: value_decile
    - columnExpr:
        expr: store_region
        type: expr
      fn: MIN
      alias: primary_region
input:
  - node: customer_features
    input_port: data
    output_port: result
"""

# generated from the system
import math
from typing import Dict, Any
import pyspark.sql.functions as F

# Default percentile (median). Used as a fallback when a PERCENTILE aggregation
# is missing or has a non-numeric / non-finite percentage. Mirrors
# DEFAULT_PERCENTILE_VALUE in AggregateNodeViewModel.ts so SQL and Python
# pipelines agree on the default.
DEFAULT_PERCENTILE = 0.5

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        # Skip pass-through columns that duplicate a group-by column;
        # groupBy() already includes them in the output.
        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum,
            "AVG": F.avg,
            "COUNT": F.count,
            "MIN": F.min,
            "MAX": F.max,
            "MEAN": F.mean,
            "MEDIAN": F.median,
            "STDDEV": F.stddev,
            "VARIANCE": F.variance,
        }

        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        elif fn == "PERCENTILE":
            # Spark PERCENTILE requires (col, percentage [, frequency]) with percentage
            # in [0, 1]; emitting PERCENTILE(col) triggers WRONG_NUM_ARGS at analysis
            # time. For finite numeric inputs we clamp to [0, 1] (mirroring the V1/V2
            # input clamps) so out-of-range values like -0.1 or 1.5 — typos or stale
            # frontend state — become a valid boundary instead of silently overriding
            # the user's intent with the median. Non-numeric, non-finite, boolean, or
            # missing values fall back to DEFAULT_PERCENTILE.
            raw_pct = agg_def.get("percentage")
            if (
                isinstance(raw_pct, (int, float))
                and not isinstance(raw_pct, bool)
                and math.isfinite(raw_pct)
            ):
                pct = max(0.0, min(1.0, float(raw_pct)))
            else:
                pct = DEFAULT_PERCENTILE
            col = F.expr(f"PERCENTILE({raw_expr}, {pct})")
        else:
            col = F.expr(f"{fn}({raw_expr})")

        if alias:
            col = col.alias(alias)

        agg_exprs.append(col)

    group_cols = [
        gb.get("expr", "") for gb in group_bys if gb.get("expr", "")
    ]

    if not agg_exprs:
        if group_cols:
            result = df.select(*group_cols).distinct()
            return {"aggregated_data": result}
        return {"aggregated_data": df}

    if group_cols:
        result = df.groupBy(*group_cols).agg(*agg_exprs)
    else:
        result = df.agg(*agg_exprs)

    return {"aggregated_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "customer_group_id",
            "type": "expr"
        },
        {
            "expr": "customer_name",
            "type": "expr"
        },
        {
            "expr": "email",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "txn_date_only",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "last_txn_date",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "transaction_id",
                "type": "expr"
            },
            "fn": "COUNT",
            "alias": "frequency",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "net_amount",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "monetary",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "net_amount",
                "type": "expr"
            },
            "fn": "AVG",
            "alias": "avg_order_value",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "txn_date_only",
                "type": "expr"
            },
            "fn": "MIN",
            "alias": "first_txn_date",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "days_since_prior",
                "type": "expr"
            },
            "fn": "AVG",
            "alias": "avg_days_between_txns",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "customer_decile",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "value_decile",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "store_region",
                "type": "expr"
            },
            "fn": "MIN",
            "alias": "primary_region",
            "withAsKeyword": None
        }
    ]
}
inputs = {
    "data": ctx["customer_features.result"]
}
out = run(config, inputs, spark)
ctx["rfm_aggregate.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: final_select_aggregate
template: transform
templateVersion: 1.0.0
name: final_select_aggregate
position:
  x: 3120
  y: 435
description:
  text: Rename and keep specific store, category, date, and sales related columns.
  hash: "23075552"
previewMode: "1000"
config:
  expressions:
    - store_id
    - store_region AS `region`
    - pc_category AS `category`
    - txn_year AS `year`
    - txn_month AS `month`
    - total_revenue AS `revenue`
    - avg_basket
    - stddev_basket
    - median_basket
    - unique_customers
    - txn_count
input:
  - node: aggregate_store_cat_month
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "store_id",
        "store_region AS `region`",
        "pc_category AS `category`",
        "txn_year AS `year`",
        "txn_month AS `month`",
        "total_revenue AS `revenue`",
        "avg_basket",
        "stddev_basket",
        "median_basket",
        "unique_customers",
        "txn_count"
    ]
}
inputs = {
    "data": ctx["aggregate_store_cat_month.result"]
}
out = run(config, inputs, spark)
ctx["final_select_aggregate.transformed_data"] = out["transformed_data"]

# %%
"""
id: pivot_by_month
template: pivot
templateVersion: 1.0.0
name: pivot_by_month
position:
  x: 3380
  y: 200
description:
  text: Aggregate total revenue by month, replacing missing values with zero, while excluding certain columns from the data.
  hash: 70cbb9fe
previewCodeHash: 964ef4099d63105e
previewMode: "1000"
config:
  mode: pivot
  pivot_column: txn_month
  value_column: total_revenue
  agg_fn: SUM
  null_behavior: zero
  unpivot_columns: []
  key_column_name: Column Name
  value_column_name: Value
  exclude_columns:
    - expr: txn_year
      type: column
    - expr: txn_count
      type: column
    - expr: unique_customers
      type: column
    - expr: avg_basket
      type: column
    - expr: stddev_basket
      type: column
    - expr: median_basket
      type: column
    - expr: total_units
      type: column
input:
  - node: aggregate_store_cat_month
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List, Optional, Set
import pyspark.sql.functions as F

AGG_FUNCTIONS = {
    "SUM": F.sum,
    "AVG": F.avg,
    "COUNT": F.count,
    "MIN": F.min,
    "MAX": F.max,
}

def _validate_columns_exist(df, columns: List[str], label: str) -> None:
    df_cols: Set[str] = set(df.columns)
    missing = [c for c in columns if c not in df_cols]
    if missing:
        raise ValueError(
            f"{label}: column(s) not found in input data: {missing}. "
            f"Available columns: {df.columns}"
        )

def _validate_aggregation(agg_fn: str) -> None:
    if agg_fn not in AGG_FUNCTIONS:
        raise ValueError(
            f"Unsupported aggregation '{agg_fn}'. "
            f"Choose one of: {list(AGG_FUNCTIONS.keys())}"
        )

def _validate_no_overlap(pivot_cols: List[str], fixed_cols: List[str]) -> None:
    overlap = set(pivot_cols) & set(fixed_cols)
    if overlap:
        raise ValueError(
            f"Column(s) {sorted(overlap)} appear in both pivot and fixed roles. "
            "A column cannot serve both roles."
        )

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    mode: str = config.get("mode", "pivot")
    exclude_cfg: List[Dict[str, str]] = config.get("exclude_columns", [])
    excluded: Set[str] = {c.get("expr", "") for c in exclude_cfg if c.get("expr")}

    if mode == "unpivot":
        unpivot_cols_cfg: List[Dict[str, str]] = config.get("unpivot_columns", [])
        key_col: str = config.get("key_column_name", "Column Name")
        value_col: str = config.get("value_column_name", "Value")

        unpivot_col_names = [c.get("expr", "") for c in unpivot_cols_cfg if c.get("expr")]
        if not unpivot_col_names:
            raise ValueError("At least one column must be selected for unpivoting.")

        _validate_columns_exist(df, unpivot_col_names, "Unpivot columns")
        if excluded:
            _validate_columns_exist(df, list(excluded), "Exclude columns")

        fixed_cols = [
            c for c in df.columns
            if c not in unpivot_col_names and c not in excluded
        ]
        _validate_no_overlap(unpivot_col_names, fixed_cols)

        n = len(unpivot_col_names)
        stack_parts = ", ".join(
            [f"'{col}', `{col}`" for col in unpivot_col_names]
        )
        stack_expr = (
            f"stack({n}, {stack_parts}) "
            f"as (`{key_col}`, `{value_col}`)"
        )
        result = df.select(
            *[F.col(c) for c in fixed_cols],
            F.expr(stack_expr),
        )
        return {"pivoted_data": result}

    # ── Pivot (Rows → Columns) ───────────────────────────────────────────
    pivot_column: str = config.get("pivot_column", "")
    value_column: str = config.get("value_column", "")
    agg_fn: str = config.get("agg_fn", "SUM")
    null_behavior: str = config.get("null_behavior", "null")

    if not pivot_column or not value_column:
        return {"pivoted_data": df}

    _validate_columns_exist(df, [pivot_column, value_column], "Pivot")
    if excluded:
        _validate_columns_exist(df, list(excluded), "Exclude columns")
    _validate_aggregation(agg_fn)

    fixed_cols = [
        c for c in df.columns
        if c not in (pivot_column, value_column) and c not in excluded
    ]
    agg_func = AGG_FUNCTIONS[agg_fn]

    result = (
        df
        .select(*fixed_cols, pivot_column, value_column)
        .groupBy(fixed_cols)
        .pivot(pivot_column)
        .agg(agg_func(F.col(value_column)))
    )
    if null_behavior == "zero":
        result = result.fillna(0)
    return {"pivoted_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "mode": "pivot",
    "pivot_column": "txn_month",
    "value_column": "total_revenue",
    "agg_fn": "SUM",
    "null_behavior": "zero",
    "unpivot_columns": [],
    "key_column_name": "Column Name",
    "value_column_name": "Value",
    "exclude_columns": [
        {
            "expr": "txn_year",
            "type": "column"
        },
        {
            "expr": "txn_count",
            "type": "column"
        },
        {
            "expr": "unique_customers",
            "type": "column"
        },
        {
            "expr": "avg_basket",
            "type": "column"
        },
        {
            "expr": "stddev_basket",
            "type": "column"
        },
        {
            "expr": "median_basket",
            "type": "column"
        },
        {
            "expr": "total_units",
            "type": "column"
        }
    ]
}
inputs = {
    "data": ctx["aggregate_store_cat_month.result"]
}
out = run(config, inputs, spark)
ctx["pivot_by_month.pivoted_data"] = out["pivoted_data"]

# %%
"""
id: calendar_fill
template: sql
templateVersion: 1.0.0
name: calendar_fill
position:
  x: 3380
  y: 780
description:
  text: Create a daily calendar and fill in missing dates with zero revenue and transactions.
  hash: aebfb492
previewMode: "1000"
config:
  query: |
    WITH calendar AS (
      SELECT EXPLODE(
        SEQUENCE(
          DATE('2024-01-01'),
          DATE('2026-12-31'),
          INTERVAL 1 DAY
        )
      ) AS cal_date
    )
    SELECT
      c.cal_date,
      COALESCE(d.daily_revenue, 0) AS daily_revenue,
      COALESCE(d.daily_txns, 0) AS daily_txns
    FROM calendar c
    LEFT JOIN daily_revenue_agg d
      ON c.cal_date = d.txn_date_only
    ORDER BY c.cal_date
input:
  - node: daily_revenue_agg
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "WITH calendar AS (\n  SELECT EXPLODE(\n    SEQUENCE(\n      DATE('2024-01-01'),\n      DATE('2026-12-31'),\n      INTERVAL 1 DAY\n    )\n  ) AS cal_date\n)\nSELECT\n  c.cal_date,\n  COALESCE(d.daily_revenue, 0) AS daily_revenue,\n  COALESCE(d.daily_txns, 0) AS daily_txns\nFROM calendar c\nLEFT JOIN daily_revenue_agg d\n  ON c.cal_date = d.txn_date_only\nORDER BY c.cal_date\n"
}
inputs = {
    "data": [
        ctx["daily_revenue_agg.aggregated_data"]
    ],
    "data__sources": [
        {
            "node": "daily_revenue_agg",
            "output_port": "aggregated_data",
            "name": "daily_revenue_agg",
            "df_name": "daily_revenue_agg"
        }
    ]
}
out = run(config, inputs, spark)
ctx["calendar_fill.result"] = out["result"]

# %%
"""
id: model_metrics
template: aggregate
templateVersion: 1.0.0
name: model_metrics
position:
  x: 3380
  y: 490
description:
  text: Calculate average, standard deviation, count, and max for specified columns without grouping.
  hash: 9024c748
previewMode: "1000"
config:
  group_bys: []
  aggregations:
    - columnExpr:
        expr: residual
        type: expr
      fn: AVG
      alias: ME
    - columnExpr:
        expr: residual
        type: expr
      fn: STDDEV
      alias: RMSE_proxy
    - columnExpr:
        expr: abs_pct_error
        type: expr
      fn: AVG
      alias: MAPE
    - columnExpr:
        expr: abs_pct_error
        type: expr
      fn: MAX
      alias: MaxAPE
    - columnExpr:
        expr: residual
        type: expr
      fn: COUNT
      alias: n_scored
input:
  - node: ml_linear_regression
    input_port: data
    output_port: result
"""

# generated from the system
import math
from typing import Dict, Any
import pyspark.sql.functions as F

# Default percentile (median). Used as a fallback when a PERCENTILE aggregation
# is missing or has a non-numeric / non-finite percentage. Mirrors
# DEFAULT_PERCENTILE_VALUE in AggregateNodeViewModel.ts so SQL and Python
# pipelines agree on the default.
DEFAULT_PERCENTILE = 0.5

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        # Skip pass-through columns that duplicate a group-by column;
        # groupBy() already includes them in the output.
        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum,
            "AVG": F.avg,
            "COUNT": F.count,
            "MIN": F.min,
            "MAX": F.max,
            "MEAN": F.mean,
            "MEDIAN": F.median,
            "STDDEV": F.stddev,
            "VARIANCE": F.variance,
        }

        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        elif fn == "PERCENTILE":
            # Spark PERCENTILE requires (col, percentage [, frequency]) with percentage
            # in [0, 1]; emitting PERCENTILE(col) triggers WRONG_NUM_ARGS at analysis
            # time. For finite numeric inputs we clamp to [0, 1] (mirroring the V1/V2
            # input clamps) so out-of-range values like -0.1 or 1.5 — typos or stale
            # frontend state — become a valid boundary instead of silently overriding
            # the user's intent with the median. Non-numeric, non-finite, boolean, or
            # missing values fall back to DEFAULT_PERCENTILE.
            raw_pct = agg_def.get("percentage")
            if (
                isinstance(raw_pct, (int, float))
                and not isinstance(raw_pct, bool)
                and math.isfinite(raw_pct)
            ):
                pct = max(0.0, min(1.0, float(raw_pct)))
            else:
                pct = DEFAULT_PERCENTILE
            col = F.expr(f"PERCENTILE({raw_expr}, {pct})")
        else:
            col = F.expr(f"{fn}({raw_expr})")

        if alias:
            col = col.alias(alias)

        agg_exprs.append(col)

    group_cols = [
        gb.get("expr", "") for gb in group_bys if gb.get("expr", "")
    ]

    if not agg_exprs:
        if group_cols:
            result = df.select(*group_cols).distinct()
            return {"aggregated_data": result}
        return {"aggregated_data": df}

    if group_cols:
        result = df.groupBy(*group_cols).agg(*agg_exprs)
    else:
        result = df.agg(*agg_exprs)

    return {"aggregated_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "residual",
                "type": "expr"
            },
            "fn": "AVG",
            "alias": "ME",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "residual",
                "type": "expr"
            },
            "fn": "STDDEV",
            "alias": "RMSE_proxy",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "abs_pct_error",
                "type": "expr"
            },
            "fn": "AVG",
            "alias": "MAPE",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "abs_pct_error",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "MaxAPE",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "residual",
                "type": "expr"
            },
            "fn": "COUNT",
            "alias": "n_scored",
            "withAsKeyword": None
        }
    ]
}
inputs = {
    "data": ctx["ml_linear_regression.result"]
}
out = run(config, inputs, spark)
ctx["model_metrics.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: output_ml_scored_table
template: output
templateVersion: 1.0.0
name: output_ml_scored_table
position:
  x: 3380
  y: 635
description:
  text: Save data as a table, replacing existing content.
  hash: 319fdf64
previewMode: "1000"
config:
  catalog: aldi_aus
  schema: demo
  table_name: retail_ml_scored
input:
  - node: ml_linear_regression
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "aldi_aus",
    "schema": "demo",
    "table_name": "retail_ml_scored"
}
inputs = {
    "data": ctx["ml_linear_regression.result"]
}
out = run(config, inputs, spark)

# %%
"""
id: write_ml_scored_csv
template: python
templateVersion: 1.0.0
name: write_ml_scored_csv
position:
  x: 3640
  y: 635
description:
  text: Save scored data to CSV file.
  hash: 5b05d503
previewMode: "1000"
config:
  code: |
    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_ml_scored.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df
input:
  - node: ml_linear_regression
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_ml_scored.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["ml_linear_regression.result"]
    ],
    "data__sources": [
        {
            "node": "ml_linear_regression",
            "output_port": "result",
            "name": "ml_linear_regression",
            "df_name": "ml_linear_regression"
        }
    ]
}
out = run(config, inputs, spark)
ctx["write_ml_scored_csv.result"] = out["result"]

# %%
"""
id: rfm_recency
template: transform
templateVersion: 1.0.0
name: rfm_recency
position:
  x: 3380
  y: 0
description:
  text: Calculate recency in days since last transaction.
  hash: 9c7b76b1
previewMode: "1000"
config:
  expressions:
    - "*"
    - DATEDIFF(current_date(), last_txn_date) AS `recency_days`
input:
  - node: rfm_aggregate
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "DATEDIFF(current_date(), last_txn_date) AS `recency_days`"
    ]
}
inputs = {
    "data": ctx["rfm_aggregate.aggregated_data"]
}
out = run(config, inputs, spark)
ctx["rfm_recency.transformed_data"] = out["transformed_data"]

# %%
"""
id: add_run_metadata
template: transform
templateVersion: 1.0.0
name: add_run_metadata
position:
  x: 3380
  y: 345
description:
  text: Add run metadata columns including run ID, run date, and pipeline version.
  hash: f4afc854
previewMode: "1000"
config:
  expressions:
    - "*"
    - "'aldi-adv-001' AS `run_id`"
    - CURRENT_DATE() AS `run_dt`
    - "'v2.0' AS `pipeline_version`"
input:
  - node: final_select_aggregate
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "'aldi-adv-001' AS `run_id`",
        "CURRENT_DATE() AS `run_dt`",
        "'v2.0' AS `pipeline_version`"
    ]
}
inputs = {
    "data": ctx["final_select_aggregate.transformed_data"]
}
out = run(config, inputs, spark)
ctx["add_run_metadata.transformed_data"] = out["transformed_data"]

# %%
"""
id: unpivot_to_long
template: pivot
templateVersion: 1.0.0
name: unpivot_to_long
position:
  x: 3640
  y: 200
description:
  text: Transform multiple columns representing monthly data into two columns for month number and revenue.
  hash: "79e60686"
previewCodeHash: c9d38422a503f6f7
previewMode: "1000"
config:
  mode: unpivot
  pivot_column: ""
  value_column: ""
  agg_fn: SUM
  null_behavior: "null"
  unpivot_columns:
    - expr: "1"
      type: column
    - expr: "2"
      type: column
    - expr: "3"
      type: column
    - expr: "4"
      type: column
    - expr: "5"
      type: column
    - expr: "6"
      type: column
    - expr: "7"
      type: column
    - expr: "8"
      type: column
    - expr: "9"
      type: column
    - expr: "10"
      type: column
    - expr: "11"
      type: column
    - expr: "12"
      type: column
  key_column_name: month_number
  value_column_name: monthly_revenue
  exclude_columns: []
input:
  - node: pivot_by_month
    input_port: data
    output_port: pivoted_data
"""

# generated from the system
from typing import Dict, Any, List, Optional, Set
import pyspark.sql.functions as F

AGG_FUNCTIONS = {
    "SUM": F.sum,
    "AVG": F.avg,
    "COUNT": F.count,
    "MIN": F.min,
    "MAX": F.max,
}

def _validate_columns_exist(df, columns: List[str], label: str) -> None:
    df_cols: Set[str] = set(df.columns)
    missing = [c for c in columns if c not in df_cols]
    if missing:
        raise ValueError(
            f"{label}: column(s) not found in input data: {missing}. "
            f"Available columns: {df.columns}"
        )

def _validate_aggregation(agg_fn: str) -> None:
    if agg_fn not in AGG_FUNCTIONS:
        raise ValueError(
            f"Unsupported aggregation '{agg_fn}'. "
            f"Choose one of: {list(AGG_FUNCTIONS.keys())}"
        )

def _validate_no_overlap(pivot_cols: List[str], fixed_cols: List[str]) -> None:
    overlap = set(pivot_cols) & set(fixed_cols)
    if overlap:
        raise ValueError(
            f"Column(s) {sorted(overlap)} appear in both pivot and fixed roles. "
            "A column cannot serve both roles."
        )

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    mode: str = config.get("mode", "pivot")
    exclude_cfg: List[Dict[str, str]] = config.get("exclude_columns", [])
    excluded: Set[str] = {c.get("expr", "") for c in exclude_cfg if c.get("expr")}

    if mode == "unpivot":
        unpivot_cols_cfg: List[Dict[str, str]] = config.get("unpivot_columns", [])
        key_col: str = config.get("key_column_name", "Column Name")
        value_col: str = config.get("value_column_name", "Value")

        unpivot_col_names = [c.get("expr", "") for c in unpivot_cols_cfg if c.get("expr")]
        if not unpivot_col_names:
            raise ValueError("At least one column must be selected for unpivoting.")

        _validate_columns_exist(df, unpivot_col_names, "Unpivot columns")
        if excluded:
            _validate_columns_exist(df, list(excluded), "Exclude columns")

        fixed_cols = [
            c for c in df.columns
            if c not in unpivot_col_names and c not in excluded
        ]
        _validate_no_overlap(unpivot_col_names, fixed_cols)

        n = len(unpivot_col_names)
        stack_parts = ", ".join(
            [f"'{col}', `{col}`" for col in unpivot_col_names]
        )
        stack_expr = (
            f"stack({n}, {stack_parts}) "
            f"as (`{key_col}`, `{value_col}`)"
        )
        result = df.select(
            *[F.col(c) for c in fixed_cols],
            F.expr(stack_expr),
        )
        return {"pivoted_data": result}

    # ── Pivot (Rows → Columns) ───────────────────────────────────────────
    pivot_column: str = config.get("pivot_column", "")
    value_column: str = config.get("value_column", "")
    agg_fn: str = config.get("agg_fn", "SUM")
    null_behavior: str = config.get("null_behavior", "null")

    if not pivot_column or not value_column:
        return {"pivoted_data": df}

    _validate_columns_exist(df, [pivot_column, value_column], "Pivot")
    if excluded:
        _validate_columns_exist(df, list(excluded), "Exclude columns")
    _validate_aggregation(agg_fn)

    fixed_cols = [
        c for c in df.columns
        if c not in (pivot_column, value_column) and c not in excluded
    ]
    agg_func = AGG_FUNCTIONS[agg_fn]

    result = (
        df
        .select(*fixed_cols, pivot_column, value_column)
        .groupBy(fixed_cols)
        .pivot(pivot_column)
        .agg(agg_func(F.col(value_column)))
    )
    if null_behavior == "zero":
        result = result.fillna(0)
    return {"pivoted_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "mode": "unpivot",
    "pivot_column": "",
    "value_column": "",
    "agg_fn": "SUM",
    "null_behavior": "null",
    "unpivot_columns": [
        {
            "expr": "1",
            "type": "column"
        },
        {
            "expr": "2",
            "type": "column"
        },
        {
            "expr": "3",
            "type": "column"
        },
        {
            "expr": "4",
            "type": "column"
        },
        {
            "expr": "5",
            "type": "column"
        },
        {
            "expr": "6",
            "type": "column"
        },
        {
            "expr": "7",
            "type": "column"
        },
        {
            "expr": "8",
            "type": "column"
        },
        {
            "expr": "9",
            "type": "column"
        },
        {
            "expr": "10",
            "type": "column"
        },
        {
            "expr": "11",
            "type": "column"
        },
        {
            "expr": "12",
            "type": "column"
        }
    ],
    "key_column_name": "month_number",
    "value_column_name": "monthly_revenue",
    "exclude_columns": []
}
inputs = {
    "data": ctx["pivot_by_month.pivoted_data"]
}
out = run(config, inputs, spark)
ctx["unpivot_to_long.pivoted_data"] = out["pivoted_data"]

# %%
"""
id: arima_forecast
template: python
templateVersion: 1.0.0
name: arima_forecast
position:
  x: 3640
  y: 780
description:
  text: Generate a 30-day forecast of daily revenue using ARIMA or moving average methods and combine with historical data.
  hash: 21acb8ab
previewMode: "1000"
config:
  code: |
    import pandas as pd
    import numpy as np
    from pyspark.sql import functions as F
    from pyspark.sql.types import StructType, StructField, DateType, DoubleType, StringType

    df = inputs["data"][0]
    pdf = df.toPandas()

    # Prepare time series data
    pdf['cal_date'] = pd.to_datetime(pdf['cal_date'])
    pdf = pdf.sort_values('cal_date').set_index('cal_date')
    ts = pdf['daily_revenue'].astype(float)

    # Fit ARIMA model (Alteryx: ARIMA forecast 30-day horizon)
    try:
        from statsmodels.tsa.arima.model import ARIMA
        # Use ARIMA(1,1,1) as default - simple but effective
        model = ARIMA(ts, order=(1, 1, 1))
        fitted = model.fit()
        forecast = fitted.forecast(steps=30)

        # Build forecast DataFrame
        last_date = pdf.index.max()
        forecast_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=30, freq='D')
        forecast_pdf = pd.DataFrame({
            'cal_date': forecast_dates,
            'daily_revenue': forecast.values,
            'daily_txns': [0] * 30,
            'forecast_type': ['forecast'] * 30
        })

        # Combine actuals + forecast
        actuals_pdf = pdf.reset_index()[['cal_date', 'daily_revenue', 'daily_txns']]
        actuals_pdf['forecast_type'] = 'actual'
        combined_pdf = pd.concat([actuals_pdf, forecast_pdf], ignore_index=True)

        result = spark.createDataFrame(combined_pdf)
    except Exception as e:
        # Fallback: simple moving average forecast if statsmodels unavailable
        ma_30 = ts.rolling(30).mean().iloc[-1] if len(ts) >= 30 else ts.mean()
        last_date = pdf.index.max()
        forecast_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=30, freq='D')
        forecast_pdf = pd.DataFrame({
            'cal_date': forecast_dates,
            'daily_revenue': [float(ma_30)] * 30,
            'daily_txns': [0] * 30,
            'forecast_type': ['forecast_ma30'] * 30
        })
        actuals_pdf = pdf.reset_index()[['cal_date', 'daily_revenue', 'daily_txns']]
        actuals_pdf['forecast_type'] = 'actual'
        combined_pdf = pd.concat([actuals_pdf, forecast_pdf], ignore_index=True)
        result = spark.createDataFrame(combined_pdf)
input:
  - node: calendar_fill
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    import pandas as pd
    import numpy as np
    from pyspark.sql import functions as F
    from pyspark.sql.types import StructType, StructField, DateType, DoubleType, StringType

    df = inputs["data"][0]
    pdf = df.toPandas()

    # Prepare time series data
    pdf['cal_date'] = pd.to_datetime(pdf['cal_date'])
    pdf = pdf.sort_values('cal_date').set_index('cal_date')
    ts = pdf['daily_revenue'].astype(float)

    # Fit ARIMA model (Alteryx: ARIMA forecast 30-day horizon)
    try:
        from statsmodels.tsa.arima.model import ARIMA
        # Use ARIMA(1,1,1) as default - simple but effective
        model = ARIMA(ts, order=(1, 1, 1))
        fitted = model.fit()
        forecast = fitted.forecast(steps=30)

        # Build forecast DataFrame
        last_date = pdf.index.max()
        forecast_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=30, freq='D')
        forecast_pdf = pd.DataFrame({
            'cal_date': forecast_dates,
            'daily_revenue': forecast.values,
            'daily_txns': [0] * 30,
            'forecast_type': ['forecast'] * 30
        })

        # Combine actuals + forecast
        actuals_pdf = pdf.reset_index()[['cal_date', 'daily_revenue', 'daily_txns']]
        actuals_pdf['forecast_type'] = 'actual'
        combined_pdf = pd.concat([actuals_pdf, forecast_pdf], ignore_index=True)

        result = spark.createDataFrame(combined_pdf)
    except Exception as e:
        # Fallback: simple moving average forecast if statsmodels unavailable
        ma_30 = ts.rolling(30).mean().iloc[-1] if len(ts) >= 30 else ts.mean()
        last_date = pdf.index.max()
        forecast_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=30, freq='D')
        forecast_pdf = pd.DataFrame({
            'cal_date': forecast_dates,
            'daily_revenue': [float(ma_30)] * 30,
            'daily_txns': [0] * 30,
            'forecast_type': ['forecast_ma30'] * 30
        })
        actuals_pdf = pdf.reset_index()[['cal_date', 'daily_revenue', 'daily_txns']]
        actuals_pdf['forecast_type'] = 'actual'
        combined_pdf = pd.concat([actuals_pdf, forecast_pdf], ignore_index=True)
        result = spark.createDataFrame(combined_pdf)

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["calendar_fill.result"]
    ],
    "data__sources": [
        {
            "node": "calendar_fill",
            "output_port": "result",
            "name": "calendar_fill",
            "df_name": "calendar_fill"
        }
    ]
}
out = run(config, inputs, spark)
ctx["arima_forecast.result"] = out["result"]

# %%
"""
id: rfm_scores
template: sql
templateVersion: 1.0.0
name: rfm_scores
position:
  x: 3640
  y: 0
description:
  text: Assign recency, frequency, and monetary scores by dividing data into 5 groups each.
  hash: 46e11b4c
previewMode: "1000"
config:
  query: |
    SELECT *,
      NTILE(5) OVER (ORDER BY recency_days) AS r_score,
      NTILE(5) OVER (ORDER BY frequency DESC) AS f_score,
      NTILE(5) OVER (ORDER BY monetary DESC) AS m_score
    FROM rfm_recency
input:
  - node: rfm_recency
    input_port: data
    output_port: transformed_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *,\n  NTILE(5) OVER (ORDER BY recency_days) AS r_score,\n  NTILE(5) OVER (ORDER BY frequency DESC) AS f_score,\n  NTILE(5) OVER (ORDER BY monetary DESC) AS m_score\nFROM rfm_recency\n"
}
inputs = {
    "data": [
        ctx["rfm_recency.transformed_data"]
    ],
    "data__sources": [
        {
            "node": "rfm_recency",
            "output_port": "transformed_data",
            "name": "rfm_recency",
            "df_name": "rfm_recency"
        }
    ]
}
out = run(config, inputs, spark)
ctx["rfm_scores.result"] = out["result"]

# %%
"""
id: limit_1000
template: limit
templateVersion: 1.0.0
name: limit_1000
position:
  x: 3640
  y: 345
description:
  text: Keep only the first 1000 rows.
  hash: c6e5e0f6
previewMode: "1000"
config:
  limit: "1000"
input:
  - node: add_run_metadata
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    n = int(config.get("limit", 1000))

    return {"limited_data": df.limit(n)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "limit": "1000"
}
inputs = {
    "data": ctx["add_run_metadata.transformed_data"]
}
out = run(config, inputs, spark)
ctx["limit_1000.limited_data"] = out["limited_data"]

# %%
"""
id: output_unpivot_table
template: output
templateVersion: 1.0.0
name: output_unpivot_table
position:
  x: 3900
  y: 200
description:
  text: Save data as a table named retail_monthly_pivot in aldi_aus.demo, replacing existing table if any.
  hash: 38b98854
previewMode: "1000"
config:
  catalog: aldi_aus
  schema: demo
  table_name: retail_monthly_pivot
input:
  - node: unpivot_to_long
    input_port: data
    output_port: pivoted_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "aldi_aus",
    "schema": "demo",
    "table_name": "retail_monthly_pivot"
}
inputs = {
    "data": ctx["unpivot_to_long.pivoted_data"]
}
out = run(config, inputs, spark)

# %%
"""
id: output_forecast_table
template: output
templateVersion: 1.0.0
name: output_forecast_table
position:
  x: 3900
  y: 780
description:
  text: Save data by replacing the table in the specified catalog and schema.
  hash: 62a23d5c
previewMode: "1000"
config:
  catalog: aldi_aus
  schema: demo
  table_name: retail_forecast_30d
input:
  - node: arima_forecast
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "aldi_aus",
    "schema": "demo",
    "table_name": "retail_forecast_30d"
}
inputs = {
    "data": ctx["arima_forecast.result"]
}
out = run(config, inputs, spark)

# %%
"""
id: write_forecast_csv
template: python
templateVersion: 1.0.0
name: write_forecast_csv
position:
  x: 4160
  y: 780
description:
  text: Save forecast data as CSV file.
  hash: e12dc407
previewMode: "1000"
config:
  code: |
    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_forecast_30d.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df
input:
  - node: arima_forecast
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_forecast_30d.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["arima_forecast.result"]
    ],
    "data__sources": [
        {
            "node": "arima_forecast",
            "output_port": "result",
            "name": "arima_forecast",
            "df_name": "arima_forecast"
        }
    ]
}
out = run(config, inputs, spark)
ctx["write_forecast_csv.result"] = out["result"]

# %%
"""
id: rfm_segment
template: transform
templateVersion: 1.0.0
name: rfm_segment
position:
  x: 3900
  y: 0
description:
  text: Add a customer segment based on r_score and f_score.
  hash: 15c3469c
previewCodeHash: 1d5e437911a3b8c0
previewMode: "1000"
config:
  expressions:
    - "*"
    - CASE WHEN r_score >= 4 AND f_score >= 4 THEN 'Champions' WHEN r_score >= 3 AND f_score >= 3 THEN 'Loyal' WHEN r_score >= 4 AND f_score <= 2 THEN 'New Customers' WHEN r_score <= 2 AND f_score >= 3 THEN 'At Risk' WHEN r_score <= 2 AND f_score <= 2 THEN 'Lost' ELSE 'Regular' END AS `segment`
input:
  - node: rfm_scores
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "CASE WHEN r_score >= 4 AND f_score >= 4 THEN 'Champions' WHEN r_score >= 3 AND f_score >= 3 THEN 'Loyal' WHEN r_score >= 4 AND f_score <= 2 THEN 'New Customers' WHEN r_score <= 2 AND f_score >= 3 THEN 'At Risk' WHEN r_score <= 2 AND f_score <= 2 THEN 'Lost' ELSE 'Regular' END AS `segment`"
    ]
}
inputs = {
    "data": ctx["rfm_scores.result"]
}
out = run(config, inputs, spark)
ctx["rfm_segment.transformed_data"] = out["transformed_data"]

# %%
"""
id: output_aggregate_table
template: output
templateVersion: 1.0.0
name: output_aggregate_table
position:
  x: 3900
  y: 345
description:
  text: Save data to the specified table, replacing existing content.
  hash: b792a474
previewMode: "1000"
config:
  catalog: aldi_aus
  schema: demo
  table_name: retail_advanced_aggregate
input:
  - node: limit_1000
    input_port: data
    output_port: limited_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "aldi_aus",
    "schema": "demo",
    "table_name": "retail_advanced_aggregate"
}
inputs = {
    "data": ctx["limit_1000.limited_data"]
}
out = run(config, inputs, spark)

# %%
"""
id: write_aggregate_csv
template: python
templateVersion: 1.0.0
name: write_aggregate_csv
position:
  x: 4160
  y: 345
description:
  text: Save data to a CSV file.
  hash: 6ff26eba
previewMode: "1000"
config:
  code: |
    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_advanced_aggregate.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df
input:
  - node: limit_1000
    input_port: data
    output_port: limited_data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_advanced_aggregate.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["limit_1000.limited_data"]
    ],
    "data__sources": [
        {
            "node": "limit_1000",
            "output_port": "limited_data",
            "name": "limit_1000",
            "df_name": "limit_1000"
        }
    ]
}
out = run(config, inputs, spark)
ctx["write_aggregate_csv.result"] = out["result"]

# %%
"""
id: customer_profile_summary
template: ai_function
templateVersion: 1.0.0
name: customer_profile_summary
position:
  x: 4160
  y: 0
description:
  text: Add a one-sentence customer profile summarizing segment, purchase frequency, monetary values, recency, and region.
  hash: 4b4c4d4f
previewMode: "1000"
config:
  expressions:
    - "ai_gen(CONCAT('Write a 1-sentence customer profile: ', customer_name, ' is a ', segment, ' segment customer with ', CAST(frequency AS STRING), ' purchases totaling $', CAST(ROUND(monetary, 2) AS STRING), ', averaging $', CAST(ROUND(avg_order_value, 2) AS STRING), ' per order, last active ', CAST(recency_days AS STRING), ' days ago in ', primary_region)) AS `customer_profile`"
input:
  - node: rfm_segment
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"ai_data": df}

    return {"ai_data": df.selectExpr(*expressions, "*")}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "ai_gen(CONCAT('Write a 1-sentence customer profile: ', customer_name, ' is a ', segment, ' segment customer with ', CAST(frequency AS STRING), ' purchases totaling $', CAST(ROUND(monetary, 2) AS STRING), ', averaging $', CAST(ROUND(avg_order_value, 2) AS STRING), ' per order, last active ', CAST(recency_days AS STRING), ' days ago in ', primary_region)) AS `customer_profile`"
    ]
}
inputs = {
    "data": ctx["rfm_segment.transformed_data"]
}
out = run(config, inputs, spark)
ctx["customer_profile_summary.ai_data"] = out["ai_data"]

# %%
"""
id: output_customer_360_table
template: output
templateVersion: 1.0.0
name: output_customer_360_table
position:
  x: 4420
  y: 0
description:
  text: Overwrite the table in specified catalog and schema with new data.
  hash: a9b47a94
previewMode: "1000"
config:
  catalog: aldi_aus
  schema: demo
  table_name: retail_customer_360
input:
  - node: customer_profile_summary
    input_port: data
    output_port: ai_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "aldi_aus",
    "schema": "demo",
    "table_name": "retail_customer_360"
}
inputs = {
    "data": ctx["customer_profile_summary.ai_data"]
}
out = run(config, inputs, spark)

# %%
"""
id: write_customer_360_csv
template: python
templateVersion: 1.0.0
name: write_customer_360_csv
position:
  x: 4420
  y: -145
description:
  text: Save customer profile data as CSV file.
  hash: 728ae9ba
previewMode: "1000"
config:
  code: |
    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_customer_360.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df
input:
  - node: customer_profile_summary
    input_port: data
    output_port: ai_data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    df = inputs["data"][0]
    out_path = "/Volumes/aldi_aus/demo/raw_test/output/output_customer_360.csv"
    df.toPandas().to_csv(out_path, index=False)
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["customer_profile_summary.ai_data"]
    ],
    "data__sources": [
        {
            "node": "customer_profile_summary",
            "output_port": "ai_data",
            "name": "customer_profile_summary",
            "df_name": "customer_profile_summary"
        }
    ]
}
out = run(config, inputs, spark)
ctx["write_customer_360_csv.result"] = out["result"]

# %% [markdown]
# ---
# id: pipeline_overview_note
# template: markdown
# name: pipeline_overview_note
# position:
#   x: 0
#   y: -300
# dimensions:
#   width: 550
#   height: 280
# config:
#   md: |
#     # RetailAnalyticsAdvancedML Pipeline
#     **Migrated from:** RetailAnalyticsAdvancedML.yxmd (61 Alteryx nodes, 8 containers)
#
#     ## Pipeline Branches
#     1. **Main Path** → Ingest → Cleanse → Parse → Join → Enrich → Dedup → Features
#     2. **Aggregation** → Store/Category/Month rollup → Pivot/Unpivot → Output
#     3. **ML** → 10% sample → Linear Regression → Score → Residuals
#     4. **Time Series** → Daily revenue → Calendar fill → ARIMA 30-day forecast
#     5. **Customer 360** → RFM Segmentation → Segment assignment
#     6. **Geospatial** → Store coordinates → Trade areas
#
#     ## Outputs
#     - `aldi_aus.demo.retail_advanced_aggregate` + CSV
#     - `aldi_aus.demo.retail_ml_scored` + CSV
#     - `aldi_aus.demo.retail_forecast_30d` + CSV
#     - `aldi_aus.demo.retail_customer_360` + CSV
#     - `aldi_aus.demo.retail_geospatial` + CSV
#     - `aldi_aus.demo.retail_monthly_pivot`
# ---

# %% [markdown]
# ---
# id: manual_steps_note
# template: markdown
# name: manual_steps_note
# position:
#   x: 600
#   y: -300
# dimensions:
#   width: 450
#   height: 250
# config:
#   md: |
#     # Manual Steps / Limitations
#
#     **Alteryx tools with no direct equivalent (simplified):**
#     - **Fuzzy Match** → Transform (SOUNDEX + REGEXP_EXTRACT) + SQL (DENSE_RANK window)
#     - **Geospatial** (Buffer, Find Nearest) → Transform (CASE WHEN coords) + SQL (DISTINCT + ROW_NUMBER)
#     - **Customer Segmentation Macro** → Aggregate + Transform + SQL (NTILE) + Transform (segment CASE WHEN)
#     - **ARIMA** → statsmodels with MA30 fallback (Python required)
#     - **TS Plot** → Use Lakeview dashboard on forecast table
#     - **Test/Message/Cache/Block** → Omitted (Spark DAG handles execution order)
#     - **Append Fields** → Replaced with Transform adding literal metadata columns
# ---
