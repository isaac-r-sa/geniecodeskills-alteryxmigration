# %%
"""
id: source_products
template: source
templateVersion: 1.0.0
name: source_products
position:
  x: 600
  y: 155
description:
  text: Read data from a CSV file with headers and automatically detect schema.
  hash: 22f042dd
previewCodeHash: 90dbaaa327195f6b
previewMode: "1000"
config:
  file_source:
    path: /Volumes/aldi_aus/demo/raw_test/product_catalog.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/aldi_aus/demo/raw_test/product_catalog.csv",
        "format": "csv",
        "header": True,
        "inferSchema": True
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_products.data"] = out["data"]

# %%
"""
id: source_stores
template: source
templateVersion: 1.0.0
name: source_stores
position:
  x: 1500
  y: 232.5
description:
  text: Load data from a CSV file with header and schema inference.
  hash: 58f44f54
previewCodeHash: b2857a1f0fde10d4
previewMode: "1000"
config:
  file_source:
    path: /Volumes/aldi_aus/demo/raw_test/stores.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/aldi_aus/demo/raw_test/stores.csv",
        "format": "csv",
        "header": True,
        "inferSchema": True
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_stores.data"] = out["data"]

# %%
"""
id: source_transactions
template: source
templateVersion: 1.0.0
name: source_transactions
position:
  x: 0
  y: 0
description:
  text: Read a CSV file with headers and schema inference from the given path.
  hash: f46dc4b7
previewCodeHash: cfed9af8a5f08ba7
previewMode: "1000"
config:
  file_source:
    path: /Volumes/aldi_aus/demo/raw_test/transactions.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/aldi_aus/demo/raw_test/transactions.csv",
        "format": "csv",
        "header": True,
        "inferSchema": True
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_transactions.data"] = out["data"]

# %%
"""
id: filter_recent_positive
template: filter
templateVersion: 1.0.0
name: filter_recent_positive
position:
  x: 300
  y: 0
description:
  text: Keep transactions with quantity above zero from the last 24 months.
  hash: d0ffb263
previewCodeHash: ed893ef9be14c01f
previewMode: "1000"
config:
  condition: quantity > 0 AND transaction_date >= add_months(current_date(), -24)
input:
  - node: source_transactions
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")

    if not condition:
        return {"filtered_data": df}

    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "quantity > 0 AND transaction_date >= add_months(current_date(), -24)"
}
inputs = {
    "data": ctx["source_transactions.data"]
}
out = run(config, inputs, spark)
ctx["filter_recent_positive.filtered_data"] = out["filtered_data"]

# %%
"""
id: parse_and_derive
template: transform
templateVersion: 1.0.0
name: parse_and_derive
position:
  x: 600
  y: 0
description:
  text: Clean and extract features from transaction data including dates, payment method, product codes, and customer names.
  hash: 68ec0ecb
previewCodeHash: 7553cf3216f5be5b
previewMode: "1000"
config:
  expressions:
    - transaction_id
    - customer_id
    - customer_name
    - product_id
    - product_code
    - store_id
    - store_region
    - transaction_date
    - quantity
    - unit_price
    - discount_pct
    - UPPER(TRIM(payment_method)) AS `payment_method_clean`
    - email
    - transaction_date AS `txn_date_parsed`
    - quantity * unit_price * (1 - discount_pct) AS `net_amount`
    - YEAR(transaction_date) AS `txn_year`
    - MONTH(transaction_date) AS `txn_month`
    - DATE_FORMAT(transaction_date, 'EEEE') AS `txn_weekday`
    - CASE WHEN dayofweek(transaction_date) IN (1, 7) THEN 1 ELSE 0 END AS `is_weekend`
    - regexp_extract(product_code, '^([A-Za-z]{2,4})-', 1) AS `pc_category`
    - regexp_extract(product_code, '-([0-9]{3,5})-', 1) AS `pc_sku`
    - regexp_extract(product_code, '-([A-Za-z0-9]{2,4})$', 1) AS `pc_variant`
    - TRIM(split(customer_name, ',')[0]) AS `cust_last_name`
    - TRIM(split(customer_name, ',')[1]) AS `cust_first_name`
input:
  - node: filter_recent_positive
    input_port: data
    output_port: filtered_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "transaction_id",
        "customer_id",
        "customer_name",
        "product_id",
        "product_code",
        "store_id",
        "store_region",
        "transaction_date",
        "quantity",
        "unit_price",
        "discount_pct",
        "UPPER(TRIM(payment_method)) AS `payment_method_clean`",
        "email",
        "transaction_date AS `txn_date_parsed`",
        "quantity * unit_price * (1 - discount_pct) AS `net_amount`",
        "YEAR(transaction_date) AS `txn_year`",
        "MONTH(transaction_date) AS `txn_month`",
        "DATE_FORMAT(transaction_date, 'EEEE') AS `txn_weekday`",
        "CASE WHEN dayofweek(transaction_date) IN (1, 7) THEN 1 ELSE 0 END AS `is_weekend`",
        "regexp_extract(product_code, '^([A-Za-z]{2,4})-', 1) AS `pc_category`",
        "regexp_extract(product_code, '-([0-9]{3,5})-', 1) AS `pc_sku`",
        "regexp_extract(product_code, '-([A-Za-z0-9]{2,4})$', 1) AS `pc_variant`",
        "TRIM(split(customer_name, ',')[0]) AS `cust_last_name`",
        "TRIM(split(customer_name, ',')[1]) AS `cust_first_name`"
    ]
}
inputs = {
    "data": ctx["filter_recent_positive.filtered_data"]
}
out = run(config, inputs, spark)
ctx["parse_and_derive.transformed_data"] = out["transformed_data"]

# %%
"""
id: join_products
template: join
templateVersion: 1.0.0
name: join_products
position:
  x: 900
  y: 77.5
description:
  text: Perform a left join on product_id and keep selected columns from both tables.
  hash: 60183a24
previewCodeHash: c8d553d2cac9d8a3
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.product_id = right.product_id
  expressions:
    - "`left`.transaction_id"
    - "`left`.customer_id"
    - "`left`.customer_name"
    - "`left`.product_id"
    - "`left`.product_code"
    - "`left`.store_id"
    - "`left`.store_region"
    - "`left`.transaction_date"
    - "`left`.quantity"
    - "`left`.unit_price"
    - "`left`.discount_pct"
    - "`left`.payment_method_clean"
    - "`left`.email"
    - "`left`.txn_date_parsed"
    - "`left`.net_amount"
    - "`left`.txn_year"
    - "`left`.txn_month"
    - "`left`.txn_weekday"
    - "`left`.is_weekend"
    - "`left`.pc_category"
    - "`left`.pc_sku"
    - "`left`.pc_variant"
    - "`left`.cust_last_name"
    - "`left`.cust_first_name"
    - "`right`.product_name"
    - "`right`.list_price"
    - "`right`.supplier_id"
input:
  - node: parse_and_derive
    input_port: left
    output_port: transformed_data
  - node: source_products
    input_port: right
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.product_id = right.product_id",
    "expressions": [
        "`left`.transaction_id",
        "`left`.customer_id",
        "`left`.customer_name",
        "`left`.product_id",
        "`left`.product_code",
        "`left`.store_id",
        "`left`.store_region",
        "`left`.transaction_date",
        "`left`.quantity",
        "`left`.unit_price",
        "`left`.discount_pct",
        "`left`.payment_method_clean",
        "`left`.email",
        "`left`.txn_date_parsed",
        "`left`.net_amount",
        "`left`.txn_year",
        "`left`.txn_month",
        "`left`.txn_weekday",
        "`left`.is_weekend",
        "`left`.pc_category",
        "`left`.pc_sku",
        "`left`.pc_variant",
        "`left`.cust_last_name",
        "`left`.cust_first_name",
        "`right`.product_name",
        "`right`.list_price",
        "`right`.supplier_id"
    ]
}
inputs = {
    "left": ctx["parse_and_derive.transformed_data"],
    "right": ctx["source_products.data"]
}
out = run(config, inputs, spark)
ctx["join_products.joined_data"] = out["joined_data"]

# %%
"""
id: standardize_and_impute
template: transform
templateVersion: 1.0.0
name: standardize_and_impute
position:
  x: 1200
  y: 77.5
description:
  text: Standardize product names, fill missing prices, add currency and exchange rate columns.
  hash: 05f8f9d6
previewCodeHash: e1db93b0f0e12b3c
previewMode: "1000"
config:
  expressions:
    - "*"
    - CASE WHEN product_name = 'Cola 1L' THEN 'Cola - 1 Liter' WHEN product_name = 'Choc Bar' THEN 'Chocolate Bar 100g' WHEN product_name = 'Bread Wht' THEN 'White Bread Loaf' WHEN product_name = 'Milk2pc' THEN 'Milk 2% 2L' ELSE product_name END AS `product_name_std`
    - COALESCE(unit_price, list_price) AS `unit_price_imputed`
    - "'AUD' AS `base_currency`"
    - 0.62 AS `fx_rate_aud_to_eur`
input:
  - node: join_products
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "CASE WHEN product_name = 'Cola 1L' THEN 'Cola - 1 Liter' WHEN product_name = 'Choc Bar' THEN 'Chocolate Bar 100g' WHEN product_name = 'Bread Wht' THEN 'White Bread Loaf' WHEN product_name = 'Milk2pc' THEN 'Milk 2% 2L' ELSE product_name END AS `product_name_std`",
        "COALESCE(unit_price, list_price) AS `unit_price_imputed`",
        "'AUD' AS `base_currency`",
        "0.62 AS `fx_rate_aud_to_eur`"
    ]
}
inputs = {
    "data": ctx["join_products.joined_data"]
}
out = run(config, inputs, spark)
ctx["standardize_and_impute.transformed_data"] = out["transformed_data"]

# %%
"""
id: window_dedupe_decile
template: sql
templateVersion: 1.0.0
name: window_dedupe_decile
position:
  x: 1500
  y: 77.5
description:
  text: Calculate running total per customer, remove duplicate transactions, and assign customers into deciles based on their running total.
  hash: 99eb6e8b
previewCodeHash: da65cd9402de03d3
previewMode: "1000"
config:
  query: |-
    WITH with_running AS (
      SELECT
        *,
        SUM(net_amount) OVER (
          PARTITION BY customer_id
          ORDER BY txn_date_parsed
          ROWS UNBOUNDED PRECEDING
        ) AS cust_running_total
      FROM standardize_and_impute
    ),
    deduped AS (
      SELECT *
      FROM (
        SELECT
          *,
          ROW_NUMBER() OVER (PARTITION BY transaction_id ORDER BY txn_date_parsed) AS rn
        FROM with_running
      )
      WHERE rn = 1
    )
    SELECT
      *,
      NTILE(10) OVER (ORDER BY cust_running_total DESC) AS customer_decile
    FROM deduped
input:
  - node: standardize_and_impute
    input_port: data
    output_port: transformed_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "WITH with_running AS (\n  SELECT\n    *,\n    SUM(net_amount) OVER (\n      PARTITION BY customer_id\n      ORDER BY txn_date_parsed\n      ROWS UNBOUNDED PRECEDING\n    ) AS cust_running_total\n  FROM standardize_and_impute\n),\ndeduped AS (\n  SELECT *\n  FROM (\n    SELECT\n      *,\n      ROW_NUMBER() OVER (PARTITION BY transaction_id ORDER BY txn_date_parsed) AS rn\n    FROM with_running\n  )\n  WHERE rn = 1\n)\nSELECT\n  *,\n  NTILE(10) OVER (ORDER BY cust_running_total DESC) AS customer_decile\nFROM deduped"
}
inputs = {
    "data": [
        ctx["standardize_and_impute.transformed_data"]
    ],
    "data__sources": [
        {
            "node": "standardize_and_impute",
            "output_port": "transformed_data",
            "name": "standardize_and_impute",
            "df_name": "standardize_and_impute"
        }
    ]
}
out = run(config, inputs, spark)
ctx["window_dedupe_decile.result"] = out["result"]

# %%
"""
id: join_stores
template: join
templateVersion: 1.0.0
name: join_stores
position:
  x: 1800
  y: 155
description:
  text: Left join on store_id and keep all left and selected right columns.
  hash: 3d3ef3e7
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.store_id = right.store_id
  expressions:
    - left.*
    - "`right`.store_name"
    - "`right`.store_size_sqm"
    - "`right`.opened_year"
input:
  - node: window_dedupe_decile
    input_port: left
    output_port: result
  - node: source_stores
    input_port: right
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.store_id = right.store_id",
    "expressions": [
        "left.*",
        "`right`.store_name",
        "`right`.store_size_sqm",
        "`right`.opened_year"
    ]
}
inputs = {
    "left": ctx["window_dedupe_decile.result"],
    "right": ctx["source_stores.data"]
}
out = run(config, inputs, spark)
ctx["join_stores.joined_data"] = out["joined_data"]

# %%
"""
id: add_running_store_sales
template: sql
templateVersion: 1.0.0
name: add_running_store_sales
position:
  x: 2100
  y: 155
description:
  text: Calculate running total of net sales for each store ordered by transaction date.
  hash: e440672d
previewCodeHash: f28055f736ce16fc
previewMode: "1000"
config:
  query: |-
    SELECT
      *,
      SUM(net_amount) OVER (
        PARTITION BY store_id
        ORDER BY txn_date_parsed
        ROWS UNBOUNDED PRECEDING
      ) AS running_store_sales
    FROM join_stores
input:
  - node: join_stores
    input_port: data
    output_port: joined_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT\n  *,\n  SUM(net_amount) OVER (\n    PARTITION BY store_id\n    ORDER BY txn_date_parsed\n    ROWS UNBOUNDED PRECEDING\n  ) AS running_store_sales\nFROM join_stores"
}
inputs = {
    "data": [
        ctx["join_stores.joined_data"]
    ],
    "data__sources": [
        {
            "node": "join_stores",
            "output_port": "joined_data",
            "name": "join_stores",
            "df_name": "join_stores"
        }
    ]
}
out = run(config, inputs, spark)
ctx["add_running_store_sales.result"] = out["result"]

# %%
"""
id: aggregate_store_cat_month
template: sql
templateVersion: 1.0.0
name: aggregate_store_cat_month
position:
  x: 2400
  y: 155
description:
  text: Summarize sales data by store, region, product category, year, and month, showing counts, unique customers, total and average revenue, min and max sales, and total units sold.
  hash: ae0823df
previewCodeHash: ea516781e21d487e
previewMode: "1000"
config:
  query: |-
    SELECT
      store_id,
      store_region,
      pc_category,
      txn_year,
      txn_month,
      COUNT(transaction_id) AS txn_count,
      COUNT(DISTINCT customer_id) AS unique_customers,
      SUM(net_amount) AS total_revenue,
      AVG(net_amount) AS avg_basket,
      MIN(net_amount) AS min_amount,
      MAX(net_amount) AS max_amount,
      SUM(quantity) AS total_units
    FROM add_running_store_sales
    GROUP BY
      store_id,
      store_region,
      pc_category,
      txn_year,
      txn_month
input:
  - node: add_running_store_sales
    input_port: data
    output_port: result
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT\n  store_id,\n  store_region,\n  pc_category,\n  txn_year,\n  txn_month,\n  COUNT(transaction_id) AS txn_count,\n  COUNT(DISTINCT customer_id) AS unique_customers,\n  SUM(net_amount) AS total_revenue,\n  AVG(net_amount) AS avg_basket,\n  MIN(net_amount) AS min_amount,\n  MAX(net_amount) AS max_amount,\n  SUM(quantity) AS total_units\nFROM add_running_store_sales\nGROUP BY\n  store_id,\n  store_region,\n  pc_category,\n  txn_year,\n  txn_month"
}
inputs = {
    "data": [
        ctx["add_running_store_sales.result"]
    ],
    "data__sources": [
        {
            "node": "add_running_store_sales",
            "output_port": "result",
            "name": "add_running_store_sales",
            "df_name": "add_running_store_sales"
        }
    ]
}
out = run(config, inputs, spark)
ctx["aggregate_store_cat_month.result"] = out["result"]

# %%
"""
id: output_enriched_table
template: output
templateVersion: 1.0.0
name: output_enriched_table
position:
  x: 2400
  y: 0
description:
  text: Replace the table with new data.
  hash: 277a6613
previewMode: "1000"
config:
  catalog: aldi_aus
  schema: demo
  table_name: retail_enriched_transactions
input:
  - node: add_running_store_sales
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "aldi_aus",
    "schema": "demo",
    "table_name": "retail_enriched_transactions"
}
inputs = {
    "data": ctx["add_running_store_sales.result"]
}
out = run(config, inputs, spark)

# %%
"""
id: write_enriched_csv
template: python
templateVersion: 1.0.0
name: write_enriched_csv
position:
  x: 2400
  y: 310
description:
  text: Save enriched transactions as a CSV file in the output folder.
  hash: 415aa7fe
previewMode: "1000"
config:
  code: |-
    # Write enriched transactions to CSV in the output volume folder
    import os
    df = inputs["data"][0]
    output_dir = "/Volumes/aldi_aus/demo/raw_test/output"
    os.makedirs(output_dir, exist_ok=True)
    output_path = f"{output_dir}/retail_enriched_transactions.csv"
    df.toPandas().to_csv(output_path, index=False)
    result = df
input:
  - node: add_running_store_sales
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # Write enriched transactions to CSV in the output volume folder
    import os
    df = inputs["data"][0]
    output_dir = "/Volumes/aldi_aus/demo/raw_test/output"
    os.makedirs(output_dir, exist_ok=True)
    output_path = f"{output_dir}/retail_enriched_transactions.csv"
    df.toPandas().to_csv(output_path, index=False)
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["add_running_store_sales.result"]
    ],
    "data__sources": [
        {
            "node": "add_running_store_sales",
            "output_port": "result",
            "name": "add_running_store_sales",
            "df_name": "add_running_store_sales"
        }
    ]
}
out = run(config, inputs, spark)
ctx["write_enriched_csv.result"] = out["result"]

# %%
"""
id: limit_1000
template: limit
templateVersion: 1.0.0
name: limit_1000
position:
  x: 2700
  y: 155
description:
  text: Keep only the first 1000 rows.
  hash: bff28731
previewCodeHash: 213bb8d1e9bfab27
previewMode: "1000"
config:
  limit: "1000"
input:
  - node: aggregate_store_cat_month
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    n = int(config.get("limit", 1000))

    return {"limited_data": df.limit(n)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "limit": "1000"
}
inputs = {
    "data": ctx["aggregate_store_cat_month.result"]
}
out = run(config, inputs, spark)
ctx["limit_1000.limited_data"] = out["limited_data"]

# %%
"""
id: final_select
template: transform
templateVersion: 1.0.0
name: final_select
position:
  x: 3000
  y: 155
description:
  text: Select and rename specific columns for focus on store and transaction details.
  hash: 8a899894
previewCodeHash: 8d011a7dd1a882e3
previewMode: "1000"
config:
  expressions:
    - store_id
    - store_region AS `region`
    - pc_category AS `category`
    - txn_year AS `year`
    - txn_month AS `month`
    - total_revenue AS `revenue`
    - avg_basket AS `avg_basket_value`
    - unique_customers
    - txn_count
input:
  - node: limit_1000
    input_port: data
    output_port: limited_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "store_id",
        "store_region AS `region`",
        "pc_category AS `category`",
        "txn_year AS `year`",
        "txn_month AS `month`",
        "total_revenue AS `revenue`",
        "avg_basket AS `avg_basket_value`",
        "unique_customers",
        "txn_count"
    ]
}
inputs = {
    "data": ctx["limit_1000.limited_data"]
}
out = run(config, inputs, spark)
ctx["final_select.transformed_data"] = out["transformed_data"]

# %%
"""
id: output_summary_table
template: output
templateVersion: 1.0.0
name: output_summary_table
position:
  x: 3300
  y: 77.5
description:
  text: Save data by replacing the specified table.
  hash: 78a830ec
previewMode: "1000"
config:
  catalog: aldi_aus
  schema: demo
  table_name: retail_store_category_monthly
input:
  - node: final_select
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "aldi_aus",
    "schema": "demo",
    "table_name": "retail_store_category_monthly"
}
inputs = {
    "data": ctx["final_select.transformed_data"]
}
out = run(config, inputs, spark)

# %%
"""
id: write_summary_csv
template: python
templateVersion: 1.0.0
name: write_summary_csv
position:
  x: 3300
  y: 232.5
description:
  text: Save data as a CSV file to a specific folder.
  hash: b2d3883d
previewMode: "1000"
config:
  code: |-
    # Write the aggregated summary to CSV in the output volume folder
    import os
    df = inputs["data"][0]
    output_dir = "/Volumes/aldi_aus/demo/raw_test/output"
    os.makedirs(output_dir, exist_ok=True)
    output_path = f"{output_dir}/retail_store_category_monthly.csv"
    df.toPandas().to_csv(output_path, index=False)
    result = df
input:
  - node: final_select
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # Write the aggregated summary to CSV in the output volume folder
    import os
    df = inputs["data"][0]
    output_dir = "/Volumes/aldi_aus/demo/raw_test/output"
    os.makedirs(output_dir, exist_ok=True)
    output_path = f"{output_dir}/retail_store_category_monthly.csv"
    df.toPandas().to_csv(output_path, index=False)
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["final_select.transformed_data"]
    ],
    "data__sources": [
        {
            "node": "final_select",
            "output_port": "transformed_data",
            "name": "final_select",
            "df_name": "final_select"
        }
    ]
}
out = run(config, inputs, spark)
ctx["write_summary_csv.result"] = out["result"]
