# %% [markdown]
# ---
# id: pipeline_header
# template: markdown
# name: MAIN FyForecastCapacityFlow_EDLAP
# position:
#   x: 0
#   y: -260
# dimensions:
#   width: 700
#   height: 220
# config:
#   md: |
#     # MAIN FyForecastCapacityFlow_EDLAP
#
#     **Converted from `MAIN FyForecastCapacityFlow_EDLAP.tflx`** by `convert_tflx.py` (tableau-to-lakeflow-designer skill).
#
#     - 90 nodes in the original Tableau Prep flow
#     - Output table: `main.default.fy_forecast_capacity_flow_output`
# ---

# %%
"""
id: sourcing_timeline
template: source
name: sourcing_timeline
position:
  x: 0
  y: 0
description:
  text: "Sourcing Timeline"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/sourcing_timeline.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/sourcing_timeline.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["sourcing_timeline.data"] = out["data"]

# %%
"""
id: division
template: source
name: division
position:
  x: 0
  y: 145
description:
  text: "Division"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/division.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/division.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["division.data"] = out["data"]

# %%
"""
id: ahead_to_cbis_code
template: source
name: ahead_to_cbis_code
position:
  x: 0
  y: 290
description:
  text: "Ahead to CBIS Code"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/ahead_to_cbis_code.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/ahead_to_cbis_code.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["ahead_to_cbis_code.data"] = out["data"]

# %%
"""
id: supplier
template: source
name: supplier
position:
  x: 0
  y: 435
description:
  text: "Supplier"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/supplier.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/supplier.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["supplier.data"] = out["data"]

# %%
"""
id: product
template: source
name: product
position:
  x: 0
  y: 580
description:
  text: "Product"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/product.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/product.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["product.data"] = out["data"]

# %%
"""
id: contract
template: source
name: contract
position:
  x: 0
  y: 725
description:
  text: "Contract"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/contract.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/contract.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["contract.data"] = out["data"]

# %%
"""
id: 2025_items_1
template: source
name: 2025_items_1
position:
  x: 0
  y: 870
description:
  text: "2025 Items (1)"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/2025_items_1.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/2025_items_1.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["2025_items_1.data"] = out["data"]

# %%
"""
id: custom_sql
template: source
name: custom_sql
position:
  x: 0
  y: 1015
description:
  text: "Custom SQL"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/custom_sql.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/custom_sql.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["custom_sql.data"] = out["data"]

# %%
"""
id: fyforecast
template: source
name: fyforecast
position:
  x: 0
  y: 1160
description:
  text: "fyForecast"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/fyforecast.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/fyforecast.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["fyforecast.data"] = out["data"]

# %%
"""
id: apt
template: source
name: apt
position:
  x: 0
  y: 1305
description:
  text: "APT"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/apt.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/Users/daphne.koch@databricks.com/tableau dashboard/extracted_data/synthetic/apt.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["apt.data"] = out["data"]

# %%
"""
id: clean_9
template: transform
name: clean_9
position:
  x: 260
  y: 0
description:
  text: "Clean 9"
previewMode: "1000"
config:
  expressions:
  - "* EXCEPT (`Description`, `CG`, `SCG`)"
input:
  - node: sourcing_timeline
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT (`Description`, `CG`, `SCG`)"
    ]
}
inputs = {
    "data": ctx["sourcing_timeline.data"],
}
out = run(config, inputs, spark)
ctx["clean_9.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_1_1
template: sql
name: clean_1_1
position:
  x: 260
  y: 145
description:
  text: "Clean 1 (1)"
previewMode: "1000"
config:
  query: "SELECT *, 1 AS `count`, `Item  Code` AS `Item code 2` FROM 2025_items_1 WHERE NOT ISNULL(`Item  Code`)"
input:
  - node: 2025_items_1
    input_port: data
    output_port: data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *, 1 AS `count`, `Item  Code` AS `Item code 2` FROM 2025_items_1 WHERE NOT ISNULL(`Item  Code`)"
}
inputs = {
    "data": [
        ctx["2025_items_1.data"],
    ],
    "data__sources": [
        {"node": "2025_items_1", "output_port": "data", "name": "2025_items_1", "df_name": "2025_items_1"},
    ],
}
out = run(config, inputs, spark)
ctx["clean_1_1.result"] = out["result"]

# %%
"""
id: clean_24
template: transform
name: clean_24
position:
  x: 260
  y: 290
description:
  text: "Clean 24"
previewMode: "1000"
config:
  expressions:
  - "* EXCEPT (`adf_insert_date`, `adf_insert_timestamp`, `adf_update_timestamp`, `rowhash`, `capacity_year_2025`, `capacity_year_2026`)"
  - `supplier_id` AS `Supplier_id`
  - `supplier_name` AS `Supplier_name`
  - `sku_id` AS `SKU_ID`
  - `sku_description` AS `SKU_Description`
  - `cg` AS `CG`
  - `scg` AS `SCG`
  - `capacity_year_2027` AS `Capacity Year_2027`
  - `capacity_year_2028` AS `Capacity Year_2028`
  - `capacity_year_2029` AS `Capacity Year_2029`
  - `capacity_year_2030` AS `Capacity Year_2030`
  - `capacity_year_2031` AS `Capacity Year_2031`
  - CAST(`Capacity Year_2027` AS INT) AS `Capacity Year_2027`
  - CAST(`Capacity Year_2028` AS INT) AS `Capacity Year_2028`
  - CAST(`Capacity Year_2029` AS INT) AS `Capacity Year_2029`
  - CAST(`Capacity Year_2030` AS INT) AS `Capacity Year_2030`
  - CAST(`Capacity Year_2031` AS INT) AS `Capacity Year_2031`
input:
  - node: custom_sql
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT (`adf_insert_date`, `adf_insert_timestamp`, `adf_update_timestamp`, `rowhash`, `capacity_year_2025`, `capacity_year_2026`)",
        "`supplier_id` AS `Supplier_id`",
        "`supplier_name` AS `Supplier_name`",
        "`sku_id` AS `SKU_ID`",
        "`sku_description` AS `SKU_Description`",
        "`cg` AS `CG`",
        "`scg` AS `SCG`",
        "`capacity_year_2027` AS `Capacity Year_2027`",
        "`capacity_year_2028` AS `Capacity Year_2028`",
        "`capacity_year_2029` AS `Capacity Year_2029`",
        "`capacity_year_2030` AS `Capacity Year_2030`",
        "`capacity_year_2031` AS `Capacity Year_2031`",
        "CAST(`Capacity Year_2027` AS INT) AS `Capacity Year_2027`",
        "CAST(`Capacity Year_2028` AS INT) AS `Capacity Year_2028`",
        "CAST(`Capacity Year_2029` AS INT) AS `Capacity Year_2029`",
        "CAST(`Capacity Year_2030` AS INT) AS `Capacity Year_2030`",
        "CAST(`Capacity Year_2031` AS INT) AS `Capacity Year_2031`"
    ]
}
inputs = {
    "data": ctx["custom_sql.data"],
}
out = run(config, inputs, spark)
ctx["clean_24.transformed_data"] = out["transformed_data"]

# %%
"""
id: fy_data_check
template: transform
name: fy_data_check
position:
  x: 260
  y: 435
description:
  text: "fy Data Check"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: fyforecast
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["fyforecast.data"],
}
out = run(config, inputs, spark)
ctx["fy_data_check.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_24_2
template: transform
name: clean_24_2
position:
  x: 260
  y: 580
description:
  text: "Clean 24"
previewMode: "1000"
config:
  expressions:
  - *
  - NULL AS `F66`
  - NULL AS `F67`
input:
  - node: apt
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "NULL AS `F66`",
        "NULL AS `F67`"
    ]
}
inputs = {
    "data": ctx["apt.data"],
}
out = run(config, inputs, spark)
ctx["clean_24_2.transformed_data"] = out["transformed_data"]

# %%
"""
id: pivot_1_1
template: pivot
name: pivot_1_1
position:
  x: 520
  y: 0
description:
  text: "Pivot 1 (1)"
previewMode: "1000"
config:
  mode: pivot
  group_by: []
  pivot_column: Team
  value_column: Item code 2
  agg: countDistinct
input:
  - node: clean_1_1
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    mode = config.get("mode", "pivot")
    if mode == "pivot":
        group_by = config.get("group_by", [])
        pivot_col = config.get("pivot_column")
        value_col = config.get("value_column")
        agg_fn = config.get("agg", "count").lower()
        result = df.groupBy(*group_by).pivot(pivot_col).agg(getattr(F, agg_fn)(value_col))
        return {"pivoted_data": result}
    else:
        id_cols: List[str] = config.get("id_columns", [])
        value_cols: List[str] = config.get("value_columns", [])
        key_name = config.get("key_name", "key")
        value_name = config.get("value_name", "value")
        stack_expr = "stack({n}, {pairs}) AS ({k}, {v})".format(
            n=len(value_cols),
            pairs=", ".join(f"'{c}', `{c}`" for c in value_cols),
            k=key_name,
            v=value_name,
        )
        result = df.selectExpr(*id_cols, stack_expr)
        return {"pivoted_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "mode": "pivot",
    "group_by": [],
    "pivot_column": "Team",
    "value_column": "Item code 2",
    "agg": "countDistinct"
}
inputs = {
    "data": ctx["clean_1_1.result"],
}
out = run(config, inputs, spark)
ctx["pivot_1_1.pivoted_data"] = out["pivoted_data"]

# %%
"""
id: clean_17
template: transform
name: clean_17
position:
  x: 520
  y: 145
description:
  text: "Clean 17"
previewMode: "1000"
config:
  expressions:
  - *
  - `Supplier_id` AS `Supplier code`
  - `Supplier_name` AS `Supplier name`
  - `SKU_ID` AS `SKU ID`
  - `SKU_Description` AS `SKU Description`
input:
  - node: clean_24
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "`Supplier_id` AS `Supplier code`",
        "`Supplier_name` AS `Supplier name`",
        "`SKU_ID` AS `SKU ID`",
        "`SKU_Description` AS `SKU Description`"
    ]
}
inputs = {
    "data": ctx["clean_24.transformed_data"],
}
out = run(config, inputs, spark)
ctx["clean_17.transformed_data"] = out["transformed_data"]

# %%
"""
id: contract_2
template: join
name: contract_2
position:
  x: 520
  y: 290
description:
  text: "Contract"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`supplierNo` = right.`supplierNo` AND left.`productCode` = right.`productCode`
  expressions: []
input:
  - node: contract
    input_port: left
    output_port: data
  - node: fy_data_check
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`supplierNo` = right.`supplierNo` AND left.`productCode` = right.`productCode`",
    "expressions": []
}
inputs = {
    "left": ctx["contract.data"],
    "right": ctx["fy_data_check.transformed_data"],
}
out = run(config, inputs, spark)
ctx["contract_2.joined_data"] = out["joined_data"]

# %%
"""
id: aggregate_7
template: aggregate
name: aggregate_7
position:
  x: 520
  y: 435
description:
  text: "Aggregate 7"
previewMode: "1000"
config:
  group_bys: []
  aggregations:
  - columnExpr:
        expr: fcYear1
        type: expr
    fn: SUM
    alias: fcYear1
  - columnExpr:
        expr: fcYear2
        type: expr
    fn: SUM
    alias: fcYear2
  - columnExpr:
        expr: fcYear3
        type: expr
    fn: SUM
    alias: fcYear3
  - columnExpr:
        expr: fcYear4
        type: expr
    fn: SUM
    alias: fcYear4
  - columnExpr:
        expr: fcYear5
        type: expr
    fn: SUM
    alias: fcYear5
  - columnExpr:
        expr: fcYear6
        type: expr
    fn: SUM
    alias: fcYear6
input:
  - node: fy_data_check
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "fcYear1",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear1"
        },
        {
            "columnExpr": {
                "expr": "fcYear2",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear2"
        },
        {
            "columnExpr": {
                "expr": "fcYear3",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear3"
        },
        {
            "columnExpr": {
                "expr": "fcYear4",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear4"
        },
        {
            "columnExpr": {
                "expr": "fcYear5",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear5"
        },
        {
            "columnExpr": {
                "expr": "fcYear6",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear6"
        }
    ]
}
inputs = {
    "data": ctx["fy_data_check.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_7.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: aggregate_21
template: aggregate
name: aggregate_21
position:
  x: 520
  y: 580
description:
  text: "Aggregate 21"
previewMode: "1000"
config:
  group_bys: []
  aggregations:
  - columnExpr:
        expr: fcYear1
        type: expr
    fn: SUM
    alias: fcYear1
  - columnExpr:
        expr: fcYear2
        type: expr
    fn: SUM
    alias: fcYear2
  - columnExpr:
        expr: fcYear3
        type: expr
    fn: SUM
    alias: fcYear3
  - columnExpr:
        expr: fcYear4
        type: expr
    fn: SUM
    alias: fcYear4
  - columnExpr:
        expr: fcYear5
        type: expr
    fn: SUM
    alias: fcYear5
  - columnExpr:
        expr: fcYear6
        type: expr
    fn: SUM
    alias: fcYear6
input:
  - node: fy_data_check
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "fcYear1",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear1"
        },
        {
            "columnExpr": {
                "expr": "fcYear2",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear2"
        },
        {
            "columnExpr": {
                "expr": "fcYear3",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear3"
        },
        {
            "columnExpr": {
                "expr": "fcYear4",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear4"
        },
        {
            "columnExpr": {
                "expr": "fcYear5",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear5"
        },
        {
            "columnExpr": {
                "expr": "fcYear6",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear6"
        }
    ]
}
inputs = {
    "data": ctx["fy_data_check.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_21.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: aggregate_23
template: aggregate
name: aggregate_23
position:
  x: 520
  y: 725
description:
  text: "Aggregate 23"
previewMode: "1000"
config:
  group_bys:
  - expr: productCode
    type: expr
  - expr: supplierNo
    type: expr
  aggregations:
  - columnExpr:
        expr: fcYear1
        type: expr
    fn: SUM
    alias: fcYear1
  - columnExpr:
        expr: fcYear2
        type: expr
    fn: SUM
    alias: fcYear2
  - columnExpr:
        expr: fcYear3
        type: expr
    fn: SUM
    alias: fcYear3
  - columnExpr:
        expr: fcYear4
        type: expr
    fn: SUM
    alias: fcYear4
  - columnExpr:
        expr: fcYear5
        type: expr
    fn: SUM
    alias: fcYear5
  - columnExpr:
        expr: fcYear6
        type: expr
    fn: SUM
    alias: fcYear6
input:
  - node: fy_data_check
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "productCode",
            "type": "expr"
        },
        {
            "expr": "supplierNo",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "fcYear1",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear1"
        },
        {
            "columnExpr": {
                "expr": "fcYear2",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear2"
        },
        {
            "columnExpr": {
                "expr": "fcYear3",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear3"
        },
        {
            "columnExpr": {
                "expr": "fcYear4",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear4"
        },
        {
            "columnExpr": {
                "expr": "fcYear5",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear5"
        },
        {
            "columnExpr": {
                "expr": "fcYear6",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear6"
        }
    ]
}
inputs = {
    "data": ctx["fy_data_check.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_23.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: clean_18
template: sql
name: clean_18
position:
  x: 520
  y: 870
description:
  text: "Clean 18"
previewMode: "1000"
config:
  query: |
    SELECT *, CAST(`Legacy Code` AS INT) AS `Legacy Code` FROM clean_24_2 WHERE `Status` = "1 - On Track"
    OR `Status` = "5 - Delivered" 
    OR `Status` = "2 - Delayed"
input:
  - node: clean_24_2
    input_port: data
    output_port: transformed_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *, CAST(`Legacy Code` AS INT) AS `Legacy Code` FROM clean_24_2 WHERE `Status` = \"1 - On Track\"\nOR `Status` = \"5 - Delivered\" \nOR `Status` = \"2 - Delayed\""
}
inputs = {
    "data": [
        ctx["clean_24_2.transformed_data"],
    ],
    "data__sources": [
        {"node": "clean_24_2", "output_port": "transformed_data", "name": "clean_24_2", "df_name": "clean_24_2"},
    ],
}
out = run(config, inputs, spark)
ctx["clean_18.result"] = out["result"]

# %%
"""
id: clean_2_1
template: transform
name: clean_2_1
position:
  x: 780
  y: 0
description:
  text: "Clean 2 (1)"
previewMode: "1000"
config:
  expressions:
  - "* EXCEPT (`count`, `VCO`, `SST`)"
  - |
    IF `VCO` = 1 AND `SST` = 1 THEN "VCO"
    ELSE IF `VCO` = 1 THEN "VCO"
    ELSE IF `SST` = 1 THEN "SST"
    ELSE NULL
    END AS `Team`
input:
  - node: pivot_1_1
    input_port: data
    output_port: pivoted_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT (`count`, `VCO`, `SST`)",
        "IF `VCO` = 1 AND `SST` = 1 THEN \"VCO\"\nELSE IF `VCO` = 1 THEN \"VCO\"\nELSE IF `SST` = 1 THEN \"SST\"\nELSE NULL\nEND AS `Team`"
    ]
}
inputs = {
    "data": ctx["pivot_1_1.pivoted_data"],
}
out = run(config, inputs, spark)
ctx["clean_2_1.transformed_data"] = out["transformed_data"]

# %%
"""
id: aggregate_29
template: aggregate
name: aggregate_29
position:
  x: 780
  y: 145
description:
  text: "Aggregate 29"
previewMode: "1000"
config:
  group_bys:
  - expr: Supplier code
    type: expr
  - expr: SKU ID
    type: expr
  aggregations:
  - columnExpr:
        expr: Capacity Year_2027
        type: expr
    fn: MAX
    alias: Capacity Year_2027
  - columnExpr:
        expr: Capacity Year_2028
        type: expr
    fn: MAX
    alias: Capacity Year_2028
  - columnExpr:
        expr: Capacity Year_2029
        type: expr
    fn: MAX
    alias: Capacity Year_2029
  - columnExpr:
        expr: Capacity Year_2030
        type: expr
    fn: MAX
    alias: Capacity Year_2030
  - columnExpr:
        expr: Capacity Year_2031
        type: expr
    fn: MAX
    alias: Capacity Year_2031
input:
  - node: clean_17
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "Supplier code",
            "type": "expr"
        },
        {
            "expr": "SKU ID",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "Capacity Year_2027",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "Capacity Year_2027"
        },
        {
            "columnExpr": {
                "expr": "Capacity Year_2028",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "Capacity Year_2028"
        },
        {
            "columnExpr": {
                "expr": "Capacity Year_2029",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "Capacity Year_2029"
        },
        {
            "columnExpr": {
                "expr": "Capacity Year_2030",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "Capacity Year_2030"
        },
        {
            "columnExpr": {
                "expr": "Capacity Year_2031",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "Capacity Year_2031"
        }
    ]
}
inputs = {
    "data": ctx["clean_17.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_29.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: contract_clean
template: transform
name: contract_clean
position:
  x: 780
  y: 290
description:
  text: "Contract Clean"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: contract_2
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["contract_2.joined_data"],
}
out = run(config, inputs, spark)
ctx["contract_clean.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_15
template: transform
name: clean_15
position:
  x: 780
  y: 435
description:
  text: "Clean 15"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: aggregate_21
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["aggregate_21.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["clean_15.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_17_2
template: transform
name: clean_17_2
position:
  x: 1040
  y: 0
description:
  text: "Clean 17"
previewMode: "1000"
config:
  expressions:
  - *
  - `Supplier code` AS `Supplier ID`
  - `Capacity Year_2027` AS `2027`
  - `Capacity Year_2028` AS `2028`
  - `Capacity Year_2029` AS `2029`
  - `Capacity Year_2030` AS `2030`
  - `Capacity Year_2031` AS `2031`
input:
  - node: aggregate_29
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "`Supplier code` AS `Supplier ID`",
        "`Capacity Year_2027` AS `2027`",
        "`Capacity Year_2028` AS `2028`",
        "`Capacity Year_2029` AS `2029`",
        "`Capacity Year_2030` AS `2030`",
        "`Capacity Year_2031` AS `2031`"
    ]
}
inputs = {
    "data": ctx["aggregate_29.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["clean_17_2.transformed_data"] = out["transformed_data"]

# %%
"""
id: join_divison
template: join
name: join_divison
position:
  x: 1040
  y: 145
description:
  text: "Join Divison"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`divNo` = right.`divNo`
  expressions: []
input:
  - node: division
    input_port: left
    output_port: data
  - node: contract_clean
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`divNo` = right.`divNo`",
    "expressions": []
}
inputs = {
    "left": ctx["division.data"],
    "right": ctx["contract_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["join_divison.joined_data"] = out["joined_data"]

# %%
"""
id: clean_2
template: transform
name: clean_2
position:
  x: 1300
  y: 0
description:
  text: "Clean 2"
previewMode: "1000"
config:
  expressions:
  - *
  - `2027` AS `Capacity Year_2027`
  - `2028` AS `Capacity Year_2028`
  - `Supplier ID` AS `Supplier Code`
  - `Supplier Code` AS `Supplier code`
  - `2029` AS `Capacity Year_2029`
  - `2030` AS `Capacity Year_2030`
  - `2031` AS `Capacity Year_2031`
input:
  - node: clean_17_2
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "`2027` AS `Capacity Year_2027`",
        "`2028` AS `Capacity Year_2028`",
        "`Supplier ID` AS `Supplier Code`",
        "`Supplier Code` AS `Supplier code`",
        "`2029` AS `Capacity Year_2029`",
        "`2030` AS `Capacity Year_2030`",
        "`2031` AS `Capacity Year_2031`"
    ]
}
inputs = {
    "data": ctx["clean_17_2.transformed_data"],
}
out = run(config, inputs, spark)
ctx["clean_2.transformed_data"] = out["transformed_data"]

# %%
"""
id: div_clean
template: transform
name: div_clean
position:
  x: 1300
  y: 145
description:
  text: "Div Clean"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: join_divison
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["join_divison.joined_data"],
}
out = run(config, inputs, spark)
ctx["div_clean.transformed_data"] = out["transformed_data"]

# %%
"""
id: data_transformation_2
template: transform
name: data_transformation_2
position:
  x: 1560
  y: 0
description:
  text: "Data Transformation 2"
previewMode: "1000"
config:
  expressions:
  - *
  - CAST(`Supplier code` AS INT) AS `Supplier code`
  - CAST(`SKU ID` AS INT) AS `SKU ID`
input:
  - node: clean_2
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "CAST(`Supplier code` AS INT) AS `Supplier code`",
        "CAST(`SKU ID` AS INT) AS `SKU ID`"
    ]
}
inputs = {
    "data": ctx["clean_2.transformed_data"],
}
out = run(config, inputs, spark)
ctx["data_transformation_2.transformed_data"] = out["transformed_data"]

# %%
"""
id: aggregate_15
template: aggregate
name: aggregate_15
position:
  x: 1560
  y: 145
description:
  text: "Aggregate 15"
previewMode: "1000"
config:
  group_bys: []
  aggregations: []
input:
  - node: clean_2
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [],
    "aggregations": []
}
inputs = {
    "data": ctx["clean_2.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_15.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: product_join
template: join
name: product_join
position:
  x: 1560
  y: 290
description:
  text: "Product Join"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`productCode` = right.`productCode`
  expressions: []
input:
  - node: product
    input_port: left
    output_port: data
  - node: div_clean
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`productCode` = right.`productCode`",
    "expressions": []
}
inputs = {
    "left": ctx["product.data"],
    "right": ctx["div_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["product_join.joined_data"] = out["joined_data"]

# %%
"""
id: aggregate_11
template: aggregate
name: aggregate_11
position:
  x: 1820
  y: 0
description:
  text: "Aggregate 11"
previewMode: "1000"
config:
  group_bys:
  - expr: SKU ID
    type: expr
  aggregations:
  - columnExpr:
        expr: Capacity Year_2027
        type: expr
    fn: SUM
    alias: Capacity Year_2027
  - columnExpr:
        expr: Capacity Year_2028
        type: expr
    fn: SUM
    alias: Capacity Year_2028
  - columnExpr:
        expr: Capacity Year_2029
        type: expr
    fn: SUM
    alias: Capacity Year_2029
  - columnExpr:
        expr: Capacity Year_2030
        type: expr
    fn: SUM
    alias: Capacity Year_2030
  - columnExpr:
        expr: Capacity Year_2031
        type: expr
    fn: SUM
    alias: Capacity Year_2031
input:
  - node: data_transformation_2
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "SKU ID",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "Capacity Year_2027",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "Capacity Year_2027"
        },
        {
            "columnExpr": {
                "expr": "Capacity Year_2028",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "Capacity Year_2028"
        },
        {
            "columnExpr": {
                "expr": "Capacity Year_2029",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "Capacity Year_2029"
        },
        {
            "columnExpr": {
                "expr": "Capacity Year_2030",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "Capacity Year_2030"
        },
        {
            "columnExpr": {
                "expr": "Capacity Year_2031",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "Capacity Year_2031"
        }
    ]
}
inputs = {
    "data": ctx["data_transformation_2.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_11.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: prod_clean
template: transform
name: prod_clean
position:
  x: 1820
  y: 145
description:
  text: "Prod Clean"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: product_join
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["product_join.joined_data"],
}
out = run(config, inputs, spark)
ctx["prod_clean.transformed_data"] = out["transformed_data"]

# %%
"""
id: supplier_join
template: join
name: supplier_join
position:
  x: 2080
  y: 0
description:
  text: "Supplier Join"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`supplierNo` = right.`supplierNo`
  expressions: []
input:
  - node: supplier
    input_port: left
    output_port: data
  - node: prod_clean
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`supplierNo` = right.`supplierNo`",
    "expressions": []
}
inputs = {
    "left": ctx["supplier.data"],
    "right": ctx["prod_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["supplier_join.joined_data"] = out["joined_data"]

# %%
"""
id: supplier_clean
template: transform
name: supplier_clean
position:
  x: 2340
  y: 0
description:
  text: "Supplier Clean"
previewMode: "1000"
config:
  expressions:
  - *
  - |
    IF `divNo` = 997 THEN "West Region"
    ELSE IF `divNo` = 998 THEN "Southeast Region"
    ELSE IF `divNo` = 999 THEN "Northeast Region"
    ELSE `Supplier`
    END AS `Supplier`
  - CAST(`mainCode` AS STRING) + " - " + CAST(`description` AS STRING) AS `prodDescFilter`
  - CAST(`CGNo` AS STRING) + " | " + CAST(`scgComplete` AS STRING) AS `scgComplete w/ cg`
  - "RIGHT(\"00000\" + CAST(`supplierNo` AS STRING), 5) + \" - \" + CAST(`Supplier` AS STRING) AS `SupplierWithName`"
  - `fcYear2` + `fcYear3` + `fcYear4` + `fcYear5` + `fcYear6` AS `5 Year Total`
  - `lySales` / CAST(`Packsize` AS INT) AS `lySales_cases`
input:
  - node: supplier_join
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "IF `divNo` = 997 THEN \"West Region\"\nELSE IF `divNo` = 998 THEN \"Southeast Region\"\nELSE IF `divNo` = 999 THEN \"Northeast Region\"\nELSE `Supplier`\nEND AS `Supplier`",
        "CAST(`mainCode` AS STRING) + \" - \" + CAST(`description` AS STRING) AS `prodDescFilter`",
        "CAST(`CGNo` AS STRING) + \" | \" + CAST(`scgComplete` AS STRING) AS `scgComplete w/ cg`",
        "RIGHT(\"00000\" + CAST(`supplierNo` AS STRING), 5) + \" - \" + CAST(`Supplier` AS STRING) AS `SupplierWithName`",
        "`fcYear2` + `fcYear3` + `fcYear4` + `fcYear5` + `fcYear6` AS `5 Year Total`",
        "`lySales` / CAST(`Packsize` AS INT) AS `lySales_cases`"
    ]
}
inputs = {
    "data": ctx["supplier_join.joined_data"],
}
out = run(config, inputs, spark)
ctx["supplier_clean.transformed_data"] = out["transformed_data"]

# %%
"""
id: remove_division
template: transform
name: remove_division
position:
  x: 2600
  y: 0
description:
  text: "Remove Division"
previewMode: "1000"
config:
  expressions:
  - "* EXCEPT (`divId`, `divNo-1`, `sortByDivOrder`, `divNo`, `startingStoreCount`)"
input:
  - node: supplier_clean
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT (`divId`, `divNo-1`, `sortByDivOrder`, `divNo`, `startingStoreCount`)"
    ]
}
inputs = {
    "data": ctx["supplier_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["remove_division.transformed_data"] = out["transformed_data"]

# %%
"""
id: remove_year
template: transform
name: remove_year
position:
  x: 2860
  y: 0
description:
  text: "Remove Year"
previewMode: "1000"
config:
  expressions:
  - "* EXCEPT (`year1`, `year2`, `year3`, `year4`, `year5`, `year6`)"
input:
  - node: remove_division
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT (`year1`, `year2`, `year3`, `year4`, `year5`, `year6`)"
    ]
}
inputs = {
    "data": ctx["remove_division.transformed_data"],
}
out = run(config, inputs, spark)
ctx["remove_year.transformed_data"] = out["transformed_data"]

# %%
"""
id: aggregate_w_o_div
template: aggregate
name: aggregate_w_o_div
position:
  x: 3120
  y: 0
description:
  text: "Aggregate w/o Div"
previewMode: "1000"
config:
  group_bys:
  - expr: mainCode
    type: expr
  - expr: buyingDirector
    type: expr
  - expr: cgComplete
    type: expr
  - expr: cgDesc
    type: expr
  - expr: CGNo
    type: expr
  - expr: description
    type: expr
  - expr: groupBuyingDirector
    type: expr
  - expr: packsize
    type: expr
  - expr: Packsize
    type: expr
  - expr: prodDescFilter
    type: expr
  - expr: productClass
    type: expr
  - expr: scgComplete
    type: expr
  - expr: scgComplete w/ cg
    type: expr
  - expr: scgDesc
    type: expr
  - expr: SCGNo
    type: expr
  - expr: productCode
    type: expr
  - expr: productCode-1
    type: expr
  - expr: productCode-2
    type: expr
  - expr: mainCode-1
    type: expr
  - expr: linkedCode
    type: expr
  - expr: Supplier
    type: expr
  - expr: supplierNo
    type: expr
  - expr: supplierNo-1
    type: expr
  - expr: supplierNo-2
    type: expr
  - expr: SupplierWithName
    type: expr
  aggregations:
  - columnExpr:
        expr: fcYear1
        type: expr
    fn: SUM
    alias: fcYear1
  - columnExpr:
        expr: fcYear2
        type: expr
    fn: SUM
    alias: fcYear2
  - columnExpr:
        expr: fcYear3
        type: expr
    fn: SUM
    alias: fcYear3
  - columnExpr:
        expr: fcYear4
        type: expr
    fn: SUM
    alias: fcYear4
  - columnExpr:
        expr: fcYear5
        type: expr
    fn: SUM
    alias: fcYear5
  - columnExpr:
        expr: fcYear6
        type: expr
    fn: SUM
    alias: fcYear6
  - columnExpr:
        expr: 5 Year Total
        type: expr
    fn: SUM
    alias: 5 Year Total
  - columnExpr:
        expr: sumOfCases
        type: expr
    fn: SUM
    alias: sumOfCases
  - columnExpr:
        expr: Retail
        type: expr
    fn: AVG
    alias: Retail
input:
  - node: remove_year
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "mainCode",
            "type": "expr"
        },
        {
            "expr": "buyingDirector",
            "type": "expr"
        },
        {
            "expr": "cgComplete",
            "type": "expr"
        },
        {
            "expr": "cgDesc",
            "type": "expr"
        },
        {
            "expr": "CGNo",
            "type": "expr"
        },
        {
            "expr": "description",
            "type": "expr"
        },
        {
            "expr": "groupBuyingDirector",
            "type": "expr"
        },
        {
            "expr": "packsize",
            "type": "expr"
        },
        {
            "expr": "Packsize",
            "type": "expr"
        },
        {
            "expr": "prodDescFilter",
            "type": "expr"
        },
        {
            "expr": "productClass",
            "type": "expr"
        },
        {
            "expr": "scgComplete",
            "type": "expr"
        },
        {
            "expr": "scgComplete w/ cg",
            "type": "expr"
        },
        {
            "expr": "scgDesc",
            "type": "expr"
        },
        {
            "expr": "SCGNo",
            "type": "expr"
        },
        {
            "expr": "productCode",
            "type": "expr"
        },
        {
            "expr": "productCode-1",
            "type": "expr"
        },
        {
            "expr": "productCode-2",
            "type": "expr"
        },
        {
            "expr": "mainCode-1",
            "type": "expr"
        },
        {
            "expr": "linkedCode",
            "type": "expr"
        },
        {
            "expr": "Supplier",
            "type": "expr"
        },
        {
            "expr": "supplierNo",
            "type": "expr"
        },
        {
            "expr": "supplierNo-1",
            "type": "expr"
        },
        {
            "expr": "supplierNo-2",
            "type": "expr"
        },
        {
            "expr": "SupplierWithName",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "fcYear1",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear1"
        },
        {
            "columnExpr": {
                "expr": "fcYear2",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear2"
        },
        {
            "columnExpr": {
                "expr": "fcYear3",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear3"
        },
        {
            "columnExpr": {
                "expr": "fcYear4",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear4"
        },
        {
            "columnExpr": {
                "expr": "fcYear5",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear5"
        },
        {
            "columnExpr": {
                "expr": "fcYear6",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear6"
        },
        {
            "columnExpr": {
                "expr": "5 Year Total",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "5 Year Total"
        },
        {
            "columnExpr": {
                "expr": "sumOfCases",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "sumOfCases"
        },
        {
            "columnExpr": {
                "expr": "Retail",
                "type": "expr"
            },
            "fn": "AVG",
            "alias": "Retail"
        }
    ]
}
inputs = {
    "data": ctx["remove_year.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_w_o_div.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: rebuild_dataset
template: transform
name: rebuild_dataset
position:
  x: 3380
  y: 0
description:
  text: "Rebuild Dataset"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: aggregate_w_o_div
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["aggregate_w_o_div.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["rebuild_dataset.transformed_data"] = out["transformed_data"]

# %%
"""
id: ahead_cbis_join
template: join
name: ahead_cbis_join
position:
  x: 3640
  y: 0
description:
  text: "Ahead CBIS Join"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`productCode` = right.`CBISProductKey`
  expressions: []
input:
  - node: ahead_to_cbis_code
    input_port: left
    output_port: data
  - node: rebuild_dataset
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`productCode` = right.`CBISProductKey`",
    "expressions": []
}
inputs = {
    "left": ctx["ahead_to_cbis_code.data"],
    "right": ctx["rebuild_dataset.transformed_data"],
}
out = run(config, inputs, spark)
ctx["ahead_cbis_join.joined_data"] = out["joined_data"]

# %%
"""
id: aggregate_19
template: aggregate
name: aggregate_19
position:
  x: 3640
  y: 145
description:
  text: "Aggregate 19"
previewMode: "1000"
config:
  group_bys: []
  aggregations:
  - columnExpr:
        expr: fcYear1
        type: expr
    fn: SUM
    alias: fcYear1
  - columnExpr:
        expr: fcYear2
        type: expr
    fn: SUM
    alias: fcYear2
  - columnExpr:
        expr: fcYear3
        type: expr
    fn: SUM
    alias: fcYear3
  - columnExpr:
        expr: fcYear4
        type: expr
    fn: SUM
    alias: fcYear4
  - columnExpr:
        expr: fcYear5
        type: expr
    fn: SUM
    alias: fcYear5
  - columnExpr:
        expr: fcYear6
        type: expr
    fn: SUM
    alias: fcYear6
input:
  - node: rebuild_dataset
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "fcYear1",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear1"
        },
        {
            "columnExpr": {
                "expr": "fcYear2",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear2"
        },
        {
            "columnExpr": {
                "expr": "fcYear3",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear3"
        },
        {
            "columnExpr": {
                "expr": "fcYear4",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear4"
        },
        {
            "columnExpr": {
                "expr": "fcYear5",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear5"
        },
        {
            "columnExpr": {
                "expr": "fcYear6",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear6"
        }
    ]
}
inputs = {
    "data": ctx["rebuild_dataset.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_19.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: ahead_clean
template: transform
name: ahead_clean
position:
  x: 3900
  y: 0
description:
  text: "AHEAD Clean"
previewMode: "1000"
config:
  expressions:
  - * EXCEPT (`CBISProductKey`)
input:
  - node: ahead_cbis_join
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT (`CBISProductKey`)"
    ]
}
inputs = {
    "data": ctx["ahead_cbis_join.joined_data"],
}
out = run(config, inputs, spark)
ctx["ahead_clean.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_16
template: transform
name: clean_16
position:
  x: 3900
  y: 145
description:
  text: "Clean 16"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: aggregate_19
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["aggregate_19.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["clean_16.transformed_data"] = out["transformed_data"]

# %%
"""
id: join_9
template: join
name: join_9
position:
  x: 4160
  y: 0
description:
  text: "Join 9"
previewMode: "1000"
config:
  join_type: left_anti
  join_conditions: left.`SKU ID` = right.`productCode` AND left.`Supplier code` = right.`supplierNo`
  expressions: []
input:
  - node: ahead_clean
    input_port: left
    output_port: transformed_data
  - node: data_transformation_2
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left_anti",
    "join_conditions": "left.`SKU ID` = right.`productCode` AND left.`Supplier code` = right.`supplierNo`",
    "expressions": []
}
inputs = {
    "left": ctx["ahead_clean.transformed_data"],
    "right": ctx["data_transformation_2.transformed_data"],
}
out = run(config, inputs, spark)
ctx["join_9.joined_data"] = out["joined_data"]

# %%
"""
id: aggregate_9
template: aggregate
name: aggregate_9
position:
  x: 4160
  y: 145
description:
  text: "Aggregate 9"
previewMode: "1000"
config:
  group_bys:
  - expr: productCode
    type: expr
  aggregations:
  - columnExpr:
        expr: fcYear1
        type: expr
    fn: SUM
    alias: fcYear1
  - columnExpr:
        expr: fcYear2
        type: expr
    fn: SUM
    alias: fcYear2
  - columnExpr:
        expr: fcYear3
        type: expr
    fn: SUM
    alias: fcYear3
  - columnExpr:
        expr: fcYear4
        type: expr
    fn: SUM
    alias: fcYear4
  - columnExpr:
        expr: fcYear5
        type: expr
    fn: SUM
    alias: fcYear5
  - columnExpr:
        expr: fcYear6
        type: expr
    fn: SUM
    alias: fcYear6
input:
  - node: ahead_clean
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "productCode",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "fcYear1",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear1"
        },
        {
            "columnExpr": {
                "expr": "fcYear2",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear2"
        },
        {
            "columnExpr": {
                "expr": "fcYear3",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear3"
        },
        {
            "columnExpr": {
                "expr": "fcYear4",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear4"
        },
        {
            "columnExpr": {
                "expr": "fcYear5",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear5"
        },
        {
            "columnExpr": {
                "expr": "fcYear6",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear6"
        }
    ]
}
inputs = {
    "data": ctx["ahead_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_9.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: aggregate_7_2
template: aggregate
name: aggregate_7_2
position:
  x: 4160
  y: 290
description:
  text: "Aggregate 7"
previewMode: "1000"
config:
  group_bys:
  - expr: productCode
    type: expr
  aggregations: []
input:
  - node: ahead_clean
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "productCode",
            "type": "expr"
        }
    ],
    "aggregations": []
}
inputs = {
    "data": ctx["ahead_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_7_2.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: clean_6
template: filter
name: clean_6
position:
  x: 4160
  y: 435
description:
  text: "Clean 6"
previewMode: "1000"
config:
  condition: "`cgComplete` NOT IN (\"02 - Sparkling wine\", \"03 - Wine\", \"04 - Beer\")"
input:
  - node: ahead_clean
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")
    if not condition:
        return {"filtered_data": df}
    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "`cgComplete` NOT IN (\"02 - Sparkling wine\", \"03 - Wine\", \"04 - Beer\")"
}
inputs = {
    "data": ctx["ahead_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["clean_6.filtered_data"] = out["filtered_data"]

# %%
"""
id: clean_7
template: sql
name: clean_7
position:
  x: 4160
  y: 580
description:
  text: "Clean 7"
previewMode: "1000"
config:
  query: "SELECT *, \"Alcohol Supplier\" AS `Supplier`, 99999 AS `supplierNo`, CAST(`supplierNo` AS STRING)+\" : \"+CAST(`Supplier` AS STRING) AS `SupplierWithName` FROM ahead_clean WHERE `cgComplete` IN (\"02 - Sparkling wine\", \"03 - Wine\", \"04 - Beer\")"
input:
  - node: ahead_clean
    input_port: data
    output_port: transformed_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *, \"Alcohol Supplier\" AS `Supplier`, 99999 AS `supplierNo`, CAST(`supplierNo` AS STRING)+\" : \"+CAST(`Supplier` AS STRING) AS `SupplierWithName` FROM ahead_clean WHERE `cgComplete` IN (\"02 - Sparkling wine\", \"03 - Wine\", \"04 - Beer\")"
}
inputs = {
    "data": [
        ctx["ahead_clean.transformed_data"],
    ],
    "data__sources": [
        {"node": "ahead_clean", "output_port": "transformed_data", "name": "ahead_clean", "df_name": "ahead_clean"},
    ],
}
out = run(config, inputs, spark)
ctx["clean_7.result"] = out["result"]

# %%
"""
id: clean_10
template: transform
name: clean_10
position:
  x: 4160
  y: 725
description:
  text: "Clean 10"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: ahead_clean
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["ahead_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["clean_10.transformed_data"] = out["transformed_data"]

# %%
"""
id: join_21
template: join
name: join_21
position:
  x: 4160
  y: 870
description:
  text: "Join 21"
previewMode: "1000"
config:
  join_type: right_anti
  join_conditions: left.`SKU ID` = right.`productCode`
  expressions: []
input:
  - node: data_transformation_2
    input_port: left
    output_port: transformed_data
  - node: ahead_clean
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "right_anti",
    "join_conditions": "left.`SKU ID` = right.`productCode`",
    "expressions": []
}
inputs = {
    "left": ctx["data_transformation_2.transformed_data"],
    "right": ctx["ahead_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["join_21.joined_data"] = out["joined_data"]

# %%
"""
id: aggregate_17
template: aggregate
name: aggregate_17
position:
  x: 4160
  y: 1015
description:
  text: "Aggregate 17"
previewMode: "1000"
config:
  group_bys: []
  aggregations:
  - columnExpr:
        expr: fcYear1
        type: expr
    fn: SUM
    alias: fcYear1
  - columnExpr:
        expr: fcYear2
        type: expr
    fn: SUM
    alias: fcYear2
  - columnExpr:
        expr: fcYear3
        type: expr
    fn: SUM
    alias: fcYear3
  - columnExpr:
        expr: fcYear4
        type: expr
    fn: SUM
    alias: fcYear4
  - columnExpr:
        expr: fcYear5
        type: expr
    fn: SUM
    alias: fcYear5
  - columnExpr:
        expr: fcYear6
        type: expr
    fn: SUM
    alias: fcYear6
input:
  - node: ahead_clean
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "fcYear1",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear1"
        },
        {
            "columnExpr": {
                "expr": "fcYear2",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear2"
        },
        {
            "columnExpr": {
                "expr": "fcYear3",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear3"
        },
        {
            "columnExpr": {
                "expr": "fcYear4",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear4"
        },
        {
            "columnExpr": {
                "expr": "fcYear5",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear5"
        },
        {
            "columnExpr": {
                "expr": "fcYear6",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear6"
        }
    ]
}
inputs = {
    "data": ctx["ahead_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_17.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: join_23
template: join
name: join_23
position:
  x: 4160
  y: 1160
description:
  text: "Join 23"
previewMode: "1000"
config:
  join_type: inner
  join_conditions: left.`productCode` = right.`productCode` AND left.`supplierNo` = right.`supplierNo`
  expressions: []
input:
  - node: ahead_clean
    input_port: left
    output_port: transformed_data
  - node: aggregate_23
    input_port: right
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "inner",
    "join_conditions": "left.`productCode` = right.`productCode` AND left.`supplierNo` = right.`supplierNo`",
    "expressions": []
}
inputs = {
    "left": ctx["ahead_clean.transformed_data"],
    "right": ctx["aggregate_23.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["join_23.joined_data"] = out["joined_data"]

# %%
"""
id: clean_3
template: transform
name: clean_3
position:
  x: 4420
  y: 0
description:
  text: "Clean 3"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: join_9
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["join_9.joined_data"],
}
out = run(config, inputs, spark)
ctx["clean_3.transformed_data"] = out["transformed_data"]

# %%
"""
id: qualtrics_capacity_join
template: join
name: qualtrics_capacity_join
position:
  x: 4420
  y: 145
description:
  text: "Qualtrics_Capacity_Join"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`productCode` = right.`SKU ID` AND left.`supplierNo` = right.`Supplier code`
  expressions: []
input:
  - node: clean_6
    input_port: left
    output_port: filtered_data
  - node: data_transformation_2
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`productCode` = right.`SKU ID` AND left.`supplierNo` = right.`Supplier code`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_6.filtered_data"],
    "right": ctx["data_transformation_2.transformed_data"],
}
out = run(config, inputs, spark)
ctx["qualtrics_capacity_join.joined_data"] = out["joined_data"]

# %%
"""
id: aggregate_9_2
template: aggregate
name: aggregate_9_2
position:
  x: 4420
  y: 290
description:
  text: "Aggregate 9"
previewMode: "1000"
config:
  group_bys:
  - expr: productCode
    type: expr
  - expr: SupplierWithName
    type: expr
  - expr: Supplier
    type: expr
  - expr: supplierNo
    type: expr
  aggregations:
  - columnExpr:
        expr: fcYear1
        type: expr
    fn: SUM
    alias: fcYear1
  - columnExpr:
        expr: fcYear2
        type: expr
    fn: SUM
    alias: fcYear2
  - columnExpr:
        expr: fcYear3
        type: expr
    fn: SUM
    alias: fcYear3
  - columnExpr:
        expr: fcYear4
        type: expr
    fn: SUM
    alias: fcYear4
  - columnExpr:
        expr: fcYear5
        type: expr
    fn: SUM
    alias: fcYear5
  - columnExpr:
        expr: fcYear6
        type: expr
    fn: SUM
    alias: fcYear6
  - columnExpr:
        expr: 5 Year Total
        type: expr
    fn: SUM
    alias: 5 Year Total
  - columnExpr:
        expr: sumOfCases
        type: expr
    fn: SUM
    alias: sumOfCases
input:
  - node: clean_7
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "productCode",
            "type": "expr"
        },
        {
            "expr": "SupplierWithName",
            "type": "expr"
        },
        {
            "expr": "Supplier",
            "type": "expr"
        },
        {
            "expr": "supplierNo",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "fcYear1",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear1"
        },
        {
            "columnExpr": {
                "expr": "fcYear2",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear2"
        },
        {
            "columnExpr": {
                "expr": "fcYear3",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear3"
        },
        {
            "columnExpr": {
                "expr": "fcYear4",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear4"
        },
        {
            "columnExpr": {
                "expr": "fcYear5",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear5"
        },
        {
            "columnExpr": {
                "expr": "fcYear6",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear6"
        },
        {
            "columnExpr": {
                "expr": "5 Year Total",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "5 Year Total"
        },
        {
            "columnExpr": {
                "expr": "sumOfCases",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "sumOfCases"
        }
    ]
}
inputs = {
    "data": ctx["clean_7.result"],
}
out = run(config, inputs, spark)
ctx["aggregate_9_2.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: aggregate_13
template: aggregate
name: aggregate_13
position:
  x: 4420
  y: 435
description:
  text: "Aggregate 13"
previewMode: "1000"
config:
  group_bys:
  - expr: productCode
    type: expr
  - expr: SCGNo
    type: expr
  - expr: scgComplete
    type: expr
  - expr: scgComplete w/ cg
    type: expr
  - expr: scgDesc
    type: expr
  - expr: CGNo
    type: expr
  - expr: cgDesc
    type: expr
  - expr: cgComplete
    type: expr
  - expr: description
    type: expr
  - expr: Active
    type: expr
  - expr: buyingDirector
    type: expr
  - expr: groupBuyingDirector
    type: expr
  - expr: linkedCode
    type: expr
  - expr: mainCode
    type: expr
  - expr: mainCode-1
    type: expr
  - expr: prodDescFilter
    type: expr
  - expr: productClass
    type: expr
  - expr: Packsize
    type: expr
  aggregations:
  - columnExpr:
        expr: Retail
        type: expr
    fn: MAX
    alias: Retail
input:
  - node: clean_10
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "productCode",
            "type": "expr"
        },
        {
            "expr": "SCGNo",
            "type": "expr"
        },
        {
            "expr": "scgComplete",
            "type": "expr"
        },
        {
            "expr": "scgComplete w/ cg",
            "type": "expr"
        },
        {
            "expr": "scgDesc",
            "type": "expr"
        },
        {
            "expr": "CGNo",
            "type": "expr"
        },
        {
            "expr": "cgDesc",
            "type": "expr"
        },
        {
            "expr": "cgComplete",
            "type": "expr"
        },
        {
            "expr": "description",
            "type": "expr"
        },
        {
            "expr": "Active",
            "type": "expr"
        },
        {
            "expr": "buyingDirector",
            "type": "expr"
        },
        {
            "expr": "groupBuyingDirector",
            "type": "expr"
        },
        {
            "expr": "linkedCode",
            "type": "expr"
        },
        {
            "expr": "mainCode",
            "type": "expr"
        },
        {
            "expr": "mainCode-1",
            "type": "expr"
        },
        {
            "expr": "prodDescFilter",
            "type": "expr"
        },
        {
            "expr": "productClass",
            "type": "expr"
        },
        {
            "expr": "Packsize",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "Retail",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "Retail"
        }
    ]
}
inputs = {
    "data": ctx["clean_10.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_13.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: clean_12
template: transform
name: clean_12
position:
  x: 4420
  y: 580
description:
  text: "Clean 12"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: join_21
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["join_21.joined_data"],
}
out = run(config, inputs, spark)
ctx["clean_12.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_13
template: transform
name: clean_13
position:
  x: 4420
  y: 725
description:
  text: "Clean 13"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: aggregate_17
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["aggregate_17.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["clean_13.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_14
template: transform
name: clean_14
position:
  x: 4420
  y: 870
description:
  text: "Clean 14"
previewMode: "1000"
config:
  expressions:
  - *
  - `variance` AS `variance-y1`
  - `fcYear1`=`fcYear1-1` AS `variance`
  - `fcYear2`=`fcYear2-1` AS `variance-y2`
  - `fcYear3`=`fcYear3-1` AS `variance-y3`
  - `fcYear4`=`fcYear4-1` AS `variance-y4`
  - `fcYear5`=`fcYear5-1` AS `variance-y5`
  - `fcYear6`=`fcYear6-1` AS `variance-y6`
  - `fcYear1`-`fcYear1-1` AS `variance calc`
input:
  - node: join_23
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "`variance` AS `variance-y1`",
        "`fcYear1`=`fcYear1-1` AS `variance`",
        "`fcYear2`=`fcYear2-1` AS `variance-y2`",
        "`fcYear3`=`fcYear3-1` AS `variance-y3`",
        "`fcYear4`=`fcYear4-1` AS `variance-y4`",
        "`fcYear5`=`fcYear5-1` AS `variance-y5`",
        "`fcYear6`=`fcYear6-1` AS `variance-y6`",
        "`fcYear1`-`fcYear1-1` AS `variance calc`"
    ]
}
inputs = {
    "data": ctx["join_23.joined_data"],
}
out = run(config, inputs, spark)
ctx["clean_14.transformed_data"] = out["transformed_data"]

# %%
"""
id: join_11
template: join
name: join_11
position:
  x: 4680
  y: 0
description:
  text: "Join 11"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`SKU ID` = right.`productCode`
  expressions: []
input:
  - node: clean_3
    input_port: left
    output_port: transformed_data
  - node: aggregate_9
    input_port: right
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`SKU ID` = right.`productCode`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_3.transformed_data"],
    "right": ctx["aggregate_9.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["join_11.joined_data"] = out["joined_data"]

# %%
"""
id: join_13
template: join
name: join_13
position:
  x: 4680
  y: 145
description:
  text: "Join 13"
previewMode: "1000"
config:
  join_type: left_anti
  join_conditions: left.`SKU ID` = right.`productCode`
  expressions: []
input:
  - node: clean_3
    input_port: left
    output_port: transformed_data
  - node: aggregate_7_2
    input_port: right
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left_anti",
    "join_conditions": "left.`SKU ID` = right.`productCode`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_3.transformed_data"],
    "right": ctx["aggregate_7_2.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["join_13.joined_data"] = out["joined_data"]

# %%
"""
id: join_15
template: join
name: join_15
position:
  x: 4680
  y: 290
description:
  text: "Join 15"
previewMode: "1000"
config:
  join_type: inner
  join_conditions: left.`SKU ID` = right.`productCode`
  expressions: []
input:
  - node: clean_3
    input_port: left
    output_port: transformed_data
  - node: aggregate_7_2
    input_port: right
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "inner",
    "join_conditions": "left.`SKU ID` = right.`productCode`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_3.transformed_data"],
    "right": ctx["aggregate_7_2.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["join_15.joined_data"] = out["joined_data"]

# %%
"""
id: qualtrics_capacity_clean
template: transform
name: qualtrics_capacity_clean
position:
  x: 4680
  y: 435
description:
  text: "Qualtrics Capacity Clean"
previewMode: "1000"
config:
  expressions:
  - "* EXCEPT (`supplierNo-2`, `productCode-1`, `supplierNo-1`, `mainCode-1`, `productCode-2`, `packsize`, `Active`, `SKU ID`, `Supplier code`)"
  - `fcYear1` AS `fcYear_2027`
  - `fcYear2` AS `fcYear_2028`
  - `fcYear3` AS `fcYear_2029`
  - `fcYear4` AS `fcYear_2030`
  - `fcYear5` AS `fcYear_2031`
  - CAST(`Capacity Year_2027` AS DOUBLE) AS `Capacity Year_2027`
  - CAST(`Capacity Year_2028` AS DOUBLE) AS `Capacity Year_2028`
  - CAST(`Capacity Year_2029` AS DOUBLE) AS `Capacity Year_2029`
  - CAST(`Capacity Year_2030` AS DOUBLE) AS `Capacity Year_2030`
  - `Capacity Year_2027`- `fcYear6` AS `Delta_2027`
  - `Capacity Year_2028`-`fcYear6` AS `Delta_2028`
  - `Capacity Year_2029`-`fcYear6` AS `Delta_2029`
  - `Capacity Year_2030`-`fcYear6` AS `Delta_2030`
  - `Capacity Year_2031`-`fcYear6` AS `Delta_2031`
input:
  - node: qualtrics_capacity_join
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT (`supplierNo-2`, `productCode-1`, `supplierNo-1`, `mainCode-1`, `productCode-2`, `packsize`, `Active`, `SKU ID`, `Supplier code`)",
        "`fcYear1` AS `fcYear_2027`",
        "`fcYear2` AS `fcYear_2028`",
        "`fcYear3` AS `fcYear_2029`",
        "`fcYear4` AS `fcYear_2030`",
        "`fcYear5` AS `fcYear_2031`",
        "CAST(`Capacity Year_2027` AS DOUBLE) AS `Capacity Year_2027`",
        "CAST(`Capacity Year_2028` AS DOUBLE) AS `Capacity Year_2028`",
        "CAST(`Capacity Year_2029` AS DOUBLE) AS `Capacity Year_2029`",
        "CAST(`Capacity Year_2030` AS DOUBLE) AS `Capacity Year_2030`",
        "`Capacity Year_2027`- `fcYear6` AS `Delta_2027`",
        "`Capacity Year_2028`-`fcYear6` AS `Delta_2028`",
        "`Capacity Year_2029`-`fcYear6` AS `Delta_2029`",
        "`Capacity Year_2030`-`fcYear6` AS `Delta_2030`",
        "`Capacity Year_2031`-`fcYear6` AS `Delta_2031`"
    ]
}
inputs = {
    "data": ctx["qualtrics_capacity_join.joined_data"],
}
out = run(config, inputs, spark)
ctx["qualtrics_capacity_clean.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_8
template: transform
name: clean_8
position:
  x: 4680
  y: 580
description:
  text: "Clean 8"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: aggregate_9_2
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["aggregate_9_2.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["clean_8.transformed_data"] = out["transformed_data"]

# %%
"""
id: all_dropped_rows
template: transform
name: all_dropped_rows
position:
  x: 4940
  y: 0
description:
  text: "ALL DROPPED ROWS"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: join_11
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["join_11.joined_data"],
}
out = run(config, inputs, spark)
ctx["all_dropped_rows.transformed_data"] = out["transformed_data"]

# %%
"""
id: no_supplier_code
template: filter
name: no_supplier_code
position:
  x: 4940
  y: 145
description:
  text: "NO SUPPLIER CODE"
previewMode: "1000"
config:
  condition: `Supplier code` IN (NULL)
input:
  - node: join_11
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")
    if not condition:
        return {"filtered_data": df}
    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "`Supplier code` IN (NULL)"
}
inputs = {
    "data": ctx["join_11.joined_data"],
}
out = run(config, inputs, spark)
ctx["no_supplier_code.filtered_data"] = out["filtered_data"]

# %%
"""
id: no_product_code
template: transform
name: no_product_code
position:
  x: 4940
  y: 290
description:
  text: "NO PRODUCT CODE"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: join_13
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["join_13.joined_data"],
}
out = run(config, inputs, spark)
ctx["no_product_code.transformed_data"] = out["transformed_data"]

# %%
"""
id: combo_with_no_match
template: filter
name: combo_with_no_match
position:
  x: 4940
  y: 435
description:
  text: "COMBO WITH NO MATCH"
previewMode: "1000"
config:
  condition: `Supplier code` NOT IN (NULL)
input:
  - node: join_15
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")
    if not condition:
        return {"filtered_data": df}
    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "`Supplier code` NOT IN (NULL)"
}
inputs = {
    "data": ctx["join_15.joined_data"],
}
out = run(config, inputs, spark)
ctx["combo_with_no_match.filtered_data"] = out["filtered_data"]

# %%
"""
id: join_17
template: join
name: join_17
position:
  x: 4940
  y: 580
description:
  text: "Join 17"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`productCode` = right.`SKU ID`
  expressions: []
input:
  - node: clean_8
    input_port: left
    output_port: transformed_data
  - node: aggregate_11
    input_port: right
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`productCode` = right.`SKU ID`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_8.transformed_data"],
    "right": ctx["aggregate_11.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["join_17.joined_data"] = out["joined_data"]

# %%
"""
id: aggregate_27
template: aggregate
name: aggregate_27
position:
  x: 5200
  y: 0
description:
  text: "Aggregate 27"
previewMode: "1000"
config:
  group_bys: []
  aggregations:
  - columnExpr:
        expr: fcYear1
        type: expr
    fn: SUM
    alias: fcYear1
  - columnExpr:
        expr: fcYear2
        type: expr
    fn: SUM
    alias: fcYear2
  - columnExpr:
        expr: fcYear3
        type: expr
    fn: SUM
    alias: fcYear3
  - columnExpr:
        expr: fcYear4
        type: expr
    fn: SUM
    alias: fcYear4
  - columnExpr:
        expr: fcYear5
        type: expr
    fn: SUM
    alias: fcYear5
  - columnExpr:
        expr: fcYear6
        type: expr
    fn: SUM
    alias: fcYear6
input:
  - node: all_dropped_rows
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "fcYear1",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear1"
        },
        {
            "columnExpr": {
                "expr": "fcYear2",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear2"
        },
        {
            "columnExpr": {
                "expr": "fcYear3",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear3"
        },
        {
            "columnExpr": {
                "expr": "fcYear4",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear4"
        },
        {
            "columnExpr": {
                "expr": "fcYear5",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear5"
        },
        {
            "columnExpr": {
                "expr": "fcYear6",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "fcYear6"
        }
    ]
}
inputs = {
    "data": ctx["all_dropped_rows.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_27.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: clean_9_2
template: transform
name: clean_9_2
position:
  x: 5200
  y: 145
description:
  text: "Clean 9"
previewMode: "1000"
config:
  expressions:
  - *
  - `fcYear1` AS `fcYear_2027`
  - `fcYear2` AS `fcYear_2028`
  - `fcYear3` AS `fcYear_2029`
  - `fcYear4` AS `fcYear_2030`
  - `fcYear5` AS `fcYear_2031`
  - "99999" AS `supplierNo-1`
  - "99999" AS `supplierNo-2`
input:
  - node: join_17
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "`fcYear1` AS `fcYear_2027`",
        "`fcYear2` AS `fcYear_2028`",
        "`fcYear3` AS `fcYear_2029`",
        "`fcYear4` AS `fcYear_2030`",
        "`fcYear5` AS `fcYear_2031`",
        "\"99999\" AS `supplierNo-1`",
        "\"99999\" AS `supplierNo-2`"
    ]
}
inputs = {
    "data": ctx["join_17.joined_data"],
}
out = run(config, inputs, spark)
ctx["clean_9_2.transformed_data"] = out["transformed_data"]

# %%
"""
id: join_19
template: join
name: join_19
position:
  x: 5460
  y: 0
description:
  text: "Join 19"
previewMode: "1000"
config:
  join_type: inner
  join_conditions: left.`productCode` = right.`productCode`
  expressions: []
input:
  - node: clean_9_2
    input_port: left
    output_port: transformed_data
  - node: aggregate_13
    input_port: right
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "inner",
    "join_conditions": "left.`productCode` = right.`productCode`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_9_2.transformed_data"],
    "right": ctx["aggregate_13.aggregated_data"],
}
out = run(config, inputs, spark)
ctx["join_19.joined_data"] = out["joined_data"]

# %%
"""
id: clean_11
template: transform
name: clean_11
position:
  x: 5720
  y: 0
description:
  text: "Clean 11"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: join_19
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["join_19.joined_data"],
}
out = run(config, inputs, spark)
ctx["clean_11.transformed_data"] = out["transformed_data"]

# %%
"""
id: union_1
template: combine
name: union_1
position:
  x: 5980
  y: 0
description:
  text: "Union 1"
previewMode: "1000"
config:
  operator: UNION
  quantifier: ALL
input:
  - node: qualtrics_capacity_clean
    input_port: data_0
    output_port: transformed_data
  - node: clean_11
    input_port: data_1
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df_0 = inputs["data_0"]
    df_1 = inputs["data_1"]
    operator = config.get("operator", "UNION")
    quantifier = config.get("quantifier", "DISTINCT")

    op_map = {
        "UNION": lambda a, b: a.union(b),
        "INTERSECT": lambda a, b: a.intersectAll(b),
        "EXCEPT": lambda a, b: a.exceptAll(b),
        "MINUS": lambda a, b: a.exceptAll(b),
    }
    op_distinct_map = {
        "UNION": lambda a, b: a.union(b).distinct(),
        "INTERSECT": lambda a, b: a.intersect(b),
        "EXCEPT": lambda a, b: a.subtract(b),
        "MINUS": lambda a, b: a.subtract(b),
    }
    if quantifier == "DISTINCT":
        combine_fn = op_distinct_map.get(operator)
    else:
        combine_fn = op_map.get(operator)
    if not combine_fn:
        raise ValueError(f"Unsupported combine operator: {operator}")

    return {"combined_data": combine_fn(df_0, df_1)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "operator": "UNION",
    "quantifier": "ALL"
}
inputs = {
    "data_0": ctx["qualtrics_capacity_clean.transformed_data"],
    "data_1": ctx["clean_11.transformed_data"],
}
out = run(config, inputs, spark)
ctx["union_1.combined_data"] = out["combined_data"]

# %%
"""
id: pivot_3
template: sql
name: pivot_3
position:
  x: 6240
  y: 0
description:
  text: "Pivot 3"
previewMode: "1000"
config:
  query: SELECT * FROM union_1
input:
  - node: union_1
    input_port: data
    output_port: combined_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT * FROM union_1"
}
inputs = {
    "data": [
        ctx["union_1.combined_data"],
    ],
    "data__sources": [
        {"node": "union_1", "output_port": "combined_data", "name": "union_1", "df_name": "union_1"},
    ],
}
out = run(config, inputs, spark)
ctx["pivot_3.result"] = out["result"]

# %%
"""
id: clean_23
template: transform
name: clean_23
position:
  x: 6240
  y: 145
description:
  text: "Clean 23"
previewMode: "1000"
config:
  expressions:
  - *
input:
  - node: union_1
    input_port: data
    output_port: combined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*"
    ]
}
inputs = {
    "data": ctx["union_1.combined_data"],
}
out = run(config, inputs, spark)
ctx["clean_23.transformed_data"] = out["transformed_data"]

# %%
"""
id: category_pivot
template: sql
name: category_pivot
position:
  x: 6500
  y: 0
description:
  text: "Category Pivot"
previewMode: "1000"
config:
  query: |
    SELECT * FROM clean_23
    UNPIVOT (
      (`Capacity`, `Forecast`)
      FOR `Category_Pivot` IN (
        (`Capacity Year_2027`, `fcYear_2027`) AS 'Capacity Year_2027',
        (`Capacity Year_2028`, `fcYear_2028`) AS 'Capacity Year_2028',
        (`Capacity Year_2029`, `fcYear_2029`) AS 'Capacity Year_2029',
        (`Capacity Year_2030`, `fcYear_2030`) AS 'Capacity Year_2030',
        (`Capacity Year_2031`, `fcYear_2031`) AS 'Capacity Year_2031'
      )
    )
input:
  - node: clean_23
    input_port: data
    output_port: transformed_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT * FROM clean_23\nUNPIVOT (\n  (`Capacity`, `Forecast`)\n  FOR `Category_Pivot` IN (\n    (`Capacity Year_2027`, `fcYear_2027`) AS 'Capacity Year_2027',\n    (`Capacity Year_2028`, `fcYear_2028`) AS 'Capacity Year_2028',\n    (`Capacity Year_2029`, `fcYear_2029`) AS 'Capacity Year_2029',\n    (`Capacity Year_2030`, `fcYear_2030`) AS 'Capacity Year_2030',\n    (`Capacity Year_2031`, `fcYear_2031`) AS 'Capacity Year_2031'\n  )\n)"
}
inputs = {
    "data": [
        ctx["clean_23.transformed_data"],
    ],
    "data__sources": [
        {"node": "clean_23", "output_port": "transformed_data", "name": "clean_23", "df_name": "clean_23"},
    ],
}
out = run(config, inputs, spark)
ctx["category_pivot.result"] = out["result"]

# %%
"""
id: category_clean
template: sql
name: category_clean
position:
  x: 6760
  y: 0
description:
  text: "Category Clean"
previewMode: "1000"
config:
  query: "SELECT *, REGEXP_EXTRACT(`buyingDirector`, \"\\s(.+)\") AS `buyingDirectorLastName`, REGEXP_EXTRACT(`groupBuyingDirector`, \"\\s(.+)\") AS `groupBuyingDirectorLastName`, `Capacity Adjusted` AS `Capacity`, CAST(`Year` AS INT) AS `Year` FROM category_pivot WHERE `productClass` NOT IN (\"Seasonal\")"
input:
  - node: category_pivot
    input_port: data
    output_port: result
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *, REGEXP_EXTRACT(`buyingDirector`, \"\\s(.+)\") AS `buyingDirectorLastName`, REGEXP_EXTRACT(`groupBuyingDirector`, \"\\s(.+)\") AS `groupBuyingDirectorLastName`, `Capacity Adjusted` AS `Capacity`, CAST(`Year` AS INT) AS `Year` FROM category_pivot WHERE `productClass` NOT IN (\"Seasonal\")"
}
inputs = {
    "data": [
        ctx["category_pivot.result"],
    ],
    "data__sources": [
        {"node": "category_pivot", "output_port": "result", "name": "category_pivot", "df_name": "category_pivot"},
    ],
}
out = run(config, inputs, spark)
ctx["category_clean.result"] = out["result"]

# %%
"""
id: sourcing_join
template: join
name: sourcing_join
position:
  x: 7020
  y: 0
description:
  text: "Sourcing Join"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`Year` = right.`Year` AND left.`productCode` = right.`Item  Code`
  expressions: []
input:
  - node: category_clean
    input_port: left
    output_port: result
  - node: clean_2_1
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`Year` = right.`Year` AND left.`productCode` = right.`Item  Code`",
    "expressions": []
}
inputs = {
    "left": ctx["category_clean.result"],
    "right": ctx["clean_2_1.transformed_data"],
}
out = run(config, inputs, spark)
ctx["sourcing_join.joined_data"] = out["joined_data"]

# %%
"""
id: soucring_tmeline_clean
template: transform
name: soucring_tmeline_clean
position:
  x: 7280
  y: 0
description:
  text: "Soucring Tmeline Clean"
previewMode: "1000"
config:
  expressions:
  - "* EXCEPT (`Category`, `Team`)"
  - CAST(`CGNo` AS INT) AS `CGNo`
  - CAST(`Year` AS DATE) AS `Year`
  - "COALESCE(`Team`,\"Buyer Action\") AS `Team Adjusted`"
  - `CGNo` AS `CGNo 1`
  - `Year` AS `Year 1`
  - "COALESCE(`SupplierWithName`,'New Division TBD') AS `Supplier With Name`"
  - `CGNo` AS `CG No`
  - `productCode` AS `Product Code`
  - CASE WHEN `Supplier` = 'New Division TBD' THEN 'New Division TBD' WHEN `Supplier` IS NULL THEN 'New Division TBD' ELSE `Supplier` END AS `Supplier`
  - CASE WHEN `SupplierWithName` = 'New Division TBD' THEN 'New Division TBD' WHEN `SupplierWithName` IS NULL THEN 'New Division TBD' ELSE `SupplierWithName` END AS `SupplierWithName`
input:
  - node: sourcing_join
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT (`Category`, `Team`)",
        "CAST(`CGNo` AS INT) AS `CGNo`",
        "CAST(`Year` AS DATE) AS `Year`",
        "COALESCE(`Team`,\"Buyer Action\") AS `Team Adjusted`",
        "`CGNo` AS `CGNo 1`",
        "`Year` AS `Year 1`",
        "COALESCE(`SupplierWithName`,'New Division TBD') AS `Supplier With Name`",
        "`CGNo` AS `CG No`",
        "`productCode` AS `Product Code`",
        "CASE WHEN `Supplier` = 'New Division TBD' THEN 'New Division TBD' WHEN `Supplier` IS NULL THEN 'New Division TBD' ELSE `Supplier` END AS `Supplier`",
        "CASE WHEN `SupplierWithName` = 'New Division TBD' THEN 'New Division TBD' WHEN `SupplierWithName` IS NULL THEN 'New Division TBD' ELSE `SupplierWithName` END AS `SupplierWithName`"
    ]
}
inputs = {
    "data": ctx["sourcing_join.joined_data"],
}
out = run(config, inputs, spark)
ctx["soucring_tmeline_clean.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_7_2
template: transform
name: clean_7_2
position:
  x: 7540
  y: 0
description:
  text: "Clean 7"
previewMode: "1000"
config:
  expressions:
  - * EXCEPT (`Table Names`)
  - `Capacity` AS `Capacity Units`
  - `Forecast` AS `Forecast Cases`
input:
  - node: soucring_tmeline_clean
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT (`Table Names`)",
        "`Capacity` AS `Capacity Units`",
        "`Forecast` AS `Forecast Cases`"
    ]
}
inputs = {
    "data": ctx["soucring_tmeline_clean.transformed_data"],
}
out = run(config, inputs, spark)
ctx["clean_7_2.transformed_data"] = out["transformed_data"]

# %%
"""
id: aggregate_25
template: aggregate
name: aggregate_25
position:
  x: 7800
  y: 0
description:
  text: "Aggregate 25"
previewMode: "1000"
config:
  group_bys:
  - expr: Year
    type: expr
  aggregations:
  - columnExpr:
        expr: Forecast
        type: expr
    fn: SUM
    alias: Forecast
input:
  - node: clean_7_2
    input_port: data
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "Year",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "Forecast",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "Forecast"
        }
    ]
}
inputs = {
    "data": ctx["clean_7_2.transformed_data"],
}
out = run(config, inputs, spark)
ctx["aggregate_25.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: join_25
template: join
name: join_25
position:
  x: 7800
  y: 145
description:
  text: "Join 25"
previewMode: "1000"
config:
  join_type: left_anti
  join_conditions: left.`productCode` = right.`Legacy Code`
  expressions: []
input:
  - node: clean_18
    input_port: left
    output_port: result
  - node: clean_7_2
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left_anti",
    "join_conditions": "left.`productCode` = right.`Legacy Code`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_18.result"],
    "right": ctx["clean_7_2.transformed_data"],
}
out = run(config, inputs, spark)
ctx["join_25.joined_data"] = out["joined_data"]

# %%
"""
id: clean_19
template: sql
name: clean_19
position:
  x: 8060
  y: 0
description:
  text: "Clean 19"
previewMode: "1000"
config:
  query: "SELECT * FROM join_25 WHERE NOT (((`Year` == DATE(#2024-01-01#)) AND NOT (ISNULL(`Year`)))) AND NOT(`CG No` == 58)"
input:
  - node: join_25
    input_port: data
    output_port: joined_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT * FROM join_25 WHERE NOT (((`Year` == DATE(#2024-01-01#)) AND NOT (ISNULL(`Year`)))) AND NOT(`CG No` == 58)"
}
inputs = {
    "data": [
        ctx["join_25.joined_data"],
    ],
    "data__sources": [
        {"node": "join_25", "output_port": "joined_data", "name": "join_25", "df_name": "join_25"},
    ],
}
out = run(config, inputs, spark)
ctx["clean_19.result"] = out["result"]

# %%
"""
id: output
template: output
name: output
position:
  x: 8320
  y: 0
description:
  text: "Output"
previewMode: "1000"
config:
  catalog: main
  schema: default
  table_name: fyforecastdb_1011_main_1_25
input:
  - node: clean_19
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")
    if not table_name:
        raise ValueError("Output: 'table_name' is required")
    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)
    df.write.mode("overwrite").saveAsTable(full_name)
    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "main",
    "schema": "default",
    "table_name": "fyforecastdb_1011_main_1_25"
}
inputs = {
    "data": ctx["clean_19.result"],
}
out = run(config, inputs, spark)

# %%
"""
id: output_2
template: output
name: output_2
position:
  x: 8320
  y: 145
description:
  text: "Output 2"
previewMode: "1000"
config:
  catalog: main
  schema: default
  table_name: fy_forecast_capacity_flow_output_hyper
input:
  - node: clean_19
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")
    if not table_name:
        raise ValueError("Output: 'table_name' is required")
    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)
    df.write.mode("overwrite").saveAsTable(full_name)
    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "main",
    "schema": "default",
    "table_name": "fy_forecast_capacity_flow_output_hyper"
}
inputs = {
    "data": ctx["clean_19.result"],
}
out = run(config, inputs, spark)

# %%
"""
id: output_3
template: output
name: output_3
position:
  x: 8320
  y: 290
description:
  text: "Output 3"
previewMode: "1000"
config:
  catalog: main
  schema: default
  table_name: fyforecastdb_1011_main_bis
input:
  - node: clean_19
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")
    if not table_name:
        raise ValueError("Output: 'table_name' is required")
    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)
    df.write.mode("overwrite").saveAsTable(full_name)
    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "main",
    "schema": "default",
    "table_name": "fyforecastdb_1011_main_bis"
}
inputs = {
    "data": ctx["clean_19.result"],
}
out = run(config, inputs, spark)

# %%
"""
id: output_4
template: output
name: output_4
position:
  x: 8320
  y: 435
description:
  text: "Output 4"
previewMode: "1000"
config:
  catalog: main
  schema: default
  table_name: fy_forecast_capacity_flow_output_csv
input:
  - node: clean_19
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")
    if not table_name:
        raise ValueError("Output: 'table_name' is required")
    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)
    df.write.mode("overwrite").saveAsTable(full_name)
    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "main",
    "schema": "default",
    "table_name": "fy_forecast_capacity_flow_output_csv"
}
inputs = {
    "data": ctx["clean_19.result"],
}
out = run(config, inputs, spark)
