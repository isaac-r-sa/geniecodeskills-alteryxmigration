# %%
"""
id: customers
template: source
name: customers
position:
  x: 0
  y: 145
description:
  text: customers
  hash: ""
previewCodeHash: 135e29546bc32b4b
previewMode: "1000"
config:
  file_source:
    path: /Volumes/daphne/tableauprep/raw/customers.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/daphne/tableauprep/raw/customers.csv",
        "format": "csv",
        "header": True,
        "inferSchema": True
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["customers.data"] = out["data"]

# %%
"""
id: orders
template: source
name: orders
position:
  x: 0
  y: 0
description:
  text: orders
  hash: ""
previewCodeHash: dea48c99fbb4d9f7
previewMode: "1000"
config:
  file_source:
    path: /Volumes/daphne/tableauprep/raw/orders.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/daphne/tableauprep/raw/orders.csv",
        "format": "csv",
        "header": True,
        "inferSchema": True
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["orders.data"] = out["data"]

# %%
"""
id: products
template: source
name: products
position:
  x: 0
  y: 290
description:
  text: products
  hash: ""
previewCodeHash: eafc6edbaa08e69e
previewMode: "1000"
config:
  file_source:
    path: /Volumes/daphne/tableauprep/raw/products.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/daphne/tableauprep/raw/products.csv",
        "format": "csv",
        "header": True,
        "inferSchema": True
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["products.data"] = out["data"]

# %%
"""
id: clean_customers
template: filter
name: clean_customers
position:
  x: 260
  y: 145
description:
  text: Filter to APAC region.
  hash: 9bca9d9b
previewCodeHash: 2f9b62c8d611e303
previewMode: "1000"
config:
  condition: region = 'APAC'
input:
  - node: customers
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")

    if not condition:
        return {"filtered_data": df}

    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "region = 'APAC'"
}
inputs = {
    "data": ctx["customers.data"]
}
out = run(config, inputs, spark)
ctx["clean_customers.filtered_data"] = out["filtered_data"]

# %%
"""
id: filter_paid
template: filter
name: filter_paid
position:
  x: 260
  y: 0
description:
  text: Keep only records where status is paid.
  hash: bed7a402
previewCodeHash: c22c73659e50bf1b
previewMode: "1000"
config:
  condition: status = 'paid'
input:
  - node: orders
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")

    if not condition:
        return {"filtered_data": df}

    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "status = 'paid'"
}
inputs = {
    "data": ctx["orders.data"]
}
out = run(config, inputs, spark)
ctx["filter_paid.filtered_data"] = out["filtered_data"]

# %%
"""
id: cast_date
template: transform
name: cast_date
position:
  x: 520
  y: 0
description:
  text: Select columns and convert placed_at to date.
  hash: cb0cc3c5
previewCodeHash: 4744e721d330a158
previewMode: "1000"
config:
  expressions:
    - order_id
    - customer_id
    - amount
    - CAST(placed_at AS DATE) AS `placed_at`
input:
  - node: filter_paid
    input_port: data
    output_port: filtered_data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "order_id",
        "customer_id",
        "amount",
        "CAST(placed_at AS DATE) AS `placed_at`"
    ]
}
inputs = {
    "data": ctx["filter_paid.filtered_data"]
}
out = run(config, inputs, spark)
ctx["cast_date.transformed_data"] = out["transformed_data"]

# %%
"""
id: orders_customers
template: join
name: orders_customers
position:
  x: 780
  y: 0
description:
  text: Join left and right data on customer_id with a left join and keep selected columns from both sides.
  hash: c340813e
previewCodeHash: b4450db74048097a
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.customer_id = right.customer_id
  expressions:
    - "`left`.order_id"
    - "`left`.customer_id `customer_id`"
    - "`left`.amount"
    - "`left`.placed_at"
    - "`right`.customer_id `right_customer_id`"
    - "`right`.name"
    - "`right`.region"
    - "`right`.signup_year"
    - "`right`._rescued_data"
input:
  - node: cast_date
    input_port: left
    output_port: transformed_data
  - node: clean_customers
    input_port: right
    output_port: filtered_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.customer_id = right.customer_id",
    "expressions": [
        "`left`.order_id",
        "`left`.customer_id `customer_id`",
        "`left`.amount",
        "`left`.placed_at",
        "`right`.customer_id `right_customer_id`",
        "`right`.name",
        "`right`.region",
        "`right`.signup_year",
        "`right`._rescued_data"
    ]
}
inputs = {
    "left": ctx["cast_date.transformed_data"],
    "right": ctx["clean_customers.filtered_data"]
}
out = run(config, inputs, spark)
ctx["orders_customers.joined_data"] = out["joined_data"]

# %%
"""
id: join_products
template: join
name: join_products
position:
  x: 1040
  y: 0
description:
  text: Perform a left join on order and product IDs, keeping selected columns from both tables.
  hash: "37315005"
previewCodeHash: 2bc826fa7266df90
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.order_id = right.product_id
  expressions:
    - "`left`.order_id"
    - "`left`.customer_id"
    - "`left`.amount"
    - "`left`.placed_at"
    - "`left`.right_customer_id"
    - "`left`.name"
    - "`left`.region"
    - "`left`.signup_year"
    - "`left`._rescued_data `_rescued_data`"
    - "`right`.product_id"
    - "`right`.sku"
    - "`right`.category"
    - "`right`.unit_price"
    - "`right`._rescued_data `right__rescued_data`"
input:
  - node: orders_customers
    input_port: left
    output_port: joined_data
  - node: products
    input_port: right
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.order_id = right.product_id",
    "expressions": [
        "`left`.order_id",
        "`left`.customer_id",
        "`left`.amount",
        "`left`.placed_at",
        "`left`.right_customer_id",
        "`left`.name",
        "`left`.region",
        "`left`.signup_year",
        "`left`._rescued_data `_rescued_data`",
        "`right`.product_id",
        "`right`.sku",
        "`right`.category",
        "`right`.unit_price",
        "`right`._rescued_data `right__rescued_data`"
    ]
}
inputs = {
    "left": ctx["orders_customers.joined_data"],
    "right": ctx["products.data"]
}
out = run(config, inputs, spark)
ctx["join_products.joined_data"] = out["joined_data"]

# %%
"""
id: apac_only
template: filter
name: apac_only
position:
  x: 1300
  y: 580
description:
  text: Filter data to keep only entries from the APAC region.
  hash: 8b64b906
previewCodeHash: 87d12c5d49d32269
previewMode: "1000"
config:
  condition: region = 'APAC'
input:
  - node: join_products
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")

    if not condition:
        return {"filtered_data": df}

    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "region = 'APAC'"
}
inputs = {
    "data": ctx["join_products.joined_data"]
}
out = run(config, inputs, spark)
ctx["apac_only.filtered_data"] = out["filtered_data"]

# %%
"""
id: category_counts
template: pivot
name: category_counts
position:
  x: 1300
  y: 290
description:
  text: category counts
  hash: ""
previewCodeHash: bfff9dc343082818
previewMode: "1000"
config:
  mode: pivot
  pivot_column: category
  value_column: order_id
  agg_fn: COUNT
  null_behavior: zero
  unpivot_columns: []
  key_column_name: Column Name
  value_column_name: Value
  exclude_columns: []
input:
  - node: join_products
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List, Optional, Set
import pyspark.sql.functions as F

AGG_FUNCTIONS = {
    "SUM": F.sum,
    "AVG": F.avg,
    "COUNT": F.count,
    "MIN": F.min,
    "MAX": F.max,
}

def _validate_columns_exist(df, columns: List[str], label: str) -> None:
    df_cols: Set[str] = set(df.columns)
    missing = [c for c in columns if c not in df_cols]
    if missing:
        raise ValueError(
            f"{label}: column(s) not found in input data: {missing}. "
            f"Available columns: {df.columns}"
        )

def _validate_aggregation(agg_fn: str) -> None:
    if agg_fn not in AGG_FUNCTIONS:
        raise ValueError(
            f"Unsupported aggregation '{agg_fn}'. "
            f"Choose one of: {list(AGG_FUNCTIONS.keys())}"
        )

def _validate_no_overlap(pivot_cols: List[str], fixed_cols: List[str]) -> None:
    overlap = set(pivot_cols) & set(fixed_cols)
    if overlap:
        raise ValueError(
            f"Column(s) {sorted(overlap)} appear in both pivot and fixed roles. "
            "A column cannot serve both roles."
        )

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    mode: str = config.get("mode", "pivot")
    exclude_cfg: List[Dict[str, str]] = config.get("exclude_columns", [])
    excluded: Set[str] = {c.get("expr", "") for c in exclude_cfg if c.get("expr")}

    if mode == "unpivot":
        unpivot_cols_cfg: List[Dict[str, str]] = config.get("unpivot_columns", [])
        key_col: str = config.get("key_column_name", "Column Name")
        value_col: str = config.get("value_column_name", "Value")

        unpivot_col_names = [c.get("expr", "") for c in unpivot_cols_cfg if c.get("expr")]
        if not unpivot_col_names:
            raise ValueError("At least one column must be selected for unpivoting.")

        _validate_columns_exist(df, unpivot_col_names, "Unpivot columns")
        if excluded:
            _validate_columns_exist(df, list(excluded), "Exclude columns")

        fixed_cols = [
            c for c in df.columns
            if c not in unpivot_col_names and c not in excluded
        ]
        _validate_no_overlap(unpivot_col_names, fixed_cols)

        n = len(unpivot_col_names)
        stack_parts = ", ".join(
            [f"'{col}', `{col}`" for col in unpivot_col_names]
        )
        stack_expr = (
            f"stack({n}, {stack_parts}) "
            f"as (`{key_col}`, `{value_col}`)"
        )
        result = df.select(
            *[F.col(c) for c in fixed_cols],
            F.expr(stack_expr),
        )
        return {"pivoted_data": result}

    # ── Pivot (Rows → Columns) ───────────────────────────────────────────
    pivot_column: str = config.get("pivot_column", "")
    value_column: str = config.get("value_column", "")
    agg_fn: str = config.get("agg_fn", "SUM")
    null_behavior: str = config.get("null_behavior", "null")

    if not pivot_column or not value_column:
        return {"pivoted_data": df}

    _validate_columns_exist(df, [pivot_column, value_column], "Pivot")
    if excluded:
        _validate_columns_exist(df, list(excluded), "Exclude columns")
    _validate_aggregation(agg_fn)

    fixed_cols = [
        c for c in df.columns
        if c not in (pivot_column, value_column) and c not in excluded
    ]
    agg_func = AGG_FUNCTIONS[agg_fn]

    result = (
        df
        .select(*fixed_cols, pivot_column, value_column)
        .groupBy(fixed_cols)
        .pivot(pivot_column)
        .agg(agg_func(F.col(value_column)))
    )
    if null_behavior == "zero":
        result = result.fillna(0)
    return {"pivoted_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "mode": "pivot",
    "pivot_column": "category",
    "value_column": "order_id",
    "agg_fn": "COUNT",
    "null_behavior": "zero",
    "unpivot_columns": [],
    "key_column_name": "Column Name",
    "value_column_name": "Value",
    "exclude_columns": []
}
inputs = {
    "data": ctx["join_products.joined_data"]
}
out = run(config, inputs, spark)
ctx["category_counts.pivoted_data"] = out["pivoted_data"]

# %%
"""
id: high_value
template: filter
name: high_value
position:
  x: 1300
  y: 435
description:
  text: Keep records where amount is greater than 100.
  hash: 18286ff9
previewCodeHash: c06ad650225be3c6
previewMode: "1000"
config:
  condition: amount > 100
input:
  - node: join_products
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")

    if not condition:
        return {"filtered_data": df}

    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "amount > 100"
}
inputs = {
    "data": ctx["join_products.joined_data"]
}
out = run(config, inputs, spark)
ctx["high_value.filtered_data"] = out["filtered_data"]

# %%
"""
id: revenue_by_customer
template: aggregate
name: revenue_by_customer
position:
  x: 1300
  y: 145
description:
  text: revenue by customer
  hash: ""
previewCodeHash: 5bcb946df652d2c2
previewMode: "1000"
config:
  group_bys:
    - expr: customer_id
      type: expr
    - expr: name
      type: expr
  aggregations:
    - columnExpr:
        expr: amount
        type: expr
      fn: SUM
      alias: total_amount
input:
  - node: join_products
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        # Skip pass-through columns that duplicate a group-by column;
        # groupBy() already includes them in the output.
        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum,
            "AVG": F.avg,
            "COUNT": F.count,
            "MIN": F.min,
            "MAX": F.max,
            "MEAN": F.mean,
            "MEDIAN": F.median,
            "STDDEV": F.stddev,
            "VARIANCE": F.variance,
        }

        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")

        if alias:
            col = col.alias(alias)

        agg_exprs.append(col)

    group_cols = [
        gb.get("expr", "") for gb in group_bys if gb.get("expr", "")
    ]

    if not agg_exprs:
        if group_cols:
            result = df.select(*group_cols).distinct()
            return {"aggregated_data": result}
        return {"aggregated_data": df}

    if group_cols:
        result = df.groupBy(*group_cols).agg(*agg_exprs)
    else:
        result = df.agg(*agg_exprs)

    return {"aggregated_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "customer_id",
            "type": "expr"
        },
        {
            "expr": "name",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "amount",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "total_amount",
            "withAsKeyword": None
        }
    ]
}
inputs = {
    "data": ctx["join_products.joined_data"]
}
out = run(config, inputs, spark)
ctx["revenue_by_customer.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: revenue_by_region
template: aggregate
name: revenue_by_region
position:
  x: 1300
  y: 0
description:
  text: revenue by region
  hash: ""
previewCodeHash: 8f82f838a25cc846
previewMode: "1000"
config:
  group_bys:
    - expr: region
      type: expr
  aggregations:
    - columnExpr:
        expr: amount
        type: expr
      fn: SUM
      alias: total_amount
    - columnExpr:
        expr: order_id
        type: expr
      fn: COUNT
      alias: order_count
input:
  - node: join_products
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        # Skip pass-through columns that duplicate a group-by column;
        # groupBy() already includes them in the output.
        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum,
            "AVG": F.avg,
            "COUNT": F.count,
            "MIN": F.min,
            "MAX": F.max,
            "MEAN": F.mean,
            "MEDIAN": F.median,
            "STDDEV": F.stddev,
            "VARIANCE": F.variance,
        }

        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")

        if alias:
            col = col.alias(alias)

        agg_exprs.append(col)

    group_cols = [
        gb.get("expr", "") for gb in group_bys if gb.get("expr", "")
    ]

    if not agg_exprs:
        if group_cols:
            result = df.select(*group_cols).distinct()
            return {"aggregated_data": result}
        return {"aggregated_data": df}

    if group_cols:
        result = df.groupBy(*group_cols).agg(*agg_exprs)
    else:
        result = df.agg(*agg_exprs)

    return {"aggregated_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "region",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "amount",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "total_amount",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "order_id",
                "type": "expr"
            },
            "fn": "COUNT",
            "alias": "order_count",
            "withAsKeyword": None
        }
    ]
}
inputs = {
    "data": ctx["join_products.joined_data"]
}
out = run(config, inputs, spark)
ctx["revenue_by_region.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: hi_or_apac
template: combine
name: hi_or_apac
position:
  x: 1560
  y: 435
description:
  text: hi or apac
  hash: ""
previewCodeHash: 10a06433e8c7f8b0
previewMode: "1000"
config:
  operator: UNION
  quantifier: ALL
input:
  - node: high_value
    input_port: data_0
    output_port: filtered_data
  - node: apac_only
    input_port: data_1
    output_port: filtered_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df_0 = inputs["data_0"]
    df_1 = inputs["data_1"]
    operator = config.get("operator", "UNION")
    quantifier = config.get("quantifier", "DISTINCT")

    op_map = {
        "UNION": lambda a, b: a.union(b),
        "INTERSECT": lambda a, b: a.intersectAll(b),
        "EXCEPT": lambda a, b: a.exceptAll(b),
        "MINUS": lambda a, b: a.exceptAll(b),
    }
    op_distinct_map = {
        "UNION": lambda a, b: a.union(b).distinct(),
        "INTERSECT": lambda a, b: a.intersect(b),
        "EXCEPT": lambda a, b: a.subtract(b),
        "MINUS": lambda a, b: a.subtract(b),
    }

    if quantifier == "DISTINCT":
        combine_fn = op_distinct_map.get(operator)
    else:
        combine_fn = op_map.get(operator)

    if not combine_fn:
        raise ValueError(f"Unsupported combine operator: {operator}")

    result = combine_fn(df_0, df_1)
    return {"combined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "operator": "UNION",
    "quantifier": "ALL"
}
inputs = {
    "data_0": ctx["high_value.filtered_data"],
    "data_1": ctx["apac_only.filtered_data"]
}
out = run(config, inputs, spark)
ctx["hi_or_apac.combined_data"] = out["combined_data"]

# %%
"""
id: publish_revenue
template: output
name: publish_revenue
position:
  x: 1560
  y: 0
description:
  text: publish revenue
  hash: ""
previewCodeHash: bf6157a9f80edc36
previewMode: "1000"
config:
  catalog: daphne
  schema: tableauprep
  table_name: revenue_summary
input:
  - node: revenue_by_region
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "daphne",
    "schema": "tableauprep",
    "table_name": "revenue_summary"
}
inputs = {
    "data": ctx["revenue_by_region.aggregated_data"]
}
out = run(config, inputs, spark)

# %%
"""
id: rank_by_revenue
template: aggregate
name: rank_by_revenue
position:
  x: 1820
  y: 435
description:
  text: rank by revenue
  hash: ""
previewCodeHash: a96051d44e762fd5
previewMode: "1000"
config:
  group_bys:
    - expr: region
      type: expr
  aggregations:
    - columnExpr:
        expr: amount
        type: expr
      fn: MAX
      alias: max_amount
input:
  - node: hi_or_apac
    input_port: data
    output_port: combined_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        # Skip pass-through columns that duplicate a group-by column;
        # groupBy() already includes them in the output.
        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum,
            "AVG": F.avg,
            "COUNT": F.count,
            "MIN": F.min,
            "MAX": F.max,
            "MEAN": F.mean,
            "MEDIAN": F.median,
            "STDDEV": F.stddev,
            "VARIANCE": F.variance,
        }

        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")

        if alias:
            col = col.alias(alias)

        agg_exprs.append(col)

    group_cols = [
        gb.get("expr", "") for gb in group_bys if gb.get("expr", "")
    ]

    if not agg_exprs:
        if group_cols:
            result = df.select(*group_cols).distinct()
            return {"aggregated_data": result}
        return {"aggregated_data": df}

    if group_cols:
        result = df.groupBy(*group_cols).agg(*agg_exprs)
    else:
        result = df.agg(*agg_exprs)

    return {"aggregated_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "region",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "amount",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "max_amount",
            "withAsKeyword": None
        }
    ]
}
inputs = {
    "data": ctx["hi_or_apac.combined_data"]
}
out = run(config, inputs, spark)
ctx["rank_by_revenue.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: rev_export_csv
template: output
name: rev_export_csv
position:
  x: 2080
  y: 435
description:
  text: rev_export.csv
  hash: ""
previewMode: "1000"
config:
  catalog: daphne
  schema: tableauprep
  table_name: flow_output_csv
input:
  - node: rank_by_revenue
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "daphne",
    "schema": "tableauprep",
    "table_name": "flow_output_csv"
}
inputs = {
    "data": ctx["rank_by_revenue.aggregated_data"]
}
out = run(config, inputs, spark)

# %% [markdown]
# ---
# id: pipeline_header
# template: markdown
# name: FY Forecast Capacity Flow
# position:
#   x: 0
#   y: -260
# dimensions:
#   width: 700
#   height: 240
# config:
#   md: |
#     # Complex Orders Pipeline
#
#     **Converted from:** `complex.tflx` (Tableau Prep)
#
#     Combines orders, customers, and products data to produce
#     revenue analytics by region, customer, and category.
#
#     **Core pipeline path:**
#     Orders → Filter (paid) → Cast date → Join Customers → Join Products
#     → Aggregates (region / customer / category pivot)
#     → Filter branches (high-value / APAC) → Union → MAX revenue
#
#     **Data sources:** 3 (orders.csv, customers.csv, products.xlsx→csv)
#     **Outputs:** `main.default.revenue_summary`, `main.default.flow_output_csv`
# ---
