# %% [markdown]
# ---
# id: pipeline_header
# template: markdown
# name: highly_complex
# position:
#   x: 0
#   y: -260
# dimensions:
#   width: 700
#   height: 220
# config:
#   md: |
#     # highly_complex
#
#     **Converted from `highly_complex.tflx`** by `convert_tflx.py` (tableau-to-lakeflow-designer skill).
#
#     - 26 nodes in the original Tableau Prep flow
#     - Output table: `main.default.flow_output`
# ---

# %%
"""
id: orders
template: source
name: orders
position:
  x: 0
  y: 0
description:
  text: "orders"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/extracted_data/orders.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/extracted_data/orders.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["orders.data"] = out["data"]

# %%
"""
id: customers
template: source
name: customers
position:
  x: 0
  y: 145
description:
  text: "customers"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/extracted_data/synthetic/customers.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/extracted_data/synthetic/customers.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["customers.data"] = out["data"]

# %%
"""
id: products
template: source
name: products
position:
  x: 0
  y: 290
description:
  text: "products"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/extracted_data/synthetic/products.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/extracted_data/synthetic/products.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["products.data"] = out["data"]

# %%
"""
id: capacity
template: source
name: capacity
position:
  x: 0
  y: 435
description:
  text: "capacity"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/extracted_data/synthetic/capacity.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/extracted_data/synthetic/capacity.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["capacity.data"] = out["data"]

# %%
"""
id: inventory
template: source
name: inventory
position:
  x: 0
  y: 580
description:
  text: "inventory"
previewMode: "1000"
config:
  file_source:
    path: /Workspace/extracted_data/inventory.csv
    format: csv
    header: true
    inferSchema: true
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Workspace/extracted_data/inventory.csv",
        "format": "csv",
        "header": true,
        "inferSchema": true
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["inventory.data"] = out["data"]

# %%
"""
id: clean_orders
template: sql
name: clean_orders
position:
  x: 260
  y: 0
description:
  text: "clean orders"
previewMode: "1000"
config:
  query: "SELECT *, CAST(`placed_at` AS DATE) AS `placed_at`, `amount` AS `revenue` FROM orders WHERE `status` = \"paid\""
input:
  - node: orders
    input_port: data
    output_port: data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *, CAST(`placed_at` AS DATE) AS `placed_at`, `amount` AS `revenue` FROM orders WHERE `status` = \"paid\""
}
inputs = {
    "data": [
        ctx["orders.data"],
    ],
    "data__sources": [
        {"node": "orders", "output_port": "data", "name": "orders", "df_name": "orders"},
    ],
}
out = run(config, inputs, spark)
ctx["clean_orders.result"] = out["result"]

# %%
"""
id: clean_customers
template: transform
name: clean_customers
position:
  x: 260
  y: 145
description:
  text: "clean customers"
previewMode: "1000"
config:
  expressions:
  - *
  - `region` AS `Region`
  - CAST(`signup_year` AS INT) AS `signup_year`
input:
  - node: customers
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])
    if not expressions:
        return {"transformed_data": df}
    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "*",
        "`region` AS `Region`",
        "CAST(`signup_year` AS INT) AS `signup_year`"
    ]
}
inputs = {
    "data": ctx["customers.data"],
}
out = run(config, inputs, spark)
ctx["clean_customers.transformed_data"] = out["transformed_data"]

# %%
"""
id: clean_products
template: sql
name: clean_products
position:
  x: 260
  y: 290
description:
  text: "clean products"
previewMode: "1000"
config:
  query: "SELECT *, `sku` + ' - ' + `category` AS `display_name` FROM products WHERE `category` NOT IN (\"\\\"Wine\\\"\", \"\\\"Beer\\\"\")"
input:
  - node: products
    input_port: data
    output_port: data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *, `sku` + ' - ' + `category` AS `display_name` FROM products WHERE `category` NOT IN (\"\\\"Wine\\\"\", \"\\\"Beer\\\"\")"
}
inputs = {
    "data": [
        ctx["products.data"],
    ],
    "data__sources": [
        {"node": "products", "output_port": "data", "name": "products", "df_name": "products"},
    ],
}
out = run(config, inputs, spark)
ctx["clean_products.result"] = out["result"]

# %%
"""
id: clean_inventory
template: filter
name: clean_inventory
position:
  x: 260
  y: 435
description:
  text: "clean inventory"
previewMode: "1000"
config:
  condition: `on_hand` > 0
input:
  - node: inventory
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")
    if not condition:
        return {"filtered_data": df}
    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "`on_hand` > 0"
}
inputs = {
    "data": ctx["inventory.data"],
}
out = run(config, inputs, spark)
ctx["clean_inventory.filtered_data"] = out["filtered_data"]

# %%
"""
id: orders_customers
template: join
name: orders_customers
position:
  x: 520
  y: 0
description:
  text: "orders+customers"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`customer_id` = right.`customer_id`
  expressions: []
input:
  - node: clean_orders
    input_port: left
    output_port: result
  - node: clean_customers
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`customer_id` = right.`customer_id`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_orders.result"],
    "right": ctx["clean_customers.transformed_data"],
}
out = run(config, inputs, spark)
ctx["orders_customers.joined_data"] = out["joined_data"]

# %%
"""
id: customers_w_o_orders
template: join
name: customers_w_o_orders
position:
  x: 520
  y: 145
description:
  text: "customers w/o orders"
previewMode: "1000"
config:
  join_type: left_anti
  join_conditions: left.`customer_id` = right.`customer_id`
  expressions: []
input:
  - node: clean_orders
    input_port: left
    output_port: result
  - node: clean_customers
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left_anti",
    "join_conditions": "left.`customer_id` = right.`customer_id`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_orders.result"],
    "right": ctx["clean_customers.transformed_data"],
}
out = run(config, inputs, spark)
ctx["customers_w_o_orders.joined_data"] = out["joined_data"]

# %%
"""
id: capacity_2
template: join
name: capacity_2
position:
  x: 520
  y: 290
description:
  text: "+capacity"
previewMode: "1000"
config:
  join_type: inner
  join_conditions: left.`sku` = right.`sku`
  expressions: []
input:
  - node: capacity
    input_port: left
    output_port: data
  - node: clean_products
    input_port: right
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "inner",
    "join_conditions": "left.`sku` = right.`sku`",
    "expressions": []
}
inputs = {
    "left": ctx["capacity.data"],
    "right": ctx["clean_products.result"],
}
out = run(config, inputs, spark)
ctx["capacity_2.joined_data"] = out["joined_data"]

# %%
"""
id: products_2
template: join
name: products_2
position:
  x: 780
  y: 0
description:
  text: "+products"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`order_id` = right.`product_id`
  expressions: []
input:
  - node: clean_products
    input_port: left
    output_port: result
  - node: orders_customers
    input_port: right
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`order_id` = right.`product_id`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_products.result"],
    "right": ctx["orders_customers.joined_data"],
}
out = run(config, inputs, spark)
ctx["products_2.joined_data"] = out["joined_data"]

# %%
"""
id: export_csv
template: output
name: export_csv
position:
  x: 780
  y: 145
description:
  text: "export csv"
previewMode: "1000"
config:
  catalog: main
  schema: default
  table_name: flow_output_csv
input:
  - node: customers_w_o_orders
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")
    if not table_name:
        raise ValueError("Output: 'table_name' is required")
    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)
    df.write.mode("overwrite").saveAsTable(full_name)
    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "main",
    "schema": "default",
    "table_name": "flow_output_csv"
}
inputs = {
    "data": ctx["customers_w_o_orders.joined_data"],
}
out = run(config, inputs, spark)

# %%
"""
id: unpivot_capacity
template: sql
name: unpivot_capacity
position:
  x: 780
  y: 290
description:
  text: "unpivot capacity"
previewMode: "1000"
config:
  query: |
    SELECT * FROM capacity_2
    UNPIVOT (
      `capacity` FOR `cap_year` IN (
        `year_2027` AS '2027',
        `year_2028` AS '2028',
        `year_2029` AS '2029',
        `year_2030` AS '2030',
        `year_2031` AS '2031'
      )
    )
input:
  - node: capacity_2
    input_port: data
    output_port: joined_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT * FROM capacity_2\nUNPIVOT (\n  `capacity` FOR `cap_year` IN (\n    `year_2027` AS '2027',\n    `year_2028` AS '2028',\n    `year_2029` AS '2029',\n    `year_2030` AS '2030',\n    `year_2031` AS '2031'\n  )\n)"
}
inputs = {
    "data": [
        ctx["capacity_2.joined_data"],
    ],
    "data__sources": [
        {"node": "capacity_2", "output_port": "joined_data", "name": "capacity_2", "df_name": "capacity_2"},
    ],
}
out = run(config, inputs, spark)
ctx["unpivot_capacity.result"] = out["result"]

# %%
"""
id: inventory_2
template: join
name: inventory_2
position:
  x: 1040
  y: 0
description:
  text: "+inventory"
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.`product_id` = right.`product_id`
  expressions: []
input:
  - node: clean_inventory
    input_port: left
    output_port: filtered_data
  - node: products_2
    input_port: right
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)
    if expressions:
        result = result.selectExpr(*expressions)
    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.`product_id` = right.`product_id`",
    "expressions": []
}
inputs = {
    "left": ctx["clean_inventory.filtered_data"],
    "right": ctx["products_2.joined_data"],
}
out = run(config, inputs, spark)
ctx["inventory_2.joined_data"] = out["joined_data"]

# %%
"""
id: rev_by_region
template: aggregate
name: rev_by_region
position:
  x: 1300
  y: 0
description:
  text: "rev by region"
previewMode: "1000"
config:
  group_bys:
  - expr: Region
    type: expr
  aggregations:
  - columnExpr:
        expr: amount
        type: expr
    fn: SUM
    alias: amount
  - columnExpr:
        expr: revenue
        type: expr
    fn: SUM
    alias: revenue
input:
  - node: inventory_2
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "Region",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "amount",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "amount"
        },
        {
            "columnExpr": {
                "expr": "revenue",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "revenue"
        }
    ]
}
inputs = {
    "data": ctx["inventory_2.joined_data"],
}
out = run(config, inputs, spark)
ctx["rev_by_region.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: rev_by_category
template: aggregate
name: rev_by_category
position:
  x: 1300
  y: 145
description:
  text: "rev by category"
previewMode: "1000"
config:
  group_bys:
  - expr: category
    type: expr
  aggregations:
  - columnExpr:
        expr: revenue
        type: expr
    fn: SUM
    alias: revenue
input:
  - node: inventory_2
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "category",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "revenue",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "revenue"
        }
    ]
}
inputs = {
    "data": ctx["inventory_2.joined_data"],
}
out = run(config, inputs, spark)
ctx["rev_by_category.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: units_by_loc
template: aggregate
name: units_by_loc
position:
  x: 1300
  y: 290
description:
  text: "units by loc"
previewMode: "1000"
config:
  group_bys:
  - expr: location
    type: expr
  aggregations:
  - columnExpr:
        expr: on_hand
        type: expr
    fn: SUM
    alias: on_hand
input:
  - node: inventory_2
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "location",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "on_hand",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "on_hand"
        }
    ]
}
inputs = {
    "data": ctx["inventory_2.joined_data"],
}
out = run(config, inputs, spark)
ctx["units_by_loc.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: category_pivot
template: pivot
name: category_pivot
position:
  x: 1300
  y: 435
description:
  text: "category-pivot"
previewMode: "1000"
config:
  mode: pivot
  group_by: []
  pivot_column: category
  value_column: amount
  agg: sum
input:
  - node: inventory_2
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    mode = config.get("mode", "pivot")
    if mode == "pivot":
        group_by = config.get("group_by", [])
        pivot_col = config.get("pivot_column")
        value_col = config.get("value_column")
        agg_fn = config.get("agg", "count").lower()
        result = df.groupBy(*group_by).pivot(pivot_col).agg(getattr(F, agg_fn)(value_col))
        return {"pivoted_data": result}
    else:
        id_cols: List[str] = config.get("id_columns", [])
        value_cols: List[str] = config.get("value_columns", [])
        key_name = config.get("key_name", "key")
        value_name = config.get("value_name", "value")
        stack_expr = "stack({n}, {pairs}) AS ({k}, {v})".format(
            n=len(value_cols),
            pairs=", ".join(f"'{c}', `{c}`" for c in value_cols),
            k=key_name,
            v=value_name,
        )
        result = df.selectExpr(*id_cols, stack_expr)
        return {"pivoted_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "mode": "pivot",
    "group_by": [],
    "pivot_column": "category",
    "value_column": "amount",
    "agg": "sum"
}
inputs = {
    "data": ctx["inventory_2.joined_data"],
}
out = run(config, inputs, spark)
ctx["category_pivot.pivoted_data"] = out["pivoted_data"]

# %%
"""
id: high_value
template: filter
name: high_value
position:
  x: 1300
  y: 580
description:
  text: "high-value"
previewMode: "1000"
config:
  condition: `amount` > 100
input:
  - node: inventory_2
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")
    if not condition:
        return {"filtered_data": df}
    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "`amount` > 100"
}
inputs = {
    "data": ctx["inventory_2.joined_data"],
}
out = run(config, inputs, spark)
ctx["high_value.filtered_data"] = out["filtered_data"]

# %%
"""
id: low_value
template: filter
name: low_value
position:
  x: 1300
  y: 725
description:
  text: "low-value"
previewMode: "1000"
config:
  condition: `amount` <= 100
input:
  - node: inventory_2
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    condition = config.get("condition", "")
    if not condition:
        return {"filtered_data": df}
    return {"filtered_data": df.filter(condition)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "condition": "`amount` <= 100"
}
inputs = {
    "data": ctx["inventory_2.joined_data"],
}
out = run(config, inputs, spark)
ctx["low_value.filtered_data"] = out["filtered_data"]

# %%
"""
id: hi_lo
template: combine
name: hi_lo
position:
  x: 1560
  y: 0
description:
  text: "hi-lo"
previewMode: "1000"
config:
  operator: UNION
  quantifier: ALL
input:
  - node: high_value
    input_port: data_0
    output_port: filtered_data
  - node: low_value
    input_port: data_1
    output_port: filtered_data
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df_0 = inputs["data_0"]
    df_1 = inputs["data_1"]
    operator = config.get("operator", "UNION")
    quantifier = config.get("quantifier", "DISTINCT")

    op_map = {
        "UNION": lambda a, b: a.union(b),
        "INTERSECT": lambda a, b: a.intersectAll(b),
        "EXCEPT": lambda a, b: a.exceptAll(b),
        "MINUS": lambda a, b: a.exceptAll(b),
    }
    op_distinct_map = {
        "UNION": lambda a, b: a.union(b).distinct(),
        "INTERSECT": lambda a, b: a.intersect(b),
        "EXCEPT": lambda a, b: a.subtract(b),
        "MINUS": lambda a, b: a.subtract(b),
    }
    if quantifier == "DISTINCT":
        combine_fn = op_distinct_map.get(operator)
    else:
        combine_fn = op_map.get(operator)
    if not combine_fn:
        raise ValueError(f"Unsupported combine operator: {operator}")

    return {"combined_data": combine_fn(df_0, df_1)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "operator": "UNION",
    "quantifier": "ALL"
}
inputs = {
    "data_0": ctx["high_value.filtered_data"],
    "data_1": ctx["low_value.filtered_data"],
}
out = run(config, inputs, spark)
ctx["hi_lo.combined_data"] = out["combined_data"]

# %%
"""
id: post_union_agg
template: aggregate
name: post_union_agg
position:
  x: 1820
  y: 0
description:
  text: "post-union agg"
previewMode: "1000"
config:
  group_bys:
  - expr: Region
    type: expr
  aggregations:
  - columnExpr:
        expr: amount
        type: expr
    fn: SUM
    alias: amount
input:
  - node: hi_lo
    input_port: data
    output_port: combined_data
"""

# generated from the system
from typing import Dict, Any
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum, "AVG": F.avg, "COUNT": F.count, "MIN": F.min, "MAX": F.max,
            "MEAN": F.mean, "MEDIAN": F.median, "STDDEV": F.stddev, "VARIANCE": F.variance,
        }
        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        else:
            col = F.expr(f"{fn}({raw_expr})")
        if alias:
            col = col.alias(alias)
        agg_exprs.append(col)

    group_cols = [gb.get("expr", "") for gb in group_bys if gb.get("expr", "")]
    if not agg_exprs:
        if group_cols:
            return {"aggregated_data": df.select(*group_cols).distinct()}
        return {"aggregated_data": df}
    if group_cols:
        return {"aggregated_data": df.groupBy(*group_cols).agg(*agg_exprs)}
    return {"aggregated_data": df.agg(*agg_exprs)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "Region",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "amount",
                "type": "expr"
            },
            "fn": "SUM",
            "alias": "amount"
        }
    ]
}
inputs = {
    "data": ctx["hi_lo.combined_data"],
}
out = run(config, inputs, spark)
ctx["post_union_agg.aggregated_data"] = out["aggregated_data"]

# %%
"""
id: mixed_cleanup
template: sql
name: mixed_cleanup
position:
  x: 2080
  y: 0
description:
  text: "mixed cleanup"
previewMode: "1000"
config:
  query: "SELECT *, `Region` AS `uppercase_region`, CAST(`amount` AS DOUBLE) AS `amount` FROM post_union_agg WHERE `Region` != 'EMEA'"
input:
  - node: post_union_agg
    input_port: data
    output_port: aggregated_data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT *, `Region` AS `uppercase_region`, CAST(`amount` AS DOUBLE) AS `amount` FROM post_union_agg WHERE `Region` != 'EMEA'"
}
inputs = {
    "data": [
        ctx["post_union_agg.aggregated_data"],
    ],
    "data__sources": [
        {"node": "post_union_agg", "output_port": "aggregated_data", "name": "post_union_agg", "df_name": "post_union_agg"},
    ],
}
out = run(config, inputs, spark)
ctx["mixed_cleanup.result"] = out["result"]

# %%
"""
id: publish_summary
template: output
name: publish_summary
position:
  x: 2340
  y: 0
description:
  text: "publish summary"
previewMode: "1000"
config:
  catalog: main
  schema: default
  table_name: demo_summary
input:
  - node: mixed_cleanup
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")
    if not table_name:
        raise ValueError("Output: 'table_name' is required")
    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)
    df.write.mode("overwrite").saveAsTable(full_name)
    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "main",
    "schema": "default",
    "table_name": "demo_summary"
}
inputs = {
    "data": ctx["mixed_cleanup.result"],
}
out = run(config, inputs, spark)
